# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-общей-информации" data-toc-modified-id="Изучение-общей-информации-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Изучение общей информации</a></span><ul class="toc-item"><li><span><a href="#Загрузка-библиотек" data-toc-modified-id="Загрузка-библиотек-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Загрузка библиотек</a></span></li><li><span><a href="#Открытие-датасета" data-toc-modified-id="Открытие-датасета-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Открытие датасета</a></span><ul class="toc-item"><li><span><a href="#Обучающая-выборка" data-toc-modified-id="Обучающая-выборка-2.1.2.1"><span class="toc-item-num">2.1.2.1&nbsp;&nbsp;</span>Обучающая выборка</a></span></li><li><span><a href="#Тестовая-выборка" data-toc-modified-id="Тестовая-выборка-2.1.2.2"><span class="toc-item-num">2.1.2.2&nbsp;&nbsp;</span>Тестовая выборка</a></span></li><li><span><a href="#Исходная-выборка" data-toc-modified-id="Исходная-выборка-2.1.2.3"><span class="toc-item-num">2.1.2.3&nbsp;&nbsp;</span>Исходная выборка</a></span></li></ul></li><li><span><a href="#Определение-целевого-параметра" data-toc-modified-id="Определение-целевого-параметра-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Определение целевого параметра</a></span></li></ul></li><li><span><a href="#Вычисление-эффективности-обогащения" data-toc-modified-id="Вычисление-эффективности-обогащения-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Вычисление эффективности обогащения</a></span></li><li><span><a href="#Анализ-признаков,-недоступных-в-тестовой-выборке" data-toc-modified-id="Анализ-признаков,-недоступных-в-тестовой-выборке-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Анализ признаков, недоступных в тестовой выборке</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Определение-пропусков" data-toc-modified-id="Определение-пропусков-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Определение пропусков</a></span></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Изменение типов данных</a></span></li><li><span><a href="#Устранение-неявных-дубликатов" data-toc-modified-id="Устранение-неявных-дубликатов-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Устранение неявных дубликатов</a></span></li><li><span><a href="#Определение-и-устранение-аномальных-значений" data-toc-modified-id="Определение-и-устранение-аномальных-значений-2.4.4"><span class="toc-item-num">2.4.4&nbsp;&nbsp;</span>Определение и устранение аномальных значений</a></span></li><li><span><a href="#Добавление-новых-столбцов-????" data-toc-modified-id="Добавление-новых-столбцов-????-2.4.5"><span class="toc-item-num">2.4.5&nbsp;&nbsp;</span>Добавление новых столбцов ????</a></span></li></ul></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изменение-концентрации-металлов" data-toc-modified-id="Изменение-концентрации-металлов-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Изменение концентрации металлов</a></span></li><li><span><a href="#Сравнение-распределения-гранул-сырья-на-выборках" data-toc-modified-id="Сравнение-распределения-гранул-сырья-на-выборках-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Сравнение распределения гранул сырья на выборках</a></span></li><li><span><a href="#Исследование-суммарной-концентрации-веществ" data-toc-modified-id="Исследование-суммарной-концентрации-веществ-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Исследование суммарной концентрации веществ</a></span></li></ul></li><li><span><a href="#Построение-модели" data-toc-modified-id="Построение-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Построение модели</a></span><ul class="toc-item"><li><span><a href="#Создание-функции-для-вычисления-итоговой-sMAPE" data-toc-modified-id="Создание-функции-для-вычисления-итоговой-sMAPE-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Создание функции для вычисления итоговой sMAPE</a></span></li><li><span><a href="#Обучение-разных-моделей" data-toc-modified-id="Обучение-разных-моделей-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Обучение разных моделей</a></span></li><li><span><a href="#Оценка-качества-моделей-кросс-валидацией" data-toc-modified-id="Оценка-качества-моделей-кросс-валидацией-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Оценка качества моделей кросс-валидацией</a></span></li><li><span><a href="#Проверка-выбранной-модели-на-тестовой-выборке" data-toc-modified-id="Проверка-выбранной-модели-на-тестовой-выборке-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Проверка выбранной модели на тестовой выборке</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для компании `Цифра`. Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# Данные находятся в трёх файлах:
#
# - [gold_recovery_train_new.csv](https://code.s3.yandex.net/datasets/gold_recovery_train_new.csv) — обучающая выборка;
# - [gold_recovery_test_new.csv](https://code.s3.yandex.net/datasets/gold_recovery_test_new.csv) — тестовая выборка;
# - [gold_recovery_full_new.csv](https://code.s3.yandex.net/datasets/gold_recovery_full_new.csv) — исходные данные.
#
# Данные индексируются датой и временем получения информации (признак `date`). Соседние по времени параметры часто похожи.
#
# Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков.
#
# Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.
#
# В вашем распоряжении сырые данные: их просто выгрузили из хранилища. Прежде чем приступить к построению модели, проверьте по нашей инструкции их на корректность.
#
# Исходя из описания технологического процесса восстановления золота из руды, необходимо спрогнозировать две величины:
# - `rougher.output.recovery` - эффективность обогащения чернового концентрата,
# - `final.output.recovery` - эффективность обогащения финального концентрата.

# %% [markdown]
# # Подготовка данных

# %% [markdown]
# ## Изучение общей информации
# ### Импорт библиотек

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt

#import requests
#from io import BytesIO
#import random
#import warnings
#from sklearn.linear_model import LogisticRegression
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.ensemble import RandomForestClassifier
#from sklearn.model_selection import train_test_split
#from joblib import dump
#from sklearn.metrics import accuracy_score
#import seaborn as sns
#import plotly.graph_objs as go
#from tqdm import tqdm
#from sklearn.dummy import DummyClassifier

# %% [markdown]
# ### Открытие датасета
# Ввиду того, что у нас представлены три отдельных датасета (обучающий, тестовый и полный с исходными данными), выполним открытие каждого из датасетов по отдельности и посмотрим инфо по типам данных, сделав первоначальный анализ имеющегося материала. Затем
#
#
# _Данные индексируются датой и временем получения информации (признак date). Соседние по времени параметры часто похожи._
#
# _Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков._
#
# _Исходный датасет содержит обучающую и тестовую выборки со всеми признаками._
#
# _В вашем распоряжении сырые данные: их просто выгрузили из хранилища. Прежде чем приступить к построению модели, проверьте по нашей инструкции их на корректность._

# %% [markdown]
# #### Обучающая выборка

# %%
url_train = 'https://code.s3.yandex.net/datasets/gold_recovery_train_new.csv'
data_train = pd.read_csv(url_train)
pd.set_option('display.max_columns', None)
data_train.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# 2                    42.657501              68.116445             10.507046
# 3                    42.689819              68.347543             10.422762
# 4                    42.774141              66.927016             10.360302
#
#    final.output.tail_pb  final.output.tail_sol  final.output.tail_au  \
# 0              0.895447              16.904297              2.143149
# 1              0.927452              16.634514              2.224930
# 2              0.953716              16.208849              2.257889
# 3              0.883763              16.532835              2.146849
# 4              0.792826              16.525686              2.055292
#
#    primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# 0                     127.092003                         10.128295
# 1                     125.629232                         10.296251
# 2                     123.819808                         11.316280
# 3                     122.270188                         11.322140
# 4                     117.988169                         11.913613
#
#    primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  \
# 0                             7.25                        0.988759
# 1                             7.25                        1.002663
# 2                             7.25                        0.991265
# 3                             7.25                        0.996739
# 4                             7.25                        1.009869
#
#    primary_cleaner.output.concentrate_ag  \
# 0                               8.547551
# 1                               8.558743
# 2                               8.603505
# 3                               7.221879
# 4                               9.089428
#
#    primary_cleaner.output.concentrate_pb  \
# 0                              10.389648
# 1                              10.497069
# 2                              10.354494
# 3                               8.496563
# 4                               9.986786
#
#    primary_cleaner.output.concentrate_sol  \
# 0                               19.529297
# 1                               19.369147
# 2                               19.167579
# 3                               15.978538
# 4                               19.199864
#
#    primary_cleaner.output.concentrate_au  primary_cleaner.output.tail_ag  \
# 0                              34.174427                       14.936526
# 1                              34.118526                       16.250511
# 2                              33.969464                       16.491823
# 3                              28.260743                       16.024359
# 4                              33.044932                       16.480185
#
#    primary_cleaner.output.tail_pb  primary_cleaner.output.tail_sol  \
# 0                        2.534912                         7.476074
# 1                        3.049646                         6.733907
# 2                        3.124664                         6.471768
# 3                        2.960362                         6.843791
# 4                        3.112100                         6.550154
#
#    primary_cleaner.output.tail_au  primary_cleaner.state.floatbank8_a_air  \
# 0                        2.106679                             1549.775757
# 1                        2.353017                             1576.166671
# 2                        2.416800                             1601.556163
# 3                        2.262051                             1599.968720
# 4                        2.277073                             1601.339707
#
#    primary_cleaner.state.floatbank8_a_level  \
# 0                               -498.912140
# 1                               -500.904965
# 2                               -499.997791
# 3                               -500.951778
# 4                               -498.975456
#
#    primary_cleaner.state.floatbank8_b_air  \
# 0                             1551.434204
# 1                             1575.950626
# 2                             1600.386685
# 3                             1600.659236
# 4                             1601.437854
#
#    primary_cleaner.state.floatbank8_b_level  \
# 0                               -516.403442
# 1                               -499.865889
# 2                               -500.607762
# 3                               -499.677094
# 4                               -500.323246
#
#    primary_cleaner.state.floatbank8_c_air  \
# 0                             1549.873901
# 1                             1575.994189
# 2                             1602.003542
# 3                             1600.304144
# 4                             1599.581894
#
#    primary_cleaner.state.floatbank8_c_level  \
# 0                               -498.666595
# 1                               -499.315107
# 2                               -500.870069
# 3                               -500.727997
# 4                               -500.888152
#
#    primary_cleaner.state.floatbank8_d_air  \
# 0                             1554.367432
# 1                             1574.479259
# 2                             1599.541515
# 3                             1600.449520
# 4                             1602.649541
#
#    primary_cleaner.state.floatbank8_d_level  \
# 0                               -493.428131
# 1                               -498.931665
# 2                               -499.827444
# 3                               -500.052575
# 4                               -500.593010
#
#    rougher.calculation.sulfate_to_au_concentrate  \
# 0                                   41885.707031
# 1                                   42050.861809
# 2                                   42018.101184
# 3                                   42029.447991
# 4                                   42125.354245
#
#    rougher.calculation.floatbank10_sulfate_to_au_feed  \
# 0                                        3481.779053
# 1                                        3498.370979
# 2                                        3495.348910
# 3                                        3498.578313
# 4                                        3494.800771
#
#    rougher.calculation.floatbank11_sulfate_to_au_feed  \
# 0                                        3520.337158
# 1                                        3489.981857
# 2                                        3502.359819
# 3                                        3499.162912
# 4                                        3506.679315
#
#    rougher.calculation.au_pb_ratio  rougher.input.feed_ag  \
# 0                         2.838687               6.100378
# 1                         2.858998               6.161113
# 2                         2.945989               6.116455
# 3                         3.002340               6.043309
# 4                         3.169615               6.060915
#
#    rougher.input.feed_pb  rougher.input.feed_rate  rougher.input.feed_size  \
# 0               2.284912               523.546326                55.486599
# 1               2.266033               525.290581                57.278666
# 2               2.159622               530.026610                57.510649
# 3               2.037807               542.590390                57.792734
# 4               1.786875               540.531893                56.047189
#
#    rougher.input.feed_sol  rougher.input.feed_au  \
# 0               36.808594               6.486150
# 1               35.753385               6.478583
# 2               35.971630               6.362222
# 3               36.862241               6.118189
# 4               34.347666               5.663707
#
#    rougher.input.floatbank10_sulfate  rougher.input.floatbank10_xanthate  \
# 0                          11.986616                            6.007990
# 1                          11.971193                            6.005766
# 2                          11.920603                            6.197377
# 3                          11.630094                            6.203177
# 4                          10.957755                            6.198826
#
#    rougher.input.floatbank11_sulfate  rougher.input.floatbank11_xanthate  \
# 0                          11.836743                            6.005818
# 1                          11.996163                            6.012594
# 2                          11.920305                            6.204633
# 3                          11.692450                            6.196578
# 4                          10.960521                            6.194897
#
#    rougher.output.concentrate_ag  rougher.output.concentrate_pb  \
# 0                      11.500771                       7.101074
# 1                      11.615865                       7.278807
# 2                      11.695753                       7.216833
# 3                      11.915047                       7.175616
# 4                      12.411054                       7.240205
#
#    rougher.output.concentrate_sol  rougher.output.concentrate_au  \
# 0                       28.029297                      19.793808
# 1                       28.067063                      20.050975
# 2                       27.454037                      19.737170
# 3                       27.341277                      19.320810
# 4                       27.041023                      19.216101
#
#    rougher.output.recovery  rougher.output.tail_ag  rougher.output.tail_pb  \
# 0                87.107763                5.008018                0.508728
# 1                86.843261                4.955378                0.536689
# 2                86.842308                4.843460                0.546416
# 3                87.226430                4.655288                0.542525
# 4                86.688794                4.552800                0.515438
#
#    rougher.output.tail_sol  rougher.output.tail_au  \
# 0                19.154297                1.170244
# 1                18.965234                1.184827
# 2                18.808533                1.162562
# 3                19.330200                1.079755
# 4                19.267422                1.012642
#
#    rougher.state.floatbank10_a_air  rougher.state.floatbank10_a_level  \
# 0                       999.706909                        -404.066986
# 1                      1000.286398                        -400.065196
# 2                       999.719565                        -400.074028
# 3                       999.814770                        -400.200179
# 4                       999.678690                        -399.752729
#
#    rougher.state.floatbank10_b_air  rougher.state.floatbank10_b_level  \
# 0                      1603.011353                        -434.715027
# 1                      1600.754587                        -449.953435
# 2                      1599.337330                        -450.008530
# 3                      1600.059442                        -450.619948
# 4                      1600.208824                        -449.599614
#
#    rougher.state.floatbank10_c_air  rougher.state.floatbank10_c_level  \
# 0                      1602.375000                        -442.204468
# 1                      1600.479580                        -449.830646
# 2                      1599.672797                        -449.954491
# 3                      1600.012842                        -449.910497
# 4                      1600.357732                        -450.034364
#
#    rougher.state.floatbank10_d_air  rougher.state.floatbank10_d_level  \
# 0                      1598.937256                        -451.294128
# 1                      1600.527589                        -449.953649
# 2                      1599.849325                        -449.954185
# 3                      1597.725177                        -450.130127
# 4                      1599.759049                        -449.909799
#
#    rougher.state.floatbank10_e_air  rougher.state.floatbank10_e_level  \
# 0                      1404.472046                        -455.462982
# 1                      1399.227084                        -450.869848
# 2                      1399.180945                        -449.937588
# 3                      1400.943157                        -450.030142
# 4                      1401.560902                        -448.877187
#
#    rougher.state.floatbank10_f_air  rougher.state.floatbank10_f_level  \
# 0                      1416.354980                        -451.939636
# 1                      1399.719514                        -450.119001
# 2                      1400.316682                        -450.527147
# 3                      1400.234743                        -449.790835
# 4                      1401.160227                        -450.407128
#
#    secondary_cleaner.output.tail_ag  secondary_cleaner.output.tail_pb  \
# 0                         14.500184                          4.694824
# 1                         14.265474                          4.592547
# 2                         14.115662                          4.624775
# 3                         13.732071                          4.482453
# 4                         14.079996                          4.470737
#
#    secondary_cleaner.output.tail_sol  secondary_cleaner.output.tail_au  \
# 0                           8.764648                          2.606185
# 1                           9.001494                          2.488248
# 2                           8.842896                          2.458187
# 3                           9.122857                          2.322062
# 4                           8.871028                          2.330448
#
#    secondary_cleaner.state.floatbank2_a_air  \
# 0                                 25.853109
# 1                                 25.880539
# 2                                 26.005245
# 3                                 25.942508
# 4                                 26.024787
#
#    secondary_cleaner.state.floatbank2_a_level  \
# 0                                 -498.526489
# 1                                 -499.989656
# 2                                 -499.929616
# 3                                 -499.176749
# 4                                 -500.279091
#
#    secondary_cleaner.state.floatbank2_b_air  \
# 0                                 23.893660
# 1                                 23.889530
# 2                                 23.886657
# 3                                 23.955516
# 4                                 23.955345
#
#    secondary_cleaner.state.floatbank2_b_level  \
# 0                                 -501.406281
# 1                                 -500.372428
# 2                                 -499.951928
# 3                                 -499.848796
# 4                                 -500.593614
#
#    secondary_cleaner.state.floatbank3_a_air  \
# 0                                 23.961798
# 1                                 23.970550
# 2                                 23.913535
# 3                                 23.966838
# 4                                 23.985703
#
#    secondary_cleaner.state.floatbank3_a_level  \
# 0                                 -495.262817
# 1                                 -500.085473
# 2                                 -499.442343
# 3                                 -500.008812
# 4                                 -500.083811
#
#    secondary_cleaner.state.floatbank3_b_air  \
# 0                                 21.940409
# 1                                 22.085714
# 2                                 23.957717
# 3                                 23.954443
# 4                                 23.958945
#
#    secondary_cleaner.state.floatbank3_b_level  \
# 0                                 -499.340973
# 1                                 -499.446897
# 2                                 -499.901982
# 3                                 -499.944710
# 4                                 -499.990309
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 14.016835
# 1                                 13.992281
# 2                                 14.015015
# 3                                 14.036510
# 4                                 14.027298
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -502.488007
# 1                                 -505.503262
# 2                                 -502.520901
# 3                                 -500.857308
# 4                                 -499.838632
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                 12.099931
# 1                                 11.950531
# 2                                 11.912783
# 3                                 11.999550
# 4                                 11.953070
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -504.715942
# 1                                 -501.331529
# 2                                 -501.133383
# 3                                 -501.193686
# 4                                 -501.053894
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                  9.925633
# 1                                 10.039245
# 2                                 10.070913
# 3                                  9.970366
# 4                                  9.925709
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -498.310211
# 1                                 -500.169983
# 2                                 -500.129135
# 3                                 -499.201640
# 4                                 -501.686727
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                  8.079666
# 1                                  7.984757
# 2                                  8.013877
# 3                                  7.977324
# 4                                  7.894242
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.470978
# 1                                 -500.582168
# 2                                 -500.517572
# 3                                 -500.255908
# 4                                 -500.356035
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 14.151341
# 1                                 13.998353
# 2                                 14.028663
# 3                                 14.005551
# 4                                 13.996647
#
#    secondary_cleaner.state.floatbank6_a_level
# 0                                 -605.841980
# 1                                 -599.787184
# 2                                 -601.427363
# 3                                 -599.996129
# 4                                 -601.496691

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
#  8   final.output.tail_sol                               14144 non-null  float64
#  9   final.output.tail_au                                14149 non-null  float64
#  10  primary_cleaner.input.sulfate                       14129 non-null  float64
#  11  primary_cleaner.input.depressant                    14117 non-null  float64
#  12  primary_cleaner.input.feed_size                     14149 non-null  float64
#  13  primary_cleaner.input.xanthate                      14049 non-null  float64
#  14  primary_cleaner.output.concentrate_ag               14149 non-null  float64
#  15  primary_cleaner.output.concentrate_pb               14063 non-null  float64
#  16  primary_cleaner.output.concentrate_sol              13863 non-null  float64
#  17  primary_cleaner.output.concentrate_au               14149 non-null  float64
#  18  primary_cleaner.output.tail_ag                      14148 non-null  float64
#  19  primary_cleaner.output.tail_pb                      14134 non-null  float64
#  20  primary_cleaner.output.tail_sol                     14103 non-null  float64
#  21  primary_cleaner.output.tail_au                      14149 non-null  float64
#  22  primary_cleaner.state.floatbank8_a_air              14145 non-null  float64
#  23  primary_cleaner.state.floatbank8_a_level            14148 non-null  float64
#  24  primary_cleaner.state.floatbank8_b_air              14145 non-null  float64
#  25  primary_cleaner.state.floatbank8_b_level            14148 non-null  float64
#  26  primary_cleaner.state.floatbank8_c_air              14147 non-null  float64
#  27  primary_cleaner.state.floatbank8_c_level            14148 non-null  float64
#  28  primary_cleaner.state.floatbank8_d_air              14146 non-null  float64
#  29  primary_cleaner.state.floatbank8_d_level            14148 non-null  float64
#  30  rougher.calculation.sulfate_to_au_concentrate       14148 non-null  float64
#  31  rougher.calculation.floatbank10_sulfate_to_au_feed  14148 non-null  float64
#  32  rougher.calculation.floatbank11_sulfate_to_au_feed  14148 non-null  float64
#  33  rougher.calculation.au_pb_ratio                     14149 non-null  float64
#  34  rougher.input.feed_ag                               14149 non-null  float64
#  35  rougher.input.feed_pb                               14049 non-null  float64
#  36  rougher.input.feed_rate                             14141 non-null  float64
#  37  rougher.input.feed_size                             14005 non-null  float64
#  38  rougher.input.feed_sol                              14071 non-null  float64
#  39  rougher.input.feed_au                               14149 non-null  float64
#  40  rougher.input.floatbank10_sulfate                   14120 non-null  float64
#  41  rougher.input.floatbank10_xanthate                  14141 non-null  float64
#  42  rougher.input.floatbank11_sulfate                   14113 non-null  float64
#  43  rougher.input.floatbank11_xanthate                  13721 non-null  float64
#  44  rougher.output.concentrate_ag                       14149 non-null  float64
#  45  rougher.output.concentrate_pb                       14149 non-null  float64
#  46  rougher.output.concentrate_sol                      14127 non-null  float64
#  47  rougher.output.concentrate_au                       14149 non-null  float64
#  48  rougher.output.recovery                             14149 non-null  float64
#  49  rougher.output.tail_ag                              14148 non-null  float64
#  50  rougher.output.tail_pb                              14149 non-null  float64
#  51  rougher.output.tail_sol                             14149 non-null  float64
#  52  rougher.output.tail_au                              14149 non-null  float64
#  53  rougher.state.floatbank10_a_air                     14148 non-null  float64
#  54  rougher.state.floatbank10_a_level                   14148 non-null  float64
#  55  rougher.state.floatbank10_b_air                     14148 non-null  float64
#  56  rougher.state.floatbank10_b_level                   14148 non-null  float64
#  57  rougher.state.floatbank10_c_air                     14148 non-null  float64
#  58  rougher.state.floatbank10_c_level                   14148 non-null  float64
#  59  rougher.state.floatbank10_d_air                     14149 non-null  float64
#  60  rougher.state.floatbank10_d_level                   14149 non-null  float64
#  61  rougher.state.floatbank10_e_air                     13713 non-null  float64
#  62  rougher.state.floatbank10_e_level                   14149 non-null  float64
#  63  rougher.state.floatbank10_f_air                     14149 non-null  float64
#  64  rougher.state.floatbank10_f_level                   14149 non-null  float64
#  65  secondary_cleaner.output.tail_ag                    14147 non-null  float64
#  66  secondary_cleaner.output.tail_pb                    14139 non-null  float64
#  67  secondary_cleaner.output.tail_sol                   12544 non-null  float64
#  68  secondary_cleaner.output.tail_au                    14149 non-null  float64
#  69  secondary_cleaner.state.floatbank2_a_air            13932 non-null  float64
#  70  secondary_cleaner.state.floatbank2_a_level          14148 non-null  float64
#  71  secondary_cleaner.state.floatbank2_b_air            14128 non-null  float64
#  72  secondary_cleaner.state.floatbank2_b_level          14148 non-null  float64
#  73  secondary_cleaner.state.floatbank3_a_air            14145 non-null  float64
#  74  secondary_cleaner.state.floatbank3_a_level          14148 non-null  float64
#  75  secondary_cleaner.state.floatbank3_b_air            14148 non-null  float64
#  76  secondary_cleaner.state.floatbank3_b_level          14148 non-null  float64
#  77  secondary_cleaner.state.floatbank4_a_air            14143 non-null  float64
#  78  secondary_cleaner.state.floatbank4_a_level          14148 non-null  float64
#  79  secondary_cleaner.state.floatbank4_b_air            14148 non-null  float64
#  80  secondary_cleaner.state.floatbank4_b_level          14148 non-null  float64
#  81  secondary_cleaner.state.floatbank5_a_air            14148 non-null  float64
#  82  secondary_cleaner.state.floatbank5_a_level          14148 non-null  float64
#  83  secondary_cleaner.state.floatbank5_b_air            14148 non-null  float64
#  84  secondary_cleaner.state.floatbank5_b_level          14148 non-null  float64
#  85  secondary_cleaner.state.floatbank6_a_air            14147 non-null  float64
#  86  secondary_cleaner.state.floatbank6_a_level          14148 non-null  float64
# dtypes: float64(86), object(1)
# memory usage: 9.4+ MB

# %% [markdown]
# #### Тестовая выборка

# %%
url_test = 'https://code.s3.yandex.net/datasets/gold_recovery_test_new.csv'
data_test = pd.read_csv(url_test)
data_test.head()
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# 1                        0.990469                             1398.777912
# 2                        0.996043                             1398.493666
# 3                        0.863514                             1399.618111
# 4                        0.805575                             1401.268123
#
#    primary_cleaner.state.floatbank8_a_level  \
# 0                               -500.225577
# 1                               -500.057435
# 2                               -500.868360
# 3                               -498.863574
# 4                               -500.808305
#
#    primary_cleaner.state.floatbank8_b_air  \
# 0                             1399.144926
# 1                             1398.055362
# 2                             1398.860436
# 3                             1397.440120
# 4                             1398.128818
#
#    primary_cleaner.state.floatbank8_b_level  \
# 0                               -499.919735
# 1                               -499.778182
# 2                               -499.764529
# 3                               -499.211024
# 4                               -499.504543
#
#    primary_cleaner.state.floatbank8_c_air  \
# 0                             1400.102998
# 1                             1396.151033
# 2                             1398.075709
# 3                             1400.129303
# 4                             1402.172226
#
#    primary_cleaner.state.floatbank8_c_level  \
# 0                               -500.704369
# 1                               -499.240168
# 2                               -502.151509
# 3                               -498.355873
# 4                               -500.810606
#
#    primary_cleaner.state.floatbank8_d_air  \
# 0                             1399.001695
# 1                             1399.508091
# 2                             1399.497088
# 3                             1401.065165
# 4                             1399.480508
#
#    primary_cleaner.state.floatbank8_d_level  rougher.input.feed_ag  \
# 0                               -499.485144              13.128569
# 1                               -500.416324              13.036280
# 2                               -499.715479              13.138412
# 3                               -501.038738              12.400507
# 4                               -499.374053              11.327427
#
#    rougher.input.feed_pb  rougher.input.feed_rate  rougher.input.feed_size  \
# 0               5.636710               489.793655                62.710452
# 1               5.526065               490.104534                61.961163
# 2               5.426561               489.617969                66.903807
# 3               5.114758               476.618130                59.865919
# 4               4.767383               488.248117                63.315324
#
#    rougher.input.feed_sol  rougher.input.feed_au  \
# 0               42.022440              12.084103
# 1               41.187903              11.918977
# 2               42.546294              12.091332
# 3               41.060195              12.181597
# 4               41.269161              11.290425
#
#    rougher.input.floatbank10_sulfate  rougher.input.floatbank10_xanthate  \
# 0                          16.922877                            6.153479
# 1                          17.002532                            5.999043
# 2                          16.992520                            5.850632
# 3                          16.532144                            5.801935
# 4                          13.607257                            5.738081
#
#    rougher.input.floatbank11_sulfate  rougher.input.floatbank11_xanthate  \
# 0                          16.867518                            6.150709
# 1                          16.996063                            6.002315
# 2                          16.982096                            5.853594
# 3                          16.515277                            5.803657
# 4                          13.650053                            5.739634
#
#    rougher.state.floatbank10_a_air  rougher.state.floatbank10_a_level  \
# 0                      1001.849317                        -350.301265
# 1                       998.690785                        -350.425704
# 2                       998.516720                        -349.783538
# 3                      1000.276604                        -350.172597
# 4                       996.541302                        -350.562517
#
#    rougher.state.floatbank10_b_air  rougher.state.floatbank10_b_level  \
# 0                      1249.738612                        -399.107531
# 1                      1248.395457                        -399.946025
# 2                      1247.440748                        -400.264330
# 3                      1251.322675                        -398.655289
# 4                      1304.658848                        -399.511519
#
#    rougher.state.floatbank10_c_air  rougher.state.floatbank10_c_level  \
# 0                      1249.750520                        -399.396730
# 1                      1249.514451                        -399.630810
# 2                      1248.207204                        -401.074405
# 3                      1250.493702                        -399.746728
# 4                      1306.455515                        -399.050685
#
#    rougher.state.floatbank10_d_air  rougher.state.floatbank10_d_level  \
# 0                      1198.287855                        -399.488594
# 1                      1200.506459                        -399.942434
# 2                      1199.770026                        -400.790582
# 3                      1199.398691                        -397.503052
# 4                      1248.699349                        -400.876894
#
#    rougher.state.floatbank10_e_air  rougher.state.floatbank10_e_level  \
# 0                       999.472250                        -399.530962
# 1                      1000.002114                        -399.491528
# 2                       999.925519                        -399.236999
# 3                      1001.930679                        -400.437573
# 4                      1058.839106                        -398.988239
#
#    rougher.state.floatbank10_f_air  rougher.state.floatbank10_f_level  \
# 0                       949.566189                        -398.180807
# 1                       950.200009                        -405.787514
# 2                       950.320481                        -400.864340
# 3                       950.735324                        -399.802986
# 4                       949.645313                        -399.277632
#
#    secondary_cleaner.state.floatbank2_a_air  \
# 0                                 24.938200
# 1                                 24.923466
# 2                                 24.908732
# 3                                 24.893998
# 4                                 24.886905
#
#    secondary_cleaner.state.floatbank2_a_level  \
# 0                                 -500.490963
# 1                                 -499.813963
# 2                                 -500.304035
# 3                                 -499.382374
# 4                                 -499.357375
#
#    secondary_cleaner.state.floatbank2_b_air  \
# 0                                 14.947607
# 1                                 14.930873
# 2                                 14.996511
# 3                                 14.916674
# 4                                 14.979233
#
#    secondary_cleaner.state.floatbank2_b_level  \
# 0                                 -500.013837
# 1                                 -500.764452
# 2                                 -500.993821
# 3                                 -499.862299
# 4                                 -500.186804
#
#    secondary_cleaner.state.floatbank3_a_air  \
# 0                                 20.018166
# 1                                 19.988503
# 2                                 20.039689
# 3                                 20.031100
# 4                                 19.962364
#
#    secondary_cleaner.state.floatbank3_a_level  \
# 0                                 -450.395995
# 1                                 -450.114024
# 2                                 -450.263164
# 3                                 -449.372570
# 4                                 -450.638828
#
#    secondary_cleaner.state.floatbank3_b_air  \
# 0                                 13.987058
# 1                                 14.092981
# 2                                 14.077881
# 3                                 14.013968
# 4                                 14.009245
#
#    secondary_cleaner.state.floatbank3_b_level  \
# 0                                 -449.831513
# 1                                 -450.059163
# 2                                 -449.660997
# 3                                 -449.526900
# 4                                 -450.022259
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 12.023554
# 1                                 12.058140
# 2                                 11.962366
# 3                                 12.033091
# 4                                 12.025367
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -497.795834
# 1                                 -498.695773
# 2                                 -498.767484
# 3                                 -498.350935
# 4                                 -500.786497
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                  8.016656
# 1                                  8.130979
# 2                                  8.096893
# 3                                  8.074946
# 4                                  8.054678
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -501.289139
# 1                                 -499.634209
# 2                                 -500.827423
# 3                                 -499.474407
# 4                                 -500.397500
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                  7.946562
# 1                                  7.958270
# 2                                  8.071056
# 3                                  7.897085
# 4                                  8.107890
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -432.317850
# 1                                 -525.839648
# 2                                 -500.801673
# 3                                 -500.868509
# 4                                 -509.526725
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                  4.872511
# 1                                  4.878850
# 2                                  4.905125
# 3                                  4.931400
# 4                                  4.957674
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.037437
# 1                                 -500.162375
# 2                                 -499.828510
# 3                                 -499.963623
# 4                                 -500.360026
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 26.705889
# 1                                 25.019940
# 2                                 24.994862
# 3                                 24.948919
# 4                                 25.003331
#
#    secondary_cleaner.state.floatbank6_a_level
# 0                                 -499.709414
# 1                                 -499.819438
# 2                                 -500.622559
# 3                                 -498.709987
# 4                                 -500.856333

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5286 non-null   float64
#  2   primary_cleaner.input.depressant            5285 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5286 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
#  9   primary_cleaner.state.floatbank8_c_air      5290 non-null   float64
#  10  primary_cleaner.state.floatbank8_c_level    5290 non-null   float64
#  11  primary_cleaner.state.floatbank8_d_air      5290 non-null   float64
#  12  primary_cleaner.state.floatbank8_d_level    5290 non-null   float64
#  13  rougher.input.feed_ag                       5290 non-null   float64
#  14  rougher.input.feed_pb                       5290 non-null   float64
#  15  rougher.input.feed_rate                     5287 non-null   float64
#  16  rougher.input.feed_size                     5289 non-null   float64
#  17  rougher.input.feed_sol                      5269 non-null   float64
#  18  rougher.input.feed_au                       5290 non-null   float64
#  19  rougher.input.floatbank10_sulfate           5285 non-null   float64
#  20  rougher.input.floatbank10_xanthate          5290 non-null   float64
#  21  rougher.input.floatbank11_sulfate           5282 non-null   float64
#  22  rougher.input.floatbank11_xanthate          5265 non-null   float64
#  23  rougher.state.floatbank10_a_air             5290 non-null   float64
#  24  rougher.state.floatbank10_a_level           5290 non-null   float64
#  25  rougher.state.floatbank10_b_air             5290 non-null   float64
#  26  rougher.state.floatbank10_b_level           5290 non-null   float64
#  27  rougher.state.floatbank10_c_air             5290 non-null   float64
#  28  rougher.state.floatbank10_c_level           5290 non-null   float64
#  29  rougher.state.floatbank10_d_air             5290 non-null   float64
#  30  rougher.state.floatbank10_d_level           5290 non-null   float64
#  31  rougher.state.floatbank10_e_air             5290 non-null   float64
#  32  rougher.state.floatbank10_e_level           5290 non-null   float64
#  33  rougher.state.floatbank10_f_air             5290 non-null   float64
#  34  rougher.state.floatbank10_f_level           5290 non-null   float64
#  35  secondary_cleaner.state.floatbank2_a_air    5287 non-null   float64
#  36  secondary_cleaner.state.floatbank2_a_level  5290 non-null   float64
#  37  secondary_cleaner.state.floatbank2_b_air    5288 non-null   float64
#  38  secondary_cleaner.state.floatbank2_b_level  5290 non-null   float64
#  39  secondary_cleaner.state.floatbank3_a_air    5281 non-null   float64
#  40  secondary_cleaner.state.floatbank3_a_level  5290 non-null   float64
#  41  secondary_cleaner.state.floatbank3_b_air    5290 non-null   float64
#  42  secondary_cleaner.state.floatbank3_b_level  5290 non-null   float64
#  43  secondary_cleaner.state.floatbank4_a_air    5290 non-null   float64
#  44  secondary_cleaner.state.floatbank4_a_level  5290 non-null   float64
#  45  secondary_cleaner.state.floatbank4_b_air    5290 non-null   float64
#  46  secondary_cleaner.state.floatbank4_b_level  5290 non-null   float64
#  47  secondary_cleaner.state.floatbank5_a_air    5290 non-null   float64
#  48  secondary_cleaner.state.floatbank5_a_level  5290 non-null   float64
#  49  secondary_cleaner.state.floatbank5_b_air    5290 non-null   float64
#  50  secondary_cleaner.state.floatbank5_b_level  5290 non-null   float64
#  51  secondary_cleaner.state.floatbank6_a_air    5290 non-null   float64
#  52  secondary_cleaner.state.floatbank6_a_level  5290 non-null   float64
# dtypes: float64(52), object(1)
# memory usage: 2.1+ MB

# %% [markdown]
# #### Исходная выборка

# %%
url_init = 'https://code.s3.yandex.net/datasets/gold_recovery_full_new.csv'
data_init = pd.read_csv(url_init)
data_init.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# 2                    42.657501              68.116445             10.507046
# 3                    42.689819              68.347543             10.422762
# 4                    42.774141              66.927016             10.360302
#
#    final.output.tail_pb  final.output.tail_sol  final.output.tail_au  \
# 0              0.895447              16.904297              2.143149
# 1              0.927452              16.634514              2.224930
# 2              0.953716              16.208849              2.257889
# 3              0.883763              16.532835              2.146849
# 4              0.792826              16.525686              2.055292
#
#    primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# 0                     127.092003                         10.128295
# 1                     125.629232                         10.296251
# 2                     123.819808                         11.316280
# 3                     122.270188                         11.322140
# 4                     117.988169                         11.913613
#
#    primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  \
# 0                             7.25                        0.988759
# 1                             7.25                        1.002663
# 2                             7.25                        0.991265
# 3                             7.25                        0.996739
# 4                             7.25                        1.009869
#
#    primary_cleaner.output.concentrate_ag  \
# 0                               8.547551
# 1                               8.558743
# 2                               8.603505
# 3                               7.221879
# 4                               9.089428
#
#    primary_cleaner.output.concentrate_pb  \
# 0                              10.389648
# 1                              10.497069
# 2                              10.354494
# 3                               8.496563
# 4                               9.986786
#
#    primary_cleaner.output.concentrate_sol  \
# 0                               19.529297
# 1                               19.369147
# 2                               19.167579
# 3                               15.978538
# 4                               19.199864
#
#    primary_cleaner.output.concentrate_au  primary_cleaner.output.tail_ag  \
# 0                              34.174427                       14.936526
# 1                              34.118526                       16.250511
# 2                              33.969464                       16.491823
# 3                              28.260743                       16.024359
# 4                              33.044932                       16.480185
#
#    primary_cleaner.output.tail_pb  primary_cleaner.output.tail_sol  \
# 0                        2.534912                         7.476074
# 1                        3.049646                         6.733907
# 2                        3.124664                         6.471768
# 3                        2.960362                         6.843791
# 4                        3.112100                         6.550154
#
#    primary_cleaner.output.tail_au  primary_cleaner.state.floatbank8_a_air  \
# 0                        2.106679                             1549.775757
# 1                        2.353017                             1576.166671
# 2                        2.416800                             1601.556163
# 3                        2.262051                             1599.968720
# 4                        2.277073                             1601.339707
#
#    primary_cleaner.state.floatbank8_a_level  \
# 0                               -498.912140
# 1                               -500.904965
# 2                               -499.997791
# 3                               -500.951778
# 4                               -498.975456
#
#    primary_cleaner.state.floatbank8_b_air  \
# 0                             1551.434204
# 1                             1575.950626
# 2                             1600.386685
# 3                             1600.659236
# 4                             1601.437854
#
#    primary_cleaner.state.floatbank8_b_level  \
# 0                               -516.403442
# 1                               -499.865889
# 2                               -500.607762
# 3                               -499.677094
# 4                               -500.323246
#
#    primary_cleaner.state.floatbank8_c_air  \
# 0                             1549.873901
# 1                             1575.994189
# 2                             1602.003542
# 3                             1600.304144
# 4                             1599.581894
#
#    primary_cleaner.state.floatbank8_c_level  \
# 0                               -498.666595
# 1                               -499.315107
# 2                               -500.870069
# 3                               -500.727997
# 4                               -500.888152
#
#    primary_cleaner.state.floatbank8_d_air  \
# 0                             1554.367432
# 1                             1574.479259
# 2                             1599.541515
# 3                             1600.449520
# 4                             1602.649541
#
#    primary_cleaner.state.floatbank8_d_level  \
# 0                               -493.428131
# 1                               -498.931665
# 2                               -499.827444
# 3                               -500.052575
# 4                               -500.593010
#
#    rougher.calculation.sulfate_to_au_concentrate  \
# 0                                   41885.707031
# 1                                   42050.861809
# 2                                   42018.101184
# 3                                   42029.447991
# 4                                   42125.354245
#
#    rougher.calculation.floatbank10_sulfate_to_au_feed  \
# 0                                        3481.779053
# 1                                        3498.370979
# 2                                        3495.348910
# 3                                        3498.578313
# 4                                        3494.800771
#
#    rougher.calculation.floatbank11_sulfate_to_au_feed  \
# 0                                        3520.337158
# 1                                        3489.981857
# 2                                        3502.359819
# 3                                        3499.162912
# 4                                        3506.679315
#
#    rougher.calculation.au_pb_ratio  rougher.input.feed_ag  \
# 0                         2.838687               6.100378
# 1                         2.858998               6.161113
# 2                         2.945989               6.116455
# 3                         3.002340               6.043309
# 4                         3.169615               6.060915
#
#    rougher.input.feed_pb  rougher.input.feed_rate  rougher.input.feed_size  \
# 0               2.284912               523.546326                55.486599
# 1               2.266033               525.290581                57.278666
# 2               2.159622               530.026610                57.510649
# 3               2.037807               542.590390                57.792734
# 4               1.786875               540.531893                56.047189
#
#    rougher.input.feed_sol  rougher.input.feed_au  \
# 0               36.808594               6.486150
# 1               35.753385               6.478583
# 2               35.971630               6.362222
# 3               36.862241               6.118189
# 4               34.347666               5.663707
#
#    rougher.input.floatbank10_sulfate  rougher.input.floatbank10_xanthate  \
# 0                          11.986616                            6.007990
# 1                          11.971193                            6.005766
# 2                          11.920603                            6.197377
# 3                          11.630094                            6.203177
# 4                          10.957755                            6.198826
#
#    rougher.input.floatbank11_sulfate  rougher.input.floatbank11_xanthate  \
# 0                          11.836743                            6.005818
# 1                          11.996163                            6.012594
# 2                          11.920305                            6.204633
# 3                          11.692450                            6.196578
# 4                          10.960521                            6.194897
#
#    rougher.output.concentrate_ag  rougher.output.concentrate_pb  \
# 0                      11.500771                       7.101074
# 1                      11.615865                       7.278807
# 2                      11.695753                       7.216833
# 3                      11.915047                       7.175616
# 4                      12.411054                       7.240205
#
#    rougher.output.concentrate_sol  rougher.output.concentrate_au  \
# 0                       28.029297                      19.793808
# 1                       28.067063                      20.050975
# 2                       27.454037                      19.737170
# 3                       27.341277                      19.320810
# 4                       27.041023                      19.216101
#
#    rougher.output.recovery  rougher.output.tail_ag  rougher.output.tail_pb  \
# 0                87.107763                5.008018                0.508728
# 1                86.843261                4.955378                0.536689
# 2                86.842308                4.843460                0.546416
# 3                87.226430                4.655288                0.542525
# 4                86.688794                4.552800                0.515438
#
#    rougher.output.tail_sol  rougher.output.tail_au  \
# 0                19.154297                1.170244
# 1                18.965234                1.184827
# 2                18.808533                1.162562
# 3                19.330200                1.079755
# 4                19.267422                1.012642
#
#    rougher.state.floatbank10_a_air  rougher.state.floatbank10_a_level  \
# 0                       999.706909                        -404.066986
# 1                      1000.286398                        -400.065196
# 2                       999.719565                        -400.074028
# 3                       999.814770                        -400.200179
# 4                       999.678690                        -399.752729
#
#    rougher.state.floatbank10_b_air  rougher.state.floatbank10_b_level  \
# 0                      1603.011353                        -434.715027
# 1                      1600.754587                        -449.953435
# 2                      1599.337330                        -450.008530
# 3                      1600.059442                        -450.619948
# 4                      1600.208824                        -449.599614
#
#    rougher.state.floatbank10_c_air  rougher.state.floatbank10_c_level  \
# 0                      1602.375000                        -442.204468
# 1                      1600.479580                        -449.830646
# 2                      1599.672797                        -449.954491
# 3                      1600.012842                        -449.910497
# 4                      1600.357732                        -450.034364
#
#    rougher.state.floatbank10_d_air  rougher.state.floatbank10_d_level  \
# 0                      1598.937256                        -451.294128
# 1                      1600.527589                        -449.953649
# 2                      1599.849325                        -449.954185
# 3                      1597.725177                        -450.130127
# 4                      1599.759049                        -449.909799
#
#    rougher.state.floatbank10_e_air  rougher.state.floatbank10_e_level  \
# 0                      1404.472046                        -455.462982
# 1                      1399.227084                        -450.869848
# 2                      1399.180945                        -449.937588
# 3                      1400.943157                        -450.030142
# 4                      1401.560902                        -448.877187
#
#    rougher.state.floatbank10_f_air  rougher.state.floatbank10_f_level  \
# 0                      1416.354980                        -451.939636
# 1                      1399.719514                        -450.119001
# 2                      1400.316682                        -450.527147
# 3                      1400.234743                        -449.790835
# 4                      1401.160227                        -450.407128
#
#    secondary_cleaner.output.tail_ag  secondary_cleaner.output.tail_pb  \
# 0                         14.500184                          4.694824
# 1                         14.265474                          4.592547
# 2                         14.115662                          4.624775
# 3                         13.732071                          4.482453
# 4                         14.079996                          4.470737
#
#    secondary_cleaner.output.tail_sol  secondary_cleaner.output.tail_au  \
# 0                           8.764648                          2.606185
# 1                           9.001494                          2.488248
# 2                           8.842896                          2.458187
# 3                           9.122857                          2.322062
# 4                           8.871028                          2.330448
#
#    secondary_cleaner.state.floatbank2_a_air  \
# 0                                 25.853109
# 1                                 25.880539
# 2                                 26.005245
# 3                                 25.942508
# 4                                 26.024787
#
#    secondary_cleaner.state.floatbank2_a_level  \
# 0                                 -498.526489
# 1                                 -499.989656
# 2                                 -499.929616
# 3                                 -499.176749
# 4                                 -500.279091
#
#    secondary_cleaner.state.floatbank2_b_air  \
# 0                                 23.893660
# 1                                 23.889530
# 2                                 23.886657
# 3                                 23.955516
# 4                                 23.955345
#
#    secondary_cleaner.state.floatbank2_b_level  \
# 0                                 -501.406281
# 1                                 -500.372428
# 2                                 -499.951928
# 3                                 -499.848796
# 4                                 -500.593614
#
#    secondary_cleaner.state.floatbank3_a_air  \
# 0                                 23.961798
# 1                                 23.970550
# 2                                 23.913535
# 3                                 23.966838
# 4                                 23.985703
#
#    secondary_cleaner.state.floatbank3_a_level  \
# 0                                 -495.262817
# 1                                 -500.085473
# 2                                 -499.442343
# 3                                 -500.008812
# 4                                 -500.083811
#
#    secondary_cleaner.state.floatbank3_b_air  \
# 0                                 21.940409
# 1                                 22.085714
# 2                                 23.957717
# 3                                 23.954443
# 4                                 23.958945
#
#    secondary_cleaner.state.floatbank3_b_level  \
# 0                                 -499.340973
# 1                                 -499.446897
# 2                                 -499.901982
# 3                                 -499.944710
# 4                                 -499.990309
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 14.016835
# 1                                 13.992281
# 2                                 14.015015
# 3                                 14.036510
# 4                                 14.027298
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -502.488007
# 1                                 -505.503262
# 2                                 -502.520901
# 3                                 -500.857308
# 4                                 -499.838632
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                 12.099931
# 1                                 11.950531
# 2                                 11.912783
# 3                                 11.999550
# 4                                 11.953070
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -504.715942
# 1                                 -501.331529
# 2                                 -501.133383
# 3                                 -501.193686
# 4                                 -501.053894
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                  9.925633
# 1                                 10.039245
# 2                                 10.070913
# 3                                  9.970366
# 4                                  9.925709
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -498.310211
# 1                                 -500.169983
# 2                                 -500.129135
# 3                                 -499.201640
# 4                                 -501.686727
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                  8.079666
# 1                                  7.984757
# 2                                  8.013877
# 3                                  7.977324
# 4                                  7.894242
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.470978
# 1                                 -500.582168
# 2                                 -500.517572
# 3                                 -500.255908
# 4                                 -500.356035
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 14.151341
# 1                                 13.998353
# 2                                 14.028663
# 3                                 14.005551
# 4                                 13.996647
#
#    secondary_cleaner.state.floatbank6_a_level
# 0                                 -605.841980
# 1                                 -599.787184
# 2                                 -601.427363
# 3                                 -599.996129
# 4                                 -601.496691

# %%
data_init.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
#  8   final.output.tail_sol                               19433 non-null  float64
#  9   final.output.tail_au                                19439 non-null  float64
#  10  primary_cleaner.input.sulfate                       19415 non-null  float64
#  11  primary_cleaner.input.depressant                    19402 non-null  float64
#  12  primary_cleaner.input.feed_size                     19439 non-null  float64
#  13  primary_cleaner.input.xanthate                      19335 non-null  float64
#  14  primary_cleaner.output.concentrate_ag               19439 non-null  float64
#  15  primary_cleaner.output.concentrate_pb               19323 non-null  float64
#  16  primary_cleaner.output.concentrate_sol              19069 non-null  float64
#  17  primary_cleaner.output.concentrate_au               19439 non-null  float64
#  18  primary_cleaner.output.tail_ag                      19435 non-null  float64
#  19  primary_cleaner.output.tail_pb                      19418 non-null  float64
#  20  primary_cleaner.output.tail_sol                     19377 non-null  float64
#  21  primary_cleaner.output.tail_au                      19439 non-null  float64
#  22  primary_cleaner.state.floatbank8_a_air              19435 non-null  float64
#  23  primary_cleaner.state.floatbank8_a_level            19438 non-null  float64
#  24  primary_cleaner.state.floatbank8_b_air              19435 non-null  float64
#  25  primary_cleaner.state.floatbank8_b_level            19438 non-null  float64
#  26  primary_cleaner.state.floatbank8_c_air              19437 non-null  float64
#  27  primary_cleaner.state.floatbank8_c_level            19438 non-null  float64
#  28  primary_cleaner.state.floatbank8_d_air              19436 non-null  float64
#  29  primary_cleaner.state.floatbank8_d_level            19438 non-null  float64
#  30  rougher.calculation.sulfate_to_au_concentrate       19437 non-null  float64
#  31  rougher.calculation.floatbank10_sulfate_to_au_feed  19437 non-null  float64
#  32  rougher.calculation.floatbank11_sulfate_to_au_feed  19437 non-null  float64
#  33  rougher.calculation.au_pb_ratio                     19439 non-null  float64
#  34  rougher.input.feed_ag                               19439 non-null  float64
#  35  rougher.input.feed_pb                               19339 non-null  float64
#  36  rougher.input.feed_rate                             19428 non-null  float64
#  37  rougher.input.feed_size                             19294 non-null  float64
#  38  rougher.input.feed_sol                              19340 non-null  float64
#  39  rougher.input.feed_au                               19439 non-null  float64
#  40  rougher.input.floatbank10_sulfate                   19405 non-null  float64
#  41  rougher.input.floatbank10_xanthate                  19431 non-null  float64
#  42  rougher.input.floatbank11_sulfate                   19395 non-null  float64
#  43  rougher.input.floatbank11_xanthate                  18986 non-null  float64
#  44  rougher.output.concentrate_ag                       19439 non-null  float64
#  45  rougher.output.concentrate_pb                       19439 non-null  float64
#  46  rougher.output.concentrate_sol                      19416 non-null  float64
#  47  rougher.output.concentrate_au                       19439 non-null  float64
#  48  rougher.output.recovery                             19439 non-null  float64
#  49  rougher.output.tail_ag                              19438 non-null  float64
#  50  rougher.output.tail_pb                              19439 non-null  float64
#  51  rougher.output.tail_sol                             19439 non-null  float64
#  52  rougher.output.tail_au                              19439 non-null  float64
#  53  rougher.state.floatbank10_a_air                     19438 non-null  float64
#  54  rougher.state.floatbank10_a_level                   19438 non-null  float64
#  55  rougher.state.floatbank10_b_air                     19438 non-null  float64
#  56  rougher.state.floatbank10_b_level                   19438 non-null  float64
#  57  rougher.state.floatbank10_c_air                     19438 non-null  float64
#  58  rougher.state.floatbank10_c_level                   19438 non-null  float64
#  59  rougher.state.floatbank10_d_air                     19439 non-null  float64
#  60  rougher.state.floatbank10_d_level                   19439 non-null  float64
#  61  rougher.state.floatbank10_e_air                     19003 non-null  float64
#  62  rougher.state.floatbank10_e_level                   19439 non-null  float64
#  63  rougher.state.floatbank10_f_air                     19439 non-null  float64
#  64  rougher.state.floatbank10_f_level                   19439 non-null  float64
#  65  secondary_cleaner.output.tail_ag                    19437 non-null  float64
#  66  secondary_cleaner.output.tail_pb                    19427 non-null  float64
#  67  secondary_cleaner.output.tail_sol                   17691 non-null  float64
#  68  secondary_cleaner.output.tail_au                    19439 non-null  float64
#  69  secondary_cleaner.state.floatbank2_a_air            19219 non-null  float64
#  70  secondary_cleaner.state.floatbank2_a_level          19438 non-null  float64
#  71  secondary_cleaner.state.floatbank2_b_air            19416 non-null  float64
#  72  secondary_cleaner.state.floatbank2_b_level          19438 non-null  float64
#  73  secondary_cleaner.state.floatbank3_a_air            19426 non-null  float64
#  74  secondary_cleaner.state.floatbank3_a_level          19438 non-null  float64
#  75  secondary_cleaner.state.floatbank3_b_air            19438 non-null  float64
#  76  secondary_cleaner.state.floatbank3_b_level          19438 non-null  float64
#  77  secondary_cleaner.state.floatbank4_a_air            19433 non-null  float64
#  78  secondary_cleaner.state.floatbank4_a_level          19438 non-null  float64
#  79  secondary_cleaner.state.floatbank4_b_air            19438 non-null  float64
#  80  secondary_cleaner.state.floatbank4_b_level          19438 non-null  float64
#  81  secondary_cleaner.state.floatbank5_a_air            19438 non-null  float64
#  82  secondary_cleaner.state.floatbank5_a_level          19438 non-null  float64
#  83  secondary_cleaner.state.floatbank5_b_air            19438 non-null  float64
#  84  secondary_cleaner.state.floatbank5_b_level          19438 non-null  float64
#  85  secondary_cleaner.state.floatbank6_a_air            19437 non-null  float64
#  86  secondary_cleaner.state.floatbank6_a_level          19438 non-null  float64
# dtypes: float64(86), object(1)
# memory usage: 12.9+ MB

# %% [markdown]
# ## Вычисление эффективности обогащения
# На обучающей выборке для признака `rougher.output.recovery` выполняем проверку, насколько правильно рассчитана эффективности обогащения чернового концентрата.
#
# В расчёте эффективности обогащения чернового концентрата используются следующие значения:
# - `rougher.output.concentrate_au` - доля золота в концентрате после флотации/очистки
# - `rougher.input.feed_au` - доля золота в сырье/концентрате до флотации/очистки
# - `rougher.output.tail_au` - доля золота в отвальных хвостах после флотации/очистки

# %%
# Вычисление эффективности обогащения
recovery_calculated = ((data_train['rougher.output.concentrate_au'] * (data_train['rougher.input.feed_au'] - data_train['rougher.output.tail_au'])) / 
                       (data_train['rougher.input.feed_au'] * (data_train['rougher.output.concentrate_au'] - data_train['rougher.output.tail_au']))) * 100

# %% [markdown]
# Покажем `MAE` между расчётами и значением признака эффективности обогащения.

# %%
# Вычисление средней абсолютной ошибки (MAE)
mean_absolute_error(data_train['rougher.output.recovery'], recovery_calculated)
# Out:
# 9.73512347450521e-15

# %% [markdown]
# Значение средней абсолютной ошибки `MAE` очень близка к нулю (_9.73512347450521e-15_). Это предполагает точность выполненных расчётов эффективности обогащения. Таким образом, можно с уверенностью сказать, что эффективность обогащения золота была рассчитана правильно на обучающей выборке.

# %% [markdown]
# ## Подготовка тестовой выборки
# ### Анализ признаков, недоступных в тестовой выборке
# Проанализируем признаки, недоступные в тестовой выборке.
#
# <font color='red'><strong>Что это за параметры? К какому типу относятся?</strong></font>

# %%
set(data_init.columns) - set(data_test.columns) # параметры, отсутствующие в тестовой выборке
# Out:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
#  'rougher.output.tail_ag',
#  'rougher.output.tail_au',
#  'rougher.output.tail_pb',
#  'rougher.output.tail_sol',
#  'secondary_cleaner.output.tail_ag',
#  'secondary_cleaner.output.tail_au',
#  'secondary_cleaner.output.tail_pb',
#  'secondary_cleaner.output.tail_sol'}

# %% [markdown]
# В тестовой выборке отсутствуют следующие группы параметров:
# - содержащие описание финальных характеристик (блок _этап_ в тестовой выборке не содержит `final`) продукта (тип параметра `output`)
# - доля сырья после первичной очистки (этап `primary_cleaner` для типа параметра `output`)
# - доля в сырье/концентрате после флотации/очистки (параметр продукта (т.е. ПОСЛЕ того, как сырьё прошло этап очистки) `output` для этапа флотации `rougher`)
# - расчётные характеристики (тип параметра `calculation`) для флотации
# - доля продукта (тип параметра `output`) в отвальных хвостах (техпроцесс `tail`) после вторичной очистки (этап `secondary_cleaner`)
#
# Таким образом в тестовой выборке отсутствуют все параметры, относящиеся к типам `output` и `calculation`, т.е. всё относящееся к данным после обработки (когда из сырья получен продукт) и расчётные характеристики (расчётные характеристики в исходных данных представлены только для этапа флотации).
#
# Также наблюдаем подтверждение догадки об отсутствии в тестовой выборке двух целевых признаков, `rougher.output.recovery` и `final.output.recovery`, прогнозы по которым необходимо будет построить.

# %% [markdown]
# ### Дополнение тестовой выборки целевыми признаками
# Тестовую выборку необходимо дополнить двумя целевыми признаками, которые необходимо брать из исходного датасета

# %%
data_test_tar = data_test.merge(
    data_init[['rougher.output.recovery', 'final.output.recovery']], 
    left_index=True, 
    right_index=True, 
    how='left'
                                      )

data_test_tar.head()
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# 1                        0.990469                             1398.777912
# 2                        0.996043                             1398.493666
# 3                        0.863514                             1399.618111
# 4                        0.805575                             1401.268123
#
#    primary_cleaner.state.floatbank8_a_level  \
# 0                               -500.225577
# 1                               -500.057435
# 2                               -500.868360
# 3                               -498.863574
# 4                               -500.808305
#
#    primary_cleaner.state.floatbank8_b_air  \
# 0                             1399.144926
# 1                             1398.055362
# 2                             1398.860436
# 3                             1397.440120
# 4                             1398.128818
#
#    primary_cleaner.state.floatbank8_b_level  \
# 0                               -499.919735
# 1                               -499.778182
# 2                               -499.764529
# 3                               -499.211024
# 4                               -499.504543
#
#    primary_cleaner.state.floatbank8_c_air  \
# 0                             1400.102998
# 1                             1396.151033
# 2                             1398.075709
# 3                             1400.129303
# 4                             1402.172226
#
#    primary_cleaner.state.floatbank8_c_level  \
# 0                               -500.704369
# 1                               -499.240168
# 2                               -502.151509
# 3                               -498.355873
# 4                               -500.810606
#
#    primary_cleaner.state.floatbank8_d_air  \
# 0                             1399.001695
# 1                             1399.508091
# 2                             1399.497088
# 3                             1401.065165
# 4                             1399.480508
#
#    primary_cleaner.state.floatbank8_d_level  rougher.input.feed_ag  \
# 0                               -499.485144              13.128569
# 1                               -500.416324              13.036280
# 2                               -499.715479              13.138412
# 3                               -501.038738              12.400507
# 4                               -499.374053              11.327427
#
#    rougher.input.feed_pb  rougher.input.feed_rate  rougher.input.feed_size  \
# 0               5.636710               489.793655                62.710452
# 1               5.526065               490.104534                61.961163
# 2               5.426561               489.617969                66.903807
# 3               5.114758               476.618130                59.865919
# 4               4.767383               488.248117                63.315324
#
#    rougher.input.feed_sol  rougher.input.feed_au  \
# 0               42.022440              12.084103
# 1               41.187903              11.918977
# 2               42.546294              12.091332
# 3               41.060195              12.181597
# 4               41.269161              11.290425
#
#    rougher.input.floatbank10_sulfate  rougher.input.floatbank10_xanthate  \
# 0                          16.922877                            6.153479
# 1                          17.002532                            5.999043
# 2                          16.992520                            5.850632
# 3                          16.532144                            5.801935
# 4                          13.607257                            5.738081
#
#    rougher.input.floatbank11_sulfate  rougher.input.floatbank11_xanthate  \
# 0                          16.867518                            6.150709
# 1                          16.996063                            6.002315
# 2                          16.982096                            5.853594
# 3                          16.515277                            5.803657
# 4                          13.650053                            5.739634
#
#    rougher.state.floatbank10_a_air  rougher.state.floatbank10_a_level  \
# 0                      1001.849317                        -350.301265
# 1                       998.690785                        -350.425704
# 2                       998.516720                        -349.783538
# 3                      1000.276604                        -350.172597
# 4                       996.541302                        -350.562517
#
#    rougher.state.floatbank10_b_air  rougher.state.floatbank10_b_level  \
# 0                      1249.738612                        -399.107531
# 1                      1248.395457                        -399.946025
# 2                      1247.440748                        -400.264330
# 3                      1251.322675                        -398.655289
# 4                      1304.658848                        -399.511519
#
#    rougher.state.floatbank10_c_air  rougher.state.floatbank10_c_level  \
# 0                      1249.750520                        -399.396730
# 1                      1249.514451                        -399.630810
# 2                      1248.207204                        -401.074405
# 3                      1250.493702                        -399.746728
# 4                      1306.455515                        -399.050685
#
#    rougher.state.floatbank10_d_air  rougher.state.floatbank10_d_level  \
# 0                      1198.287855                        -399.488594
# 1                      1200.506459                        -399.942434
# 2                      1199.770026                        -400.790582
# 3                      1199.398691                        -397.503052
# 4                      1248.699349                        -400.876894
#
#    rougher.state.floatbank10_e_air  rougher.state.floatbank10_e_level  \
# 0                       999.472250                        -399.530962
# 1                      1000.002114                        -399.491528
# 2                       999.925519                        -399.236999
# 3                      1001.930679                        -400.437573
# 4                      1058.839106                        -398.988239
#
#    rougher.state.floatbank10_f_air  rougher.state.floatbank10_f_level  \
# 0                       949.566189                        -398.180807
# 1                       950.200009                        -405.787514
# 2                       950.320481                        -400.864340
# 3                       950.735324                        -399.802986
# 4                       949.645313                        -399.277632
#
#    secondary_cleaner.state.floatbank2_a_air  \
# 0                                 24.938200
# 1                                 24.923466
# 2                                 24.908732
# 3                                 24.893998
# 4                                 24.886905
#
#    secondary_cleaner.state.floatbank2_a_level  \
# 0                                 -500.490963
# 1                                 -499.813963
# 2                                 -500.304035
# 3                                 -499.382374
# 4                                 -499.357375
#
#    secondary_cleaner.state.floatbank2_b_air  \
# 0                                 14.947607
# 1                                 14.930873
# 2                                 14.996511
# 3                                 14.916674
# 4                                 14.979233
#
#    secondary_cleaner.state.floatbank2_b_level  \
# 0                                 -500.013837
# 1                                 -500.764452
# 2                                 -500.993821
# 3                                 -499.862299
# 4                                 -500.186804
#
#    secondary_cleaner.state.floatbank3_a_air  \
# 0                                 20.018166
# 1                                 19.988503
# 2                                 20.039689
# 3                                 20.031100
# 4                                 19.962364
#
#    secondary_cleaner.state.floatbank3_a_level  \
# 0                                 -450.395995
# 1                                 -450.114024
# 2                                 -450.263164
# 3                                 -449.372570
# 4                                 -450.638828
#
#    secondary_cleaner.state.floatbank3_b_air  \
# 0                                 13.987058
# 1                                 14.092981
# 2                                 14.077881
# 3                                 14.013968
# 4                                 14.009245
#
#    secondary_cleaner.state.floatbank3_b_level  \
# 0                                 -449.831513
# 1                                 -450.059163
# 2                                 -449.660997
# 3                                 -449.526900
# 4                                 -450.022259
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 12.023554
# 1                                 12.058140
# 2                                 11.962366
# 3                                 12.033091
# 4                                 12.025367
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -497.795834
# 1                                 -498.695773
# 2                                 -498.767484
# 3                                 -498.350935
# 4                                 -500.786497
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                  8.016656
# 1                                  8.130979
# 2                                  8.096893
# 3                                  8.074946
# 4                                  8.054678
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -501.289139
# 1                                 -499.634209
# 2                                 -500.827423
# 3                                 -499.474407
# 4                                 -500.397500
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                  7.946562
# 1                                  7.958270
# 2                                  8.071056
# 3                                  7.897085
# 4                                  8.107890
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -432.317850
# 1                                 -525.839648
# 2                                 -500.801673
# 3                                 -500.868509
# 4                                 -509.526725
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                  4.872511
# 1                                  4.878850
# 2                                  4.905125
# 3                                  4.931400
# 4                                  4.957674
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.037437
# 1                                 -500.162375
# 2                                 -499.828510
# 3                                 -499.963623
# 4                                 -500.360026
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 26.705889
# 1                                 25.019940
# 2                                 24.994862
# 3                                 24.948919
# 4                                 25.003331
#
#    secondary_cleaner.state.floatbank6_a_level  rougher.output.recovery  \
# 0                                 -499.709414                87.107763
# 1                                 -499.819438                86.843261
# 2                                 -500.622559                86.842308
# 3                                 -498.709987                87.226430
# 4                                 -500.856333                86.688794
#
#    final.output.recovery
# 0              70.541216
# 1              69.266198
# 2              68.116445
# 3              68.347543
# 4              66.927016

# %%
data_test_tar.shape
# Out:
# (5290, 55)

# %% [markdown]
# В тестовой выборке фигурирует 55 признаков и более 5К строк.

# %% [markdown]
# ## Предобработка данных
# Предобработку данных будем делать для обучающей выборки <font color='red'><strong>и возможно для тестовой</strong></font>.

# %% [markdown]
# ### Определение и устранение аномальных значений
# <font color='red'><strong>и возможно для тестовой аномалиями для удаления считал только 0% и 100% концентрации. Смотрел по гистограмме. Хотя boxplot также просили построить. По итогу осталось больше 95% данных</strong></font>
#
# Построим диаграмму `ящик с усами` для каждого из признаков, входящих в обучающую выборку. Нам это даст возможность визуально оценить, значения каких параметров можно отнести к выбросам и избавиться от них, сделав, тем самым, очистку данных.

# %% [markdown]
# #### Устранение аномальных значений для обучающей выборки

# %%
fig, axes = plt.subplots(nrows=(len(data_train.columns)-1)//7+1, ncols=7, figsize=(20, 45))

for i, column in enumerate(data_train.columns):
    if column != 'date':
        row = i // axes.shape[1]
        col = i % axes.shape[1]
        data_train.boxplot(column=column, ax=axes[row, col])

plt.tight_layout()
plt.show()

# %% [markdown]
# По графикам на обучающей выборке можно сделать заключение о наличии выбросов практически для каждого из параметров.
# Удалим значения 0 и 100 для признаков `rougher.output.recovery` и `final.output.recovery`, а затем посмотрим на иные результаты. Что характерно, для `rougher.output.recovery` 100 не является выбросом, а находится на самой верхней границе диаграммы. Но очевидно, что доля продукта после флотации не может составлять 100%, поэтому от такого значения избавимся. Посмотрим график в более крупном масштабе и примем решение.

# %%
fig, ax = plt.subplots(figsize=(20, 5))

data_train.boxplot(column=['final.output.recovery', 'rougher.output.recovery'], ax=ax, vert=False)
ax.set_title('Обогащение продукта для целевых признаков')
ax.set_xticks(range(0, 101, 4))
plt.show()

# %%
data_train_clr = data_train[(data_train['final.output.recovery'] > 50) & (data_train['final.output.recovery'] < 88)]
data_train_clr = data_train_clr[(data_train_clr['rougher.output.recovery'] > 66) & (data_train_clr['rougher.output.recovery'] != 100)]

# %% [markdown]
# <font color='red'><strong>Теперь устраним для остальных признаков выбивающиеся значения `0`</font></strong>

# %%
for column in data_train_clr.columns:
    data_train_clr = data_train_clr[data_train_clr[column] != 0]

# %% [markdown]
# #### Устранение аномальных значений для тестовой выборки

# %% [markdown]
# Для признаков, входящих в тестовую выборку, построим аналогичный boxplot, а затем на основании его избавимся от выбросов в целевых признаках.

# %%
fig, ax = plt.subplots(figsize=(20, 5))

data_test_tar.boxplot(column=['final.output.recovery', 'rougher.output.recovery'], ax=ax, vert=False)
ax.set_title('Обогащение продукта для целевых признаков')
ax.set_xticks(range(0, 101, 4))
plt.show()

# %%
data_test_tar = data_test_tar[(data_test_tar['final.output.recovery'] > 46) & (data_test_tar['final.output.recovery'] < 84)]
data_test_tar = data_test_tar[(data_test_tar['rougher.output.recovery'] > 60) & (data_test_tar['rougher.output.recovery'] != 100)]

# %% [markdown]
# <font color='red'><strong>Теперь устраним для остальных признаков выбивающиеся значения `0`</font></strong>

# %%
for column in data_test_tar.columns:
    data_test_tar = data_test_tar[data_test_tar[column] != 0]

# %% [markdown]
# ### Определение пропусков
# <font color='red'><strong>Замена NaN на очищенных выборках (train и test). Перебирал разные варианты 0 / bfill / ffill / interpolate - особой разницы не увидел. Но написать какое-то обоснование нужно.</font></strong>
#
# Подсчитаем количество пропусков для признаков в тестовой и обучающей выборках.

# %% [markdown]
# #### Определение пропусков в обучающей выборке

# %%
data_train_clr.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# secondary_cleaner.output.tail_sol           1436
# rougher.state.floatbank10_e_air              345
# secondary_cleaner.state.floatbank2_a_air     175
# primary_cleaner.output.concentrate_sol       149
# final.output.concentrate_sol                 136
# rougher.input.feed_size                      114
# rougher.input.floatbank11_xanthate            91
# final.output.tail_pb                          72
# primary_cleaner.input.xanthate                62
# rougher.input.feed_pb                         60
# dtype: int64

# %%
print(f'Суммарное число пропусков {data_train_clr.isnull().sum().sum()} из {data_train_clr.shape[0]} строк обучающей выборки')
# Out:
# Суммарное число пропусков 2844 из 12138 строк обучающей выборки

# %% [markdown]
# Как видно, процент пропусков велик - почти четверть всех строк. Наибольшее значение пропусков в `secondary_cleaner.output.tail_sol` составляет более 11% от общего числа строк. Этот признак отвечает за `содержание твёрдых частиц в отвальных хвостах после вторичной очистки`. В тестовой выборке этот признак отсутствует, поэтому проверять обученность модели по нему не получится. И в дальнейшем от данного признака мы избавимся на шаге [подготовки обучающей выборки](#Подготовка-обучающей-выборки).
#
# Посему пропуска по данному признаку предлагается удалить, а для остальных признаков заполним пропущенные значения на основе ближайших известных значений. Тем самым результат будет "более плавным", основываясь на соседних известных точках. Использование _bfill/ffill_ может привести к заполнению пропусков в ряде случаев значениями, выходящими за границы верхней и нижней границ. А мы как раз от этого избавлялись.

# %%
data_train_clr.dropna(subset=['secondary_cleaner.output.tail_sol'], inplace=True)
data_train_clr.interpolate(method='linear', inplace=True)

# %%
print(f'После очистки от пропусков и выбросов в обучающей выборке осталось {data_train_clr.shape[0]} строк и {data_train_clr.shape[1]} признаков')
# Out:
# После очистки от пропусков и выбросов в обучающей выборке осталось 10702 строк и 87 признаков

# %% [markdown]
# #### Определение пропусков в тестовой выборке

# %%
data_test_tar.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# rougher.input.floatbank11_xanthate          22
# rougher.input.feed_sol                      19
# secondary_cleaner.state.floatbank3_a_air     9
# rougher.input.floatbank11_sulfate            7
# primary_cleaner.input.depressant             4
# rougher.input.floatbank10_sulfate            4
# primary_cleaner.input.xanthate               3
# secondary_cleaner.state.floatbank2_a_air     3
# rougher.input.feed_rate                      3
# primary_cleaner.input.sulfate                3
# dtype: int64

# %%
print(f'Суммарное число пропусков {data_test_tar.isnull().sum().sum()} из {data_test_tar.shape[0]} строк тестовой выборки')
# Out:
# Суммарное число пропусков 80 из 4936 строк тестовой выборки

# %% [markdown]
# Число пропусков крайне мало по сравнению с общим числом строк и составляет суммарно менее 2%. Поэтому имеет смысл попросту удалить из датасета.

# %%
data_test_tar.dropna(inplace=True)

# %%
print(f'После очистки от пропусков и выбросов в тестовой выборке осталось {data_test_tar.shape[0]} строк и {data_test_tar.shape[1]} признаков')
# Out:
# После очистки от пропусков и выбросов в тестовой выборке осталось 4881 строк и 55 признаков

# %% [markdown]
# ### Устранение неявных дубликатов
# <font color='red'><strong>Нужно ли???</font></strong>

# %% [markdown]
# ### Подсчёт корреляции
# Выполним проверку на мультиколлинеарность для обучающей и тестовой выборок. В результате получим матрицу корреляций между всеми столбцами (признаками) датасетов. Если есть сильная корреляция между какими-то столбцами, то это может указывать на мультиколлинеарность. В таком случае можно рассмотреть возможность удаления одного из коррелирующих столбцов.

# %%
pd.set_option('display.max_rows', None)
correlation_matrix_train = data_train_clr.drop('date', axis=1).corr()
correlation_matrix_train
# Out:
#                                                     final.output.concentrate_ag  \
# final.output.concentrate_ag                                            1.000000
# final.output.concentrate_pb                                           -0.135305
# final.output.concentrate_sol                                           0.270998
# final.output.concentrate_au                                           -0.418340
# final.output.recovery                                                  0.176545
# final.output.tail_ag                                                   0.332796
# final.output.tail_pb                                                  -0.107178
# final.output.tail_sol                                                 -0.021244
# final.output.tail_au                                                   0.172840
# primary_cleaner.input.sulfate                                          0.010675
# primary_cleaner.input.depressant                                       0.138698
# primary_cleaner.input.feed_size                                        0.015049
# primary_cleaner.input.xanthate                                         0.190296
# primary_cleaner.output.concentrate_ag                                  0.525459
# primary_cleaner.output.concentrate_pb                                 -0.169598
# primary_cleaner.output.concentrate_sol                                 0.318266
# primary_cleaner.output.concentrate_au                                 -0.238818
# primary_cleaner.output.tail_ag                                         0.041355
# primary_cleaner.output.tail_pb                                        -0.019746
# primary_cleaner.output.tail_sol                                        0.126983
# primary_cleaner.output.tail_au                                         0.156613
# primary_cleaner.state.floatbank8_a_air                                 0.191894
# primary_cleaner.state.floatbank8_a_level                               0.050549
# primary_cleaner.state.floatbank8_b_air                                 0.207002
# primary_cleaner.state.floatbank8_b_level                               0.049648
# primary_cleaner.state.floatbank8_c_air                                 0.169539
# primary_cleaner.state.floatbank8_c_level                               0.040769
# primary_cleaner.state.floatbank8_d_air                                 0.110516
# primary_cleaner.state.floatbank8_d_level                              -0.007332
# rougher.calculation.sulfate_to_au_concentrate                         -0.020174
# rougher.calculation.floatbank10_sulfate_to_au_feed                    -0.137490
# rougher.calculation.floatbank11_sulfate_to_au_feed                    -0.231444
# rougher.calculation.au_pb_ratio                                        0.179207
# rougher.input.feed_ag                                                  0.436979
# rougher.input.feed_pb                                                  0.028324
# rougher.input.feed_rate                                               -0.198894
# rougher.input.feed_size                                                0.000740
# rougher.input.feed_sol                                                -0.078534
# rougher.input.feed_au                                                  0.294139
# rougher.input.floatbank10_sulfate                                     -0.192019
# rougher.input.floatbank10_xanthate                                     0.112379
# rougher.input.floatbank11_sulfate                                     -0.212027
# rougher.input.floatbank11_xanthate                                     0.069901
# rougher.output.concentrate_ag                                          0.402686
# rougher.output.concentrate_pb                                         -0.218529
# rougher.output.concentrate_sol                                        -0.085270
# rougher.output.concentrate_au                                         -0.007160
# rougher.output.recovery                                                0.149976
# rougher.output.tail_ag                                                 0.177955
# rougher.output.tail_pb                                                -0.107612
# rougher.output.tail_sol                                                0.006164
# rougher.output.tail_au                                                 0.090790
# rougher.state.floatbank10_a_air                                        0.130968
# rougher.state.floatbank10_a_level                                     -0.175994
# rougher.state.floatbank10_b_air                                        0.078274
# rougher.state.floatbank10_b_level                                      0.063682
# rougher.state.floatbank10_c_air                                        0.063440
# rougher.state.floatbank10_c_level                                      0.069268
# rougher.state.floatbank10_d_air                                        0.090991
# rougher.state.floatbank10_d_level                                      0.064511
# rougher.state.floatbank10_e_air                                        0.142431
# rougher.state.floatbank10_e_level                                      0.083826
# rougher.state.floatbank10_f_air                                        0.117274
# rougher.state.floatbank10_f_level                                      0.078600
# secondary_cleaner.output.tail_ag                                      -0.097263
# secondary_cleaner.output.tail_pb                                      -0.298835
# secondary_cleaner.output.tail_sol                                      0.148801
# secondary_cleaner.output.tail_au                                       0.021136
# secondary_cleaner.state.floatbank2_a_air                              -0.059311
# secondary_cleaner.state.floatbank2_a_level                             0.026803
# secondary_cleaner.state.floatbank2_b_air                              -0.031526
# secondary_cleaner.state.floatbank2_b_level                             0.030821
# secondary_cleaner.state.floatbank3_a_air                               0.078475
# secondary_cleaner.state.floatbank3_a_level                             0.186741
# secondary_cleaner.state.floatbank3_b_air                               0.024606
# secondary_cleaner.state.floatbank3_b_level                             0.224959
# secondary_cleaner.state.floatbank4_a_air                               0.099344
# secondary_cleaner.state.floatbank4_a_level                             0.178396
# secondary_cleaner.state.floatbank4_b_air                               0.054127
# secondary_cleaner.state.floatbank4_b_level                            -0.023216
# secondary_cleaner.state.floatbank5_a_air                               0.039669
# secondary_cleaner.state.floatbank5_a_level                             0.247548
# secondary_cleaner.state.floatbank5_b_air                               0.035127
# secondary_cleaner.state.floatbank5_b_level                             0.243622
# secondary_cleaner.state.floatbank6_a_air                               0.182215
# secondary_cleaner.state.floatbank6_a_level                             0.061257
#
#                                                     final.output.concentrate_pb  \
# final.output.concentrate_ag                                           -0.135305
# final.output.concentrate_pb                                            1.000000
# final.output.concentrate_sol                                          -0.116826
# final.output.concentrate_au                                            0.019809
# final.output.recovery                                                 -0.151636
# final.output.tail_ag                                                  -0.201274
# final.output.tail_pb                                                   0.267816
# final.output.tail_sol                                                  0.057075
# final.output.tail_au                                                   0.034292
# primary_cleaner.input.sulfate                                          0.103400
# primary_cleaner.input.depressant                                      -0.018824
# primary_cleaner.input.feed_size                                       -0.085538
# primary_cleaner.input.xanthate                                        -0.218391
# primary_cleaner.output.concentrate_ag                                 -0.085148
# primary_cleaner.output.concentrate_pb                                  0.378963
# primary_cleaner.output.concentrate_sol                                -0.123374
# primary_cleaner.output.concentrate_au                                 -0.041567
# primary_cleaner.output.tail_ag                                        -0.131007
# primary_cleaner.output.tail_pb                                        -0.072109
# primary_cleaner.output.tail_sol                                       -0.052784
# primary_cleaner.output.tail_au                                        -0.174371
# primary_cleaner.state.floatbank8_a_air                                 0.002276
# primary_cleaner.state.floatbank8_a_level                               0.081752
# primary_cleaner.state.floatbank8_b_air                                -0.014301
# primary_cleaner.state.floatbank8_b_level                               0.073397
# primary_cleaner.state.floatbank8_c_air                                 0.009708
# primary_cleaner.state.floatbank8_c_level                               0.076797
# primary_cleaner.state.floatbank8_d_air                                -0.024873
# primary_cleaner.state.floatbank8_d_level                               0.108858
# rougher.calculation.sulfate_to_au_concentrate                          0.017200
# rougher.calculation.floatbank10_sulfate_to_au_feed                     0.080415
# rougher.calculation.floatbank11_sulfate_to_au_feed                     0.151716
# rougher.calculation.au_pb_ratio                                       -0.453125
# rougher.input.feed_ag                                                 -0.235482
# rougher.input.feed_pb                                                  0.355994
# rougher.input.feed_rate                                               -0.026218
# rougher.input.feed_size                                               -0.062878
# rougher.input.feed_sol                                                -0.005590
# rougher.input.feed_au                                                 -0.066074
# rougher.input.floatbank10_sulfate                                      0.120370
# rougher.input.floatbank10_xanthate                                    -0.081187
# rougher.input.floatbank11_sulfate                                      0.140788
# rougher.input.floatbank11_xanthate                                    -0.035916
# rougher.output.concentrate_ag                                         -0.450624
# rougher.output.concentrate_pb                                          0.662212
# rougher.output.concentrate_sol                                        -0.028849
# rougher.output.concentrate_au                                         -0.043230
# rougher.output.recovery                                               -0.076006
# rougher.output.tail_ag                                                -0.092645
# rougher.output.tail_pb                                                 0.223034
# rougher.output.tail_sol                                               -0.276752
# rougher.output.tail_au                                                 0.047415
# rougher.state.floatbank10_a_air                                       -0.039954
# rougher.state.floatbank10_a_level                                      0.088625
# rougher.state.floatbank10_b_air                                        0.130233
# rougher.state.floatbank10_b_level                                      0.027855
# rougher.state.floatbank10_c_air                                        0.141876
# rougher.state.floatbank10_c_level                                      0.019809
# rougher.state.floatbank10_d_air                                        0.122001
# rougher.state.floatbank10_d_level                                      0.017789
# rougher.state.floatbank10_e_air                                        0.105018
# rougher.state.floatbank10_e_level                                      0.014689
# rougher.state.floatbank10_f_air                                        0.159348
# rougher.state.floatbank10_f_level                                      0.012860
# secondary_cleaner.output.tail_ag                                      -0.075724
# secondary_cleaner.output.tail_pb                                       0.214848
# secondary_cleaner.output.tail_sol                                     -0.044685
# secondary_cleaner.output.tail_au                                      -0.119267
# secondary_cleaner.state.floatbank2_a_air                               0.071782
# secondary_cleaner.state.floatbank2_a_level                             0.013952
# secondary_cleaner.state.floatbank2_b_air                               0.118309
# secondary_cleaner.state.floatbank2_b_level                             0.043786
# secondary_cleaner.state.floatbank3_a_air                               0.051052
# secondary_cleaner.state.floatbank3_a_level                            -0.043239
# secondary_cleaner.state.floatbank3_b_air                               0.173868
# secondary_cleaner.state.floatbank3_b_level                            -0.158882
# secondary_cleaner.state.floatbank4_a_air                              -0.022284
# secondary_cleaner.state.floatbank4_a_level                            -0.040644
# secondary_cleaner.state.floatbank4_b_air                               0.115984
# secondary_cleaner.state.floatbank4_b_level                             0.087953
# secondary_cleaner.state.floatbank5_a_air                               0.106725
# secondary_cleaner.state.floatbank5_a_level                            -0.112965
# secondary_cleaner.state.floatbank5_b_air                               0.161459
# secondary_cleaner.state.floatbank5_b_level                            -0.132484
# secondary_cleaner.state.floatbank6_a_air                               0.002481
# secondary_cleaner.state.floatbank6_a_level                             0.067602
#
#                                                     final.output.concentrate_sol  \
# final.output.concentrate_ag                                             0.270998
# final.output.concentrate_pb                                            -0.116826
# final.output.concentrate_sol                                            1.000000
# final.output.concentrate_au                                             0.037102
# final.output.recovery                                                   0.228541
# final.output.tail_ag                                                    0.168969
# final.output.tail_pb                                                    0.314304
# final.output.tail_sol                                                  -0.214004
# final.output.tail_au                                                    0.274240
# primary_cleaner.input.sulfate                                           0.301306
# primary_cleaner.input.depressant                                        0.035006
# primary_cleaner.input.feed_size                                         0.115466
# primary_cleaner.input.xanthate                                          0.036954
# primary_cleaner.output.concentrate_ag                                   0.296833
# primary_cleaner.output.concentrate_pb                                   0.077234
# primary_cleaner.output.concentrate_sol                                  0.123904
# primary_cleaner.output.concentrate_au                                  -0.145113
# primary_cleaner.output.tail_ag                                          0.041156
# primary_cleaner.output.tail_pb                                          0.031241
# primary_cleaner.output.tail_sol                                         0.318097
# primary_cleaner.output.tail_au                                          0.123544
# primary_cleaner.state.floatbank8_a_air                                  0.101241
# primary_cleaner.state.floatbank8_a_level                               -0.233614
# primary_cleaner.state.floatbank8_b_air                                  0.113986
# primary_cleaner.state.floatbank8_b_level                               -0.229505
# primary_cleaner.state.floatbank8_c_air                                  0.086857
# primary_cleaner.state.floatbank8_c_level                               -0.228591
# primary_cleaner.state.floatbank8_d_air                                  0.256583
# primary_cleaner.state.floatbank8_d_level                               -0.200622
# rougher.calculation.sulfate_to_au_concentrate                          -0.022243
# rougher.calculation.floatbank10_sulfate_to_au_feed                     -0.143039
# rougher.calculation.floatbank11_sulfate_to_au_feed                     -0.056892
# rougher.calculation.au_pb_ratio                                         0.045774
# rougher.input.feed_ag                                                   0.413360
# rougher.input.feed_pb                                                   0.265491
# rougher.input.feed_rate                                                -0.185838
# rougher.input.feed_size                                                -0.131817
# rougher.input.feed_sol                                                  0.049498
# rougher.input.feed_au                                                   0.444418
# rougher.input.floatbank10_sulfate                                       0.095746
# rougher.input.floatbank10_xanthate                                     -0.154953
# rougher.input.floatbank11_sulfate                                       0.133288
# rougher.input.floatbank11_xanthate                                     -0.075424
# rougher.output.concentrate_ag                                           0.446766
# rougher.output.concentrate_pb                                          -0.066194
# rougher.output.concentrate_sol                                          0.337815
# rougher.output.concentrate_au                                           0.303659
# rougher.output.recovery                                                 0.260348
# rougher.output.tail_ag                                                  0.282653
# rougher.output.tail_pb                                                 -0.165113
# rougher.output.tail_sol                                                -0.083280
# rougher.output.tail_au                                                  0.064353
# rougher.state.floatbank10_a_air                                         0.139906
# rougher.state.floatbank10_a_level                                      -0.062218
# rougher.state.floatbank10_b_air                                        -0.140710
# rougher.state.floatbank10_b_level                                       0.012839
# rougher.state.floatbank10_c_air                                        -0.110986
# rougher.state.floatbank10_c_level                                       0.020728
# rougher.state.floatbank10_d_air                                        -0.135457
# rougher.state.floatbank10_d_level                                       0.023065
# rougher.state.floatbank10_e_air                                        -0.241972
# rougher.state.floatbank10_e_level                                       0.030201
# rougher.state.floatbank10_f_air                                        -0.230305
# rougher.state.floatbank10_f_level                                       0.029257
# secondary_cleaner.output.tail_ag                                        0.037662
# secondary_cleaner.output.tail_pb                                       -0.254023
# secondary_cleaner.output.tail_sol                                       0.248899
# secondary_cleaner.output.tail_au                                       -0.003583
# secondary_cleaner.state.floatbank2_a_air                                0.031790
# secondary_cleaner.state.floatbank2_a_level                             -0.025677
# secondary_cleaner.state.floatbank2_b_air                               -0.013213
# secondary_cleaner.state.floatbank2_b_level                             -0.006365
# secondary_cleaner.state.floatbank3_a_air                                0.125587
# secondary_cleaner.state.floatbank3_a_level                              0.115196
# secondary_cleaner.state.floatbank3_b_air                               -0.024493
# secondary_cleaner.state.floatbank3_b_level                              0.027968
# secondary_cleaner.state.floatbank4_a_air                                0.107967
# secondary_cleaner.state.floatbank4_a_level                              0.256741
# secondary_cleaner.state.floatbank4_b_air                                0.095342
# secondary_cleaner.state.floatbank4_b_level                              0.124446
# secondary_cleaner.state.floatbank5_a_air                                0.095104
# secondary_cleaner.state.floatbank5_a_level                              0.233006
# secondary_cleaner.state.floatbank5_b_air                                0.062473
# secondary_cleaner.state.floatbank5_b_level                              0.237099
# secondary_cleaner.state.floatbank6_a_air                                0.230264
# secondary_cleaner.state.floatbank6_a_level                             -0.297884
#
#                                                     final.output.concentrate_au  \
# final.output.concentrate_ag                                           -0.418340
# final.output.concentrate_pb                                            0.019809
# final.output.concentrate_sol                                           0.037102
# final.output.concentrate_au                                            1.000000
# final.output.recovery                                                 -0.082683
# final.output.tail_ag                                                  -0.036678
# final.output.tail_pb                                                   0.033919
# final.output.tail_sol                                                  0.025173
# final.output.tail_au                                                  -0.049781
# primary_cleaner.input.sulfate                                          0.014179
# primary_cleaner.input.depressant                                      -0.084511
# primary_cleaner.input.feed_size                                       -0.030721
# primary_cleaner.input.xanthate                                         0.029531
# primary_cleaner.output.concentrate_ag                                 -0.230552
# primary_cleaner.output.concentrate_pb                                  0.059750
# primary_cleaner.output.concentrate_sol                                -0.101193
# primary_cleaner.output.concentrate_au                                  0.250461
# primary_cleaner.output.tail_ag                                         0.155279
# primary_cleaner.output.tail_pb                                         0.135157
# primary_cleaner.output.tail_sol                                       -0.004627
# primary_cleaner.output.tail_au                                        -0.044152
# primary_cleaner.state.floatbank8_a_air                                -0.073810
# primary_cleaner.state.floatbank8_a_level                              -0.131176
# primary_cleaner.state.floatbank8_b_air                                -0.068759
# primary_cleaner.state.floatbank8_b_level                              -0.129322
# primary_cleaner.state.floatbank8_c_air                                -0.053751
# primary_cleaner.state.floatbank8_c_level                              -0.113971
# primary_cleaner.state.floatbank8_d_air                                -0.001131
# primary_cleaner.state.floatbank8_d_level                              -0.089768
# rougher.calculation.sulfate_to_au_concentrate                          0.001460
# rougher.calculation.floatbank10_sulfate_to_au_feed                     0.026924
# rougher.calculation.floatbank11_sulfate_to_au_feed                     0.042433
# rougher.calculation.au_pb_ratio                                        0.065671
# rougher.input.feed_ag                                                 -0.064418
# rougher.input.feed_pb                                                 -0.063873
# rougher.input.feed_rate                                                0.165533
# rougher.input.feed_size                                                0.060709
# rougher.input.feed_sol                                                 0.218893
# rougher.input.feed_au                                                 -0.035530
# rougher.input.floatbank10_sulfate                                      0.070150
# rougher.input.floatbank10_xanthate                                     0.007160
# rougher.input.floatbank11_sulfate                                      0.066692
# rougher.input.floatbank11_xanthate                                     0.008431
# rougher.output.concentrate_ag                                          0.039075
# rougher.output.concentrate_pb                                         -0.040995
# rougher.output.concentrate_sol                                         0.177939
# rougher.output.concentrate_au                                          0.165702
# rougher.output.recovery                                                0.061727
# rougher.output.tail_ag                                                -0.067257
# rougher.output.tail_pb                                                -0.003655
# rougher.output.tail_sol                                                0.127716
# rougher.output.tail_au                                                -0.116147
# rougher.state.floatbank10_a_air                                        0.070620
# rougher.state.floatbank10_a_level                                      0.159555
# rougher.state.floatbank10_b_air                                       -0.129767
# rougher.state.floatbank10_b_level                                     -0.074788
# rougher.state.floatbank10_c_air                                       -0.134889
# rougher.state.floatbank10_c_level                                     -0.072856
# rougher.state.floatbank10_d_air                                       -0.152701
# rougher.state.floatbank10_d_level                                     -0.067048
# rougher.state.floatbank10_e_air                                       -0.170602
# rougher.state.floatbank10_e_level                                     -0.075416
# rougher.state.floatbank10_f_air                                       -0.160599
# rougher.state.floatbank10_f_level                                     -0.070966
# secondary_cleaner.output.tail_ag                                       0.134517
# secondary_cleaner.output.tail_pb                                       0.123134
# secondary_cleaner.output.tail_sol                                     -0.115784
# secondary_cleaner.output.tail_au                                      -0.006671
# secondary_cleaner.state.floatbank2_a_air                               0.000910
# secondary_cleaner.state.floatbank2_a_level                            -0.087510
# secondary_cleaner.state.floatbank2_b_air                              -0.022613
# secondary_cleaner.state.floatbank2_b_level                            -0.095865
# secondary_cleaner.state.floatbank3_a_air                               0.004020
# secondary_cleaner.state.floatbank3_a_level                            -0.081898
# secondary_cleaner.state.floatbank3_b_air                              -0.089900
# secondary_cleaner.state.floatbank3_b_level                            -0.145419
# secondary_cleaner.state.floatbank4_a_air                               0.016329
# secondary_cleaner.state.floatbank4_a_level                            -0.078542
# secondary_cleaner.state.floatbank4_b_air                              -0.007660
# secondary_cleaner.state.floatbank4_b_level                            -0.025611
# secondary_cleaner.state.floatbank5_a_air                              -0.018459
# secondary_cleaner.state.floatbank5_a_level                            -0.134354
# secondary_cleaner.state.floatbank5_b_air                              -0.029746
# secondary_cleaner.state.floatbank5_b_level                            -0.128631
# secondary_cleaner.state.floatbank6_a_air                              -0.156999
# secondary_cleaner.state.floatbank6_a_level                            -0.084121
#
#                                                     final.output.recovery  \
# final.output.concentrate_ag                                      0.176545
# final.output.concentrate_pb                                     -0.151636
# final.output.concentrate_sol                                     0.228541
# final.output.concentrate_au                                     -0.082683
# final.output.recovery                                            1.000000
# final.output.tail_ag                                             0.372188
# final.output.tail_pb                                            -0.095629
# final.output.tail_sol                                           -0.082292
# final.output.tail_au                                            -0.339966
# primary_cleaner.input.sulfate                                    0.402503
# primary_cleaner.input.depressant                                 0.171273
# primary_cleaner.input.feed_size                                  0.017689
# primary_cleaner.input.xanthate                                   0.257017
# primary_cleaner.output.concentrate_ag                            0.327394
# primary_cleaner.output.concentrate_pb                            0.096926
# primary_cleaner.output.concentrate_sol                           0.256142
# primary_cleaner.output.concentrate_au                           -0.272499
# primary_cleaner.output.tail_ag                                   0.314963
# primary_cleaner.output.tail_pb                                   0.283601
# primary_cleaner.output.tail_sol                                  0.120539
# primary_cleaner.output.tail_au                                  -0.348891
# primary_cleaner.state.floatbank8_a_air                           0.207814
# primary_cleaner.state.floatbank8_a_level                         0.067551
# primary_cleaner.state.floatbank8_b_air                           0.219379
# primary_cleaner.state.floatbank8_b_level                         0.065945
# primary_cleaner.state.floatbank8_c_air                           0.211062
# primary_cleaner.state.floatbank8_c_level                         0.065665
# primary_cleaner.state.floatbank8_d_air                           0.055813
# primary_cleaner.state.floatbank8_d_level                         0.024292
# rougher.calculation.sulfate_to_au_concentrate                   -0.014552
# rougher.calculation.floatbank10_sulfate_to_au_feed              -0.308843
# rougher.calculation.floatbank11_sulfate_to_au_feed              -0.312928
# rougher.calculation.au_pb_ratio                                  0.079351
# rougher.input.feed_ag                                            0.447454
# rougher.input.feed_pb                                            0.226261
# rougher.input.feed_rate                                          0.123466
# rougher.input.feed_size                                          0.113206
# rougher.input.feed_sol                                           0.234014
# rougher.input.feed_au                                            0.399371
# rougher.input.floatbank10_sulfate                               -0.044014
# rougher.input.floatbank10_xanthate                               0.321157
# rougher.input.floatbank11_sulfate                               -0.031959
# rougher.input.floatbank11_xanthate                               0.260663
# rougher.output.concentrate_ag                                    0.368356
# rougher.output.concentrate_pb                                   -0.127031
# rougher.output.concentrate_sol                                   0.017450
# rougher.output.concentrate_au                                   -0.112291
# rougher.output.recovery                                          0.640525
# rougher.output.tail_ag                                          -0.141271
# rougher.output.tail_pb                                          -0.374468
# rougher.output.tail_sol                                          0.169805
# rougher.output.tail_au                                          -0.358366
# rougher.state.floatbank10_a_air                                  0.303003
# rougher.state.floatbank10_a_level                                0.109633
# rougher.state.floatbank10_b_air                                 -0.211076
# rougher.state.floatbank10_b_level                               -0.127516
# rougher.state.floatbank10_c_air                                 -0.257011
# rougher.state.floatbank10_c_level                               -0.143050
# rougher.state.floatbank10_d_air                                 -0.244497
# rougher.state.floatbank10_d_level                               -0.143437
# rougher.state.floatbank10_e_air                                 -0.147514
# rougher.state.floatbank10_e_level                               -0.144712
# rougher.state.floatbank10_f_air                                 -0.118059
# rougher.state.floatbank10_f_level                               -0.145786
# secondary_cleaner.output.tail_ag                                 0.202025
# secondary_cleaner.output.tail_pb                                 0.000990
# secondary_cleaner.output.tail_sol                               -0.063392
# secondary_cleaner.output.tail_au                                -0.234338
# secondary_cleaner.state.floatbank2_a_air                         0.192783
# secondary_cleaner.state.floatbank2_a_level                       0.035870
# secondary_cleaner.state.floatbank2_b_air                         0.173601
# secondary_cleaner.state.floatbank2_b_level                       0.023855
# secondary_cleaner.state.floatbank3_a_air                         0.218085
# secondary_cleaner.state.floatbank3_a_level                       0.014166
# secondary_cleaner.state.floatbank3_b_air                         0.019277
# secondary_cleaner.state.floatbank3_b_level                       0.013009
# secondary_cleaner.state.floatbank4_a_air                         0.272679
# secondary_cleaner.state.floatbank4_a_level                       0.046222
# secondary_cleaner.state.floatbank4_b_air                         0.195384
# secondary_cleaner.state.floatbank4_b_level                      -0.130657
# secondary_cleaner.state.floatbank5_a_air                         0.082236
# secondary_cleaner.state.floatbank5_a_level                       0.036216
# secondary_cleaner.state.floatbank5_b_air                         0.059039
# secondary_cleaner.state.floatbank5_b_level                       0.043306
# secondary_cleaner.state.floatbank6_a_air                        -0.058165
# secondary_cleaner.state.floatbank6_a_level                      -0.040546
#
#                                                     final.output.tail_ag  \
# final.output.concentrate_ag                                     0.332796
# final.output.concentrate_pb                                    -0.201274
# final.output.concentrate_sol                                    0.168969
# final.output.concentrate_au                                    -0.036678
# final.output.recovery                                           0.372188
# final.output.tail_ag                                            1.000000
# final.output.tail_pb                                            0.223504
# final.output.tail_sol                                          -0.031359
# final.output.tail_au                                            0.372637
# primary_cleaner.input.sulfate                                   0.490406
# primary_cleaner.input.depressant                                0.550703
# primary_cleaner.input.feed_size                                -0.016771
# primary_cleaner.input.xanthate                                  0.299024
# primary_cleaner.output.concentrate_ag                           0.459400
# primary_cleaner.output.concentrate_pb                           0.036754
# primary_cleaner.output.concentrate_sol                          0.549076
# primary_cleaner.output.concentrate_au                          -0.249545
# primary_cleaner.output.tail_ag                                  0.658717
# primary_cleaner.output.tail_pb                                  0.686205
# primary_cleaner.output.tail_sol                                 0.121434
# primary_cleaner.output.tail_au                                  0.101865
# primary_cleaner.state.floatbank8_a_air                          0.171383
# primary_cleaner.state.floatbank8_a_level                        0.227999
# primary_cleaner.state.floatbank8_b_air                          0.196324
# primary_cleaner.state.floatbank8_b_level                        0.230188
# primary_cleaner.state.floatbank8_c_air                          0.198605
# primary_cleaner.state.floatbank8_c_level                        0.224488
# primary_cleaner.state.floatbank8_d_air                         -0.065216
# primary_cleaner.state.floatbank8_d_level                        0.138667
# rougher.calculation.sulfate_to_au_concentrate                  -0.019913
# rougher.calculation.floatbank10_sulfate_to_au_feed             -0.361415
# rougher.calculation.floatbank11_sulfate_to_au_feed             -0.375708
# rougher.calculation.au_pb_ratio                                 0.025875
# rougher.input.feed_ag                                           0.845454
# rougher.input.feed_pb                                           0.451641
# rougher.input.feed_rate                                        -0.072737
# rougher.input.feed_size                                         0.030436
# rougher.input.feed_sol                                         -0.006051
# rougher.input.feed_au                                           0.658406
# rougher.input.floatbank10_sulfate                              -0.121368
# rougher.input.floatbank10_xanthate                              0.348561
# rougher.input.floatbank11_sulfate                              -0.098892
# rougher.input.floatbank11_xanthate                              0.295205
# rougher.output.concentrate_ag                                   0.581087
# rougher.output.concentrate_pb                                  -0.003012
# rougher.output.concentrate_sol                                  0.030388
# rougher.output.concentrate_au                                  -0.015641
# rougher.output.recovery                                         0.506298
# rougher.output.tail_ag                                          0.230035
# rougher.output.tail_pb                                         -0.220992
# rougher.output.tail_sol                                        -0.081543
# rougher.output.tail_au                                         -0.002197
# rougher.state.floatbank10_a_air                                 0.347591
# rougher.state.floatbank10_a_level                              -0.002410
# rougher.state.floatbank10_b_air                                -0.180878
# rougher.state.floatbank10_b_level                              -0.282185
# rougher.state.floatbank10_c_air                                -0.246388
# rougher.state.floatbank10_c_level                              -0.275441
# rougher.state.floatbank10_d_air                                -0.218640
# rougher.state.floatbank10_d_level                              -0.277755
# rougher.state.floatbank10_e_air                                -0.054352
# rougher.state.floatbank10_e_level                              -0.275579
# rougher.state.floatbank10_f_air                                -0.045619
# rougher.state.floatbank10_f_level                              -0.276749
# secondary_cleaner.output.tail_ag                                0.268192
# secondary_cleaner.output.tail_pb                                0.100559
# secondary_cleaner.output.tail_sol                               0.133339
# secondary_cleaner.output.tail_au                                0.165555
# secondary_cleaner.state.floatbank2_a_air                        0.115351
# secondary_cleaner.state.floatbank2_a_level                      0.056309
# secondary_cleaner.state.floatbank2_b_air                        0.197621
# secondary_cleaner.state.floatbank2_b_level                      0.048016
# secondary_cleaner.state.floatbank3_a_air                        0.114420
# secondary_cleaner.state.floatbank3_a_level                      0.031729
# secondary_cleaner.state.floatbank3_b_air                        0.069210
# secondary_cleaner.state.floatbank3_b_level                      0.007423
# secondary_cleaner.state.floatbank4_a_air                        0.228364
# secondary_cleaner.state.floatbank4_a_level                      0.018746
# secondary_cleaner.state.floatbank4_b_air                        0.251937
# secondary_cleaner.state.floatbank4_b_level                     -0.269074
# secondary_cleaner.state.floatbank5_a_air                        0.034360
# secondary_cleaner.state.floatbank5_a_level                     -0.018520
# secondary_cleaner.state.floatbank5_b_air                        0.056794
# secondary_cleaner.state.floatbank5_b_level                     -0.012962
# secondary_cleaner.state.floatbank6_a_air                       -0.098463
# secondary_cleaner.state.floatbank6_a_level                     -0.140605
#
#                                                     final.output.tail_pb  \
# final.output.concentrate_ag                                    -0.107178
# final.output.concentrate_pb                                     0.267816
# final.output.concentrate_sol                                    0.314304
# final.output.concentrate_au                                     0.033919
# final.output.recovery                                          -0.095629
# final.output.tail_ag                                            0.223504
# final.output.tail_pb                                            1.000000
# final.output.tail_sol                                          -0.373835
# final.output.tail_au                                            0.628043
# primary_cleaner.input.sulfate                                   0.389789
# primary_cleaner.input.depressant                                0.081357
# primary_cleaner.input.feed_size                                -0.184729
# primary_cleaner.input.xanthate                                 -0.219887
# primary_cleaner.output.concentrate_ag                          -0.015199
# primary_cleaner.output.concentrate_pb                           0.476900
# primary_cleaner.output.concentrate_sol                         -0.112722
# primary_cleaner.output.concentrate_au                          -0.161108
# primary_cleaner.output.tail_ag                                  0.217894
# primary_cleaner.output.tail_pb                                  0.344264
# primary_cleaner.output.tail_sol                                 0.031431
# primary_cleaner.output.tail_au                                  0.175000
# primary_cleaner.state.floatbank8_a_air                          0.044283
# primary_cleaner.state.floatbank8_a_level                       -0.164170
# primary_cleaner.state.floatbank8_b_air                          0.049777
# primary_cleaner.state.floatbank8_b_level                       -0.162757
# primary_cleaner.state.floatbank8_c_air                          0.069980
# primary_cleaner.state.floatbank8_c_level                       -0.158994
# primary_cleaner.state.floatbank8_d_air                          0.248108
# primary_cleaner.state.floatbank8_d_level                       -0.130864
# rougher.calculation.sulfate_to_au_concentrate                  -0.001720
# rougher.calculation.floatbank10_sulfate_to_au_feed              0.187512
# rougher.calculation.floatbank11_sulfate_to_au_feed              0.075295
# rougher.calculation.au_pb_ratio                                -0.452198
# rougher.input.feed_ag                                           0.302902
# rougher.input.feed_pb                                           0.827923
# rougher.input.feed_rate                                        -0.384396
# rougher.input.feed_size                                        -0.081513
# rougher.input.feed_sol                                         -0.037607
# rougher.input.feed_au                                           0.546370
# rougher.input.floatbank10_sulfate                               0.390635
# rougher.input.floatbank10_xanthate                             -0.263132
# rougher.input.floatbank11_sulfate                               0.260988
# rougher.input.floatbank11_xanthate                             -0.281195
# rougher.output.concentrate_ag                                   0.061814
# rougher.output.concentrate_pb                                   0.649796
# rougher.output.concentrate_sol                                  0.346507
# rougher.output.concentrate_au                                   0.245139
# rougher.output.recovery                                         0.241515
# rougher.output.tail_ag                                          0.271401
# rougher.output.tail_pb                                          0.097318
# rougher.output.tail_sol                                        -0.479944
# rougher.output.tail_au                                          0.187388
# rougher.state.floatbank10_a_air                                 0.233049
# rougher.state.floatbank10_a_level                               0.374177
# rougher.state.floatbank10_b_air                                -0.179296
# rougher.state.floatbank10_b_level                               0.042532
# rougher.state.floatbank10_c_air                                -0.141817
# rougher.state.floatbank10_c_level                               0.066828
# rougher.state.floatbank10_d_air                                -0.242193
# rougher.state.floatbank10_d_level                               0.068338
# rougher.state.floatbank10_e_air                                -0.373605
# rougher.state.floatbank10_e_level                               0.067848
# rougher.state.floatbank10_f_air                                -0.324945
# rougher.state.floatbank10_f_level                               0.069283
# secondary_cleaner.output.tail_ag                                0.019636
# secondary_cleaner.output.tail_pb                                0.234809
# secondary_cleaner.output.tail_sol                              -0.083438
# secondary_cleaner.output.tail_au                                0.137886
# secondary_cleaner.state.floatbank2_a_air                        0.041809
# secondary_cleaner.state.floatbank2_a_level                     -0.147501
# secondary_cleaner.state.floatbank2_b_air                        0.000494
# secondary_cleaner.state.floatbank2_b_level                     -0.127184
# secondary_cleaner.state.floatbank3_a_air                        0.154869
# secondary_cleaner.state.floatbank3_a_level                      0.072650
# ...
# final.output.tail_au                                                                0.094421
# primary_cleaner.input.sulfate                                                      -0.156395
# primary_cleaner.input.depressant                                                   -0.201230
# primary_cleaner.input.feed_size                                                     0.109588
# primary_cleaner.input.xanthate                                                     -0.262318
# primary_cleaner.output.concentrate_ag                                               0.022800
# primary_cleaner.output.concentrate_pb                                              -0.144508
# primary_cleaner.output.concentrate_sol                                             -0.192383
# primary_cleaner.output.concentrate_au                                              -0.042812
# primary_cleaner.output.tail_ag                                                     -0.333371
# primary_cleaner.output.tail_pb                                                     -0.358975
# primary_cleaner.output.tail_sol                                                     0.172189
# primary_cleaner.output.tail_au                                                      0.132489
# primary_cleaner.state.floatbank8_a_air                                              0.318817
# primary_cleaner.state.floatbank8_a_level                                            0.145370
# primary_cleaner.state.floatbank8_b_air                                              0.347936
# primary_cleaner.state.floatbank8_b_level                                            0.145010
# primary_cleaner.state.floatbank8_c_air                                              0.304740
# primary_cleaner.state.floatbank8_c_level                                            0.141217
# primary_cleaner.state.floatbank8_d_air                                              0.059733
# primary_cleaner.state.floatbank8_d_level                                            0.064660
# rougher.calculation.sulfate_to_au_concentrate                                      -0.008378
# rougher.calculation.floatbank10_sulfate_to_au_feed                                  0.056027
# rougher.calculation.floatbank11_sulfate_to_au_feed                                 -0.054542
# rougher.calculation.au_pb_ratio                                                     0.068261
# rougher.input.feed_ag                                                              -0.003027
# rougher.input.feed_pb                                                              -0.035617
# rougher.input.feed_rate                                                            -0.344772
# rougher.input.feed_size                                                            -0.152021
# rougher.input.feed_sol                                                             -0.207724
# rougher.input.feed_au                                                               0.031306
# rougher.input.floatbank10_sulfate                                                  -0.095190
# rougher.input.floatbank10_xanthate                                                 -0.335356
# rougher.input.floatbank11_sulfate                                                  -0.145663
# rougher.input.floatbank11_xanthate                                                 -0.333260
# rougher.output.concentrate_ag                                                       0.024928
# rougher.output.concentrate_pb                                                      -0.049911
# rougher.output.concentrate_sol                                                     -0.071059
# rougher.output.concentrate_au                                                       0.151006
# rougher.output.recovery                                                            -0.116243
# rougher.output.tail_ag                                                              0.308253
# rougher.output.tail_pb                                                              0.020871
# rougher.output.tail_sol                                                             0.014365
# rougher.output.tail_au                                                              0.141233
# rougher.state.floatbank10_a_air                                                     0.028826
# rougher.state.floatbank10_a_level                                                  -0.175325
# rougher.state.floatbank10_b_air                                                     0.391160
# rougher.state.floatbank10_b_level                                                   0.473996
# rougher.state.floatbank10_c_air                                                     0.428147
# rougher.state.floatbank10_c_level                                                   0.475954
# rougher.state.floatbank10_d_air                                                     0.383392
# rougher.state.floatbank10_d_level                                                   0.478058
# rougher.state.floatbank10_e_air                                                     0.177539
# rougher.state.floatbank10_e_level                                                   0.482575
# rougher.state.floatbank10_f_air                                                     0.227243
# rougher.state.floatbank10_f_level                                                   0.488944
# secondary_cleaner.output.tail_ag                                                   -0.433656
# secondary_cleaner.output.tail_pb                                                   -0.521520
# secondary_cleaner.output.tail_sol                                                   0.336372
# secondary_cleaner.output.tail_au                                                   -0.176376
# secondary_cleaner.state.floatbank2_a_air                                           -0.032396
# secondary_cleaner.state.floatbank2_a_level                                         -0.061177
# secondary_cleaner.state.floatbank2_b_air                                           -0.049323
# secondary_cleaner.state.floatbank2_b_level                                         -0.043000
# secondary_cleaner.state.floatbank3_a_air                                            0.361333
# secondary_cleaner.state.floatbank3_a_level                                          0.511752
# secondary_cleaner.state.floatbank3_b_air                                            0.366993
# secondary_cleaner.state.floatbank3_b_level                                          0.172510
# secondary_cleaner.state.floatbank4_a_air                                            0.242033
# secondary_cleaner.state.floatbank4_a_level                                          0.597617
# secondary_cleaner.state.floatbank4_b_air                                            0.337879
# secondary_cleaner.state.floatbank4_b_level                                          0.296551
# secondary_cleaner.state.floatbank5_a_air                                            0.475275
# secondary_cleaner.state.floatbank5_a_level                                          0.526559
# secondary_cleaner.state.floatbank5_b_air                                            0.478463
# secondary_cleaner.state.floatbank5_b_level                                          0.523765
# secondary_cleaner.state.floatbank6_a_air                                            1.000000
# secondary_cleaner.state.floatbank6_a_level                                          0.126400
#
#                                                     secondary_cleaner.state.floatbank6_a_level
# final.output.concentrate_ag                                                           0.061257
# final.output.concentrate_pb                                                           0.067602
# final.output.concentrate_sol                                                         -0.297884
# final.output.concentrate_au                                                          -0.084121
# final.output.recovery                                                                -0.040546
# final.output.tail_ag                                                                 -0.140605
# final.output.tail_pb                                                                 -0.211790
# final.output.tail_sol                                                                 0.028924
# final.output.tail_au                                                                 -0.149569
# primary_cleaner.input.sulfate                                                        -0.152394
# primary_cleaner.input.depressant                                                     -0.132954
# primary_cleaner.input.feed_size                                                       0.086914
# primary_cleaner.input.xanthate                                                       -0.079991
# primary_cleaner.output.concentrate_ag                                                -0.071609
# primary_cleaner.output.concentrate_pb                                                -0.103651
# primary_cleaner.output.concentrate_sol                                               -0.166487
# primary_cleaner.output.concentrate_au                                                 0.059279
# primary_cleaner.output.tail_ag                                                       -0.218675
# primary_cleaner.output.tail_pb                                                       -0.239176
# primary_cleaner.output.tail_sol                                                      -0.007645
# primary_cleaner.output.tail_au                                                       -0.001294
# primary_cleaner.state.floatbank8_a_air                                                0.057520
# primary_cleaner.state.floatbank8_a_level                                              0.208866
# primary_cleaner.state.floatbank8_b_air                                                0.035093
# primary_cleaner.state.floatbank8_b_level                                              0.208938
# primary_cleaner.state.floatbank8_c_air                                                0.038249
# primary_cleaner.state.floatbank8_c_level                                              0.207672
# primary_cleaner.state.floatbank8_d_air                                               -0.117509
# primary_cleaner.state.floatbank8_d_level                                              0.190325
# rougher.calculation.sulfate_to_au_concentrate                                        -0.001616
# rougher.calculation.floatbank10_sulfate_to_au_feed                                    0.098956
# rougher.calculation.floatbank11_sulfate_to_au_feed                                    0.073497
# rougher.calculation.au_pb_ratio                                                       0.002791
# rougher.input.feed_ag                                                                -0.104135
# rougher.input.feed_pb                                                                -0.131059
# rougher.input.feed_rate                                                               0.019005
# rougher.input.feed_size                                                               0.071495
# rougher.input.feed_sol                                                               -0.030287
# rougher.input.feed_au                                                                -0.165695
# rougher.input.floatbank10_sulfate                                                    -0.028041
# rougher.input.floatbank10_xanthate                                                    0.000671
# rougher.input.floatbank11_sulfate                                                    -0.042115
# rougher.input.floatbank11_xanthate                                                   -0.015294
# rougher.output.concentrate_ag                                                        -0.259742
# rougher.output.concentrate_pb                                                        -0.097118
# rougher.output.concentrate_sol                                                       -0.271710
# rougher.output.concentrate_au                                                        -0.180651
# rougher.output.recovery                                                              -0.077078
# rougher.output.tail_ag                                                               -0.102656
# rougher.output.tail_pb                                                                0.049218
# rougher.output.tail_sol                                                               0.062222
# rougher.output.tail_au                                                               -0.066308
# rougher.state.floatbank10_a_air                                                      -0.020572
# rougher.state.floatbank10_a_level                                                     0.106098
# rougher.state.floatbank10_b_air                                                       0.180351
# rougher.state.floatbank10_b_level                                                     0.208436
# rougher.state.floatbank10_c_air                                                       0.150804
# rougher.state.floatbank10_c_level                                                     0.207397
# rougher.state.floatbank10_d_air                                                       0.149115
# rougher.state.floatbank10_d_level                                                     0.209992
# rougher.state.floatbank10_e_air                                                       0.210275
# rougher.state.floatbank10_e_level                                                     0.199444
# rougher.state.floatbank10_f_air                                                       0.212115
# rougher.state.floatbank10_f_level                                                     0.198853
# secondary_cleaner.output.tail_ag                                                     -0.085030
# secondary_cleaner.output.tail_pb                                                     -0.001125
# secondary_cleaner.output.tail_sol                                                    -0.100777
# secondary_cleaner.output.tail_au                                                      0.028171
# secondary_cleaner.state.floatbank2_a_air                                             -0.001781
# secondary_cleaner.state.floatbank2_a_level                                            0.092471
# secondary_cleaner.state.floatbank2_b_air                                             -0.061205
# secondary_cleaner.state.floatbank2_b_level                                            0.090701
# secondary_cleaner.state.floatbank3_a_air                                             -0.040167
# secondary_cleaner.state.floatbank3_a_level                                            0.315608
# secondary_cleaner.state.floatbank3_b_air                                             -0.062149
# secondary_cleaner.state.floatbank3_b_level                                            0.303858
# secondary_cleaner.state.floatbank4_a_air                                             -0.016413
# secondary_cleaner.state.floatbank4_a_level                                            0.286281
# secondary_cleaner.state.floatbank4_b_air                                             -0.123463
# secondary_cleaner.state.floatbank4_b_level                                            0.319225
# secondary_cleaner.state.floatbank5_a_air                                             -0.013258
# secondary_cleaner.state.floatbank5_a_level                                            0.403871
# secondary_cleaner.state.floatbank5_b_air                                             -0.036324
# secondary_cleaner.state.floatbank5_b_level                                            0.371695
# secondary_cleaner.state.floatbank6_a_air                                              0.126400
# secondary_cleaner.state.floatbank6_a_level                                            1.000000

# %% [markdown]
# Мультиколлинеарность означает, что два или более признака сильно коррелируют друг с другом. В данном случае мы видим, что явно отсутствуют хотя бы два признака с сильной линейной зависимостью друг с другом. В свою очередь, это не должно привести к проблемам при построении модели, т.к. исключает ситуацию, когда один из признаков вносит больший вклад в предсказание целевого признака.

# %% [markdown]
# # Исследовательский анализ данных
#
# https://github.com/DmitriyPyankov/Prediction-of-recovery-coefficients-of-gold-from-gold-bearing-ore/tree/main/%D0%9F%D1%80%D0%BE%D0%B3%D0%BD%D0%BE%D0%B7%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20%D0%BA%D0%BE%D1%8D%D1%84%D1%84%D0%B8%D1%86%D0%B8%D0%B5%D0%BD%D1%82%D0%BE%D0%B2%20%D0%B2%D0%BE%D1%81%D1%81%D1%82%D0%B0%D0%BD%D0%BE%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D1%8F%20%D0%B7%D0%BE%D0%BB%D0%BE%D1%82%D0%B0%20%D0%B8%D0%B7%20%D0%B7%D0%BE%D0%BB%D0%BE%D1%82%D0%BE%D1%81%D0%BE%D0%B4%D0%B5%D1%80%D0%B6%D0%B0%D1%89%D0%B5%D0%B9%20%D1%80%D1%83%D0%B4%D1%8B

# %% [markdown]
# ## Изменение концентрации металлов
# _Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Опишите выводы._

# %%
output_concentrate = data_train_clr.filter(like='output.concentrate')

# Строим графики для каждого металла на различных этапах очистки
for metal in ['au', 'ag', 'pb']:
    metal_concentrate = output_concentrate.filter(like=metal)
    metal_concentrate.plot(
        kind='hist',
        histtype='barstacked',
        bins=50, 
        linewidth=10,
        alpha=0.6, 
        figsize=(20, 10)
    )
    plt.title(f'Изменение концентрации {metal.upper()} в зависимости от стадий очистки')
    plt.xlabel('Концентрация металлов')
    plt.ylabel('Распределение металла')

plt.show()

# %% [markdown]
# ## Сравнение распределения гранул сырья на выборках
# _Сравните распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной._

# %% [markdown]
# ## Исследование суммарной концентрации веществ
# _Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах_

# %% [markdown]
# # Построение модели

# %% [markdown]
# ## Подготовка обучающей выборки
# <font color='red'><strong>train уменьшить до 53+2 признаков, как в test</strong></font>
#
# Обучающая выборка содержит ровным счётом те же самые признаки, что и исходный датасет. Однако для непосредственно обучения и последующего тестирования нам необходимо идентичное число признаков в тестовом и обучающем датасетах. Следовательно избавимся от "лишних" признаков.

# %%
difference_columns = set(data_init.columns) - set(data_test_tar.columns)
data_train_clr = data_train.drop(columns=difference_columns)
data_train_clr.shape

# %% [markdown]
# В итоге в обучающей выборке фигурирует более 14К строк и 55 признаков. Процент строк тестовой выборки в отношении к всем рассматриваемым строкам составляет более 27%.

# %% [markdown]
# ## Создание функции для вычисления итоговой sMAPE

# %% [markdown]
# ## Обучение разных моделей
#  <font color='red'><strong>Перед обучением потребовали масштабирование. Использовал StandardScaler().
#  fit+transform scaler-a только на обучающей, а  на остальных только transform</font></strong>

# %% [markdown]
# ## Оценка качества моделей кросс-валидацией

# %% [markdown]
# ## Проверка выбранной модели на тестовой выборке

# %% [markdown]
# # Чек-лист готовности проекта

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [ ]  Весь код выполняется без ошибок
# - [ ]  Ячейки с кодом расположены в порядке выполнения
# - [ ]  Выполнен шаг 1: данные подготовлены
#     - [ ]  Проверена формула вычисления эффективности обогащения
#     - [ ]  Проанализированы признаки, недоступные в тестовой выборке
#     - [ ]  Проведена предобработка данных
# - [ ]  Выполнен шаг 2: данные проанализированы
#     - [ ]  Исследовано изменение концентрации элементов на каждом этапе
#     - [ ]  Проанализированы распределения размеров гранул на обучающей и тестовой выборках
#     - [ ]  Исследованы суммарные концентрации
# - [ ]  Выполнен шаг 3: построена модель прогнозирования
#     - [ ]  Написана функция для вычисления итогового *sMAPE*
#     - [ ]  Обучено и проверено несколько моделей
#     - [ ]  Выбрана лучшая модель, её качество проверено на тестовой выборке
