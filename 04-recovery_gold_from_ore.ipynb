# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-общей-информации" data-toc-modified-id="Изучение-общей-информации-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Изучение общей информации</a></span><ul class="toc-item"><li><span><a href="#Загрузка-библиотек" data-toc-modified-id="Загрузка-библиотек-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Загрузка библиотек</a></span></li><li><span><a href="#Открытие-датасета" data-toc-modified-id="Открытие-датасета-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Открытие датасета</a></span><ul class="toc-item"><li><span><a href="#Обучающая-выборка" data-toc-modified-id="Обучающая-выборка-2.1.2.1"><span class="toc-item-num">2.1.2.1&nbsp;&nbsp;</span>Обучающая выборка</a></span></li><li><span><a href="#Тестовая-выборка" data-toc-modified-id="Тестовая-выборка-2.1.2.2"><span class="toc-item-num">2.1.2.2&nbsp;&nbsp;</span>Тестовая выборка</a></span></li><li><span><a href="#Исходная-выборка" data-toc-modified-id="Исходная-выборка-2.1.2.3"><span class="toc-item-num">2.1.2.3&nbsp;&nbsp;</span>Исходная выборка</a></span></li></ul></li><li><span><a href="#Определение-целевого-параметра" data-toc-modified-id="Определение-целевого-параметра-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Определение целевого параметра</a></span></li></ul></li><li><span><a href="#Вычисление-эффективности-обогащения" data-toc-modified-id="Вычисление-эффективности-обогащения-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Вычисление эффективности обогащения</a></span></li><li><span><a href="#Анализ-признаков,-недоступных-в-тестовой-выборке" data-toc-modified-id="Анализ-признаков,-недоступных-в-тестовой-выборке-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Анализ признаков, недоступных в тестовой выборке</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Определение-пропусков" data-toc-modified-id="Определение-пропусков-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Определение пропусков</a></span></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Изменение типов данных</a></span></li><li><span><a href="#Устранение-неявных-дубликатов" data-toc-modified-id="Устранение-неявных-дубликатов-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Устранение неявных дубликатов</a></span></li><li><span><a href="#Определение-и-устранение-аномальных-значений" data-toc-modified-id="Определение-и-устранение-аномальных-значений-2.4.4"><span class="toc-item-num">2.4.4&nbsp;&nbsp;</span>Определение и устранение аномальных значений</a></span></li><li><span><a href="#Добавление-новых-столбцов-????" data-toc-modified-id="Добавление-новых-столбцов-????-2.4.5"><span class="toc-item-num">2.4.5&nbsp;&nbsp;</span>Добавление новых столбцов ????</a></span></li></ul></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изменение-концентрации-металлов" data-toc-modified-id="Изменение-концентрации-металлов-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Изменение концентрации металлов</a></span></li><li><span><a href="#Сравнение-распределения-гранул-сырья-на-выборках" data-toc-modified-id="Сравнение-распределения-гранул-сырья-на-выборках-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Сравнение распределения гранул сырья на выборках</a></span></li><li><span><a href="#Исследование-суммарной-концентрации-веществ" data-toc-modified-id="Исследование-суммарной-концентрации-веществ-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Исследование суммарной концентрации веществ</a></span></li></ul></li><li><span><a href="#Построение-модели" data-toc-modified-id="Построение-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Построение модели</a></span><ul class="toc-item"><li><span><a href="#Создание-функции-для-вычисления-итоговой-sMAPE" data-toc-modified-id="Создание-функции-для-вычисления-итоговой-sMAPE-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Создание функции для вычисления итоговой sMAPE</a></span></li><li><span><a href="#Обучение-разных-моделей" data-toc-modified-id="Обучение-разных-моделей-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Обучение разных моделей</a></span></li><li><span><a href="#Оценка-качества-моделей-кросс-валидацией" data-toc-modified-id="Оценка-качества-моделей-кросс-валидацией-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Оценка качества моделей кросс-валидацией</a></span></li><li><span><a href="#Проверка-выбранной-модели-на-тестовой-выборке" data-toc-modified-id="Проверка-выбранной-модели-на-тестовой-выборке-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Проверка выбранной модели на тестовой выборке</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для компании `Цифра`. Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# Данные находятся в трёх файлах:
#
# - [gold_recovery_train_new.csv](https://code.s3.yandex.net/datasets/gold_recovery_train_new.csv) — обучающая выборка;
# - [gold_recovery_test_new.csv](https://code.s3.yandex.net/datasets/gold_recovery_test_new.csv) — тестовая выборка;
# - [gold_recovery_full_new.csv](https://code.s3.yandex.net/datasets/gold_recovery_full_new.csv) — исходные данные.
#
# Данные индексируются датой и временем получения информации (признак `date`). Соседние по времени параметры часто похожи.
#
# Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков.
#
# Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.
#
# В вашем распоряжении сырые данные: их просто выгрузили из хранилища. Прежде чем приступить к построению модели, проверьте по нашей инструкции их на корректность.
#
# Исходя из описания технологического процесса восстановления золота из руды, необходимо спрогнозировать две величины:
# - `rougher.output.recovery` - эффективность обогащения чернового концентрата,
# - `final.output.recovery` - эффективность обогащения финального концентрата.

# %% [markdown]
# # Подготовка данных

# %% [markdown]
# ## Изучение общей информации
# ### Импорт библиотек

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt

#import requests
#from io import BytesIO
#import random
#import warnings
#from sklearn.linear_model import LogisticRegression
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.ensemble import RandomForestClassifier
#from sklearn.model_selection import train_test_split
#from joblib import dump
#from sklearn.metrics import accuracy_score
#import seaborn as sns
#import plotly.graph_objs as go
#from tqdm import tqdm
#from sklearn.dummy import DummyClassifier

# %% [markdown]
# ### Открытие датасета
# Ввиду того, что у нас представлены три отдельных датасета (обучающий, тестовый и полный с исходными данными), выполним открытие каждого из датасетов по отдельности и посмотрим инфо по типам данных, сделав первоначальный анализ имеющегося материала. Затем
#
#
# _Данные индексируются датой и временем получения информации (признак date). Соседние по времени параметры часто похожи._
#
# _Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков._
#
# _Исходный датасет содержит обучающую и тестовую выборки со всеми признаками._
#
# _В вашем распоряжении сырые данные: их просто выгрузили из хранилища. Прежде чем приступить к построению модели, проверьте по нашей инструкции их на корректность._

# %% [markdown]
# #### Обучающая выборка

# %%
url_train = 'https://code.s3.yandex.net/datasets/gold_recovery_train_new.csv'
data_train = pd.read_csv(url_train)
pd.set_option('display.max_columns', None)
data_train.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# 2                    42.657501              68.116445             10.507046
# 3                    42.689819              68.347543             10.422762
# 4                    42.774141              66.927016             10.360302
#
#    final.output.tail_pb  final.output.tail_sol  final.output.tail_au  \
# 0              0.895447              16.904297              2.143149
# 1              0.927452              16.634514              2.224930
# 2              0.953716              16.208849              2.257889
# 3              0.883763              16.532835              2.146849
# 4              0.792826              16.525686              2.055292
#
#    primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# 0                     127.092003                         10.128295
# 1                     125.629232                         10.296251
# 2                     123.819808                         11.316280
# 3                     122.270188                         11.322140
# 4                     117.988169                         11.913613
#
#    primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  \
# 0                             7.25                        0.988759
# 1                             7.25                        1.002663
# 2                             7.25                        0.991265
# 3                             7.25                        0.996739
# 4                             7.25                        1.009869
#
#    primary_cleaner.output.concentrate_ag  \
# 0                               8.547551
# 1                               8.558743
# 2                               8.603505
# 3                               7.221879
# 4                               9.089428
#
#    primary_cleaner.output.concentrate_pb  \
# 0                              10.389648
# 1                              10.497069
# 2                              10.354494
# 3                               8.496563
# 4                               9.986786
#
#    primary_cleaner.output.concentrate_sol  \
# 0                               19.529297
# 1                               19.369147
# 2                               19.167579
# 3                               15.978538
# 4                               19.199864
#
#    primary_cleaner.output.concentrate_au  primary_cleaner.output.tail_ag  \
# 0                              34.174427                       14.936526
# 1                              34.118526                       16.250511
# 2                              33.969464                       16.491823
# 3                              28.260743                       16.024359
# 4                              33.044932                       16.480185
#
#    primary_cleaner.output.tail_pb  primary_cleaner.output.tail_sol  \
# 0                        2.534912                         7.476074
# 1                        3.049646                         6.733907
# 2                        3.124664                         6.471768
# 3                        2.960362                         6.843791
# 4                        3.112100                         6.550154
#
#    primary_cleaner.output.tail_au  primary_cleaner.state.floatbank8_a_air  \
# 0                        2.106679                             1549.775757
# 1                        2.353017                             1576.166671
# 2                        2.416800                             1601.556163
# 3                        2.262051                             1599.968720
# 4                        2.277073                             1601.339707
#
#    primary_cleaner.state.floatbank8_a_level  \
# 0                               -498.912140
# 1                               -500.904965
# 2                               -499.997791
# 3                               -500.951778
# 4                               -498.975456
#
#    primary_cleaner.state.floatbank8_b_air  \
# 0                             1551.434204
# 1                             1575.950626
# 2                             1600.386685
# 3                             1600.659236
# 4                             1601.437854
#
#    primary_cleaner.state.floatbank8_b_level  \
# 0                               -516.403442
# 1                               -499.865889
# 2                               -500.607762
# 3                               -499.677094
# 4                               -500.323246
#
#    primary_cleaner.state.floatbank8_c_air  \
# 0                             1549.873901
# 1                             1575.994189
# 2                             1602.003542
# 3                             1600.304144
# 4                             1599.581894
#
#    primary_cleaner.state.floatbank8_c_level  \
# 0                               -498.666595
# 1                               -499.315107
# 2                               -500.870069
# 3                               -500.727997
# 4                               -500.888152
#
#    primary_cleaner.state.floatbank8_d_air  \
# 0                             1554.367432
# 1                             1574.479259
# 2                             1599.541515
# 3                             1600.449520
# 4                             1602.649541
#
#    primary_cleaner.state.floatbank8_d_level  \
# 0                               -493.428131
# 1                               -498.931665
# 2                               -499.827444
# 3                               -500.052575
# 4                               -500.593010
#
#    rougher.calculation.sulfate_to_au_concentrate  \
# 0                                   41885.707031
# 1                                   42050.861809
# 2                                   42018.101184
# 3                                   42029.447991
# 4                                   42125.354245
#
#    rougher.calculation.floatbank10_sulfate_to_au_feed  \
# 0                                        3481.779053
# 1                                        3498.370979
# 2                                        3495.348910
# 3                                        3498.578313
# 4                                        3494.800771
#
#    rougher.calculation.floatbank11_sulfate_to_au_feed  \
# 0                                        3520.337158
# 1                                        3489.981857
# 2                                        3502.359819
# 3                                        3499.162912
# 4                                        3506.679315
#
#    rougher.calculation.au_pb_ratio  rougher.input.feed_ag  \
# 0                         2.838687               6.100378
# 1                         2.858998               6.161113
# 2                         2.945989               6.116455
# 3                         3.002340               6.043309
# 4                         3.169615               6.060915
#
#    rougher.input.feed_pb  rougher.input.feed_rate  rougher.input.feed_size  \
# 0               2.284912               523.546326                55.486599
# 1               2.266033               525.290581                57.278666
# 2               2.159622               530.026610                57.510649
# 3               2.037807               542.590390                57.792734
# 4               1.786875               540.531893                56.047189
#
#    rougher.input.feed_sol  rougher.input.feed_au  \
# 0               36.808594               6.486150
# 1               35.753385               6.478583
# 2               35.971630               6.362222
# 3               36.862241               6.118189
# 4               34.347666               5.663707
#
#    rougher.input.floatbank10_sulfate  rougher.input.floatbank10_xanthate  \
# 0                          11.986616                            6.007990
# 1                          11.971193                            6.005766
# 2                          11.920603                            6.197377
# 3                          11.630094                            6.203177
# 4                          10.957755                            6.198826
#
#    rougher.input.floatbank11_sulfate  rougher.input.floatbank11_xanthate  \
# 0                          11.836743                            6.005818
# 1                          11.996163                            6.012594
# 2                          11.920305                            6.204633
# 3                          11.692450                            6.196578
# 4                          10.960521                            6.194897
#
#    rougher.output.concentrate_ag  rougher.output.concentrate_pb  \
# 0                      11.500771                       7.101074
# 1                      11.615865                       7.278807
# 2                      11.695753                       7.216833
# 3                      11.915047                       7.175616
# 4                      12.411054                       7.240205
#
#    rougher.output.concentrate_sol  rougher.output.concentrate_au  \
# 0                       28.029297                      19.793808
# 1                       28.067063                      20.050975
# 2                       27.454037                      19.737170
# 3                       27.341277                      19.320810
# 4                       27.041023                      19.216101
#
#    rougher.output.recovery  rougher.output.tail_ag  rougher.output.tail_pb  \
# 0                87.107763                5.008018                0.508728
# 1                86.843261                4.955378                0.536689
# 2                86.842308                4.843460                0.546416
# 3                87.226430                4.655288                0.542525
# 4                86.688794                4.552800                0.515438
#
#    rougher.output.tail_sol  rougher.output.tail_au  \
# 0                19.154297                1.170244
# 1                18.965234                1.184827
# 2                18.808533                1.162562
# 3                19.330200                1.079755
# 4                19.267422                1.012642
#
#    rougher.state.floatbank10_a_air  rougher.state.floatbank10_a_level  \
# 0                       999.706909                        -404.066986
# 1                      1000.286398                        -400.065196
# 2                       999.719565                        -400.074028
# 3                       999.814770                        -400.200179
# 4                       999.678690                        -399.752729
#
#    rougher.state.floatbank10_b_air  rougher.state.floatbank10_b_level  \
# 0                      1603.011353                        -434.715027
# 1                      1600.754587                        -449.953435
# 2                      1599.337330                        -450.008530
# 3                      1600.059442                        -450.619948
# 4                      1600.208824                        -449.599614
#
#    rougher.state.floatbank10_c_air  rougher.state.floatbank10_c_level  \
# 0                      1602.375000                        -442.204468
# 1                      1600.479580                        -449.830646
# 2                      1599.672797                        -449.954491
# 3                      1600.012842                        -449.910497
# 4                      1600.357732                        -450.034364
#
#    rougher.state.floatbank10_d_air  rougher.state.floatbank10_d_level  \
# 0                      1598.937256                        -451.294128
# 1                      1600.527589                        -449.953649
# 2                      1599.849325                        -449.954185
# 3                      1597.725177                        -450.130127
# 4                      1599.759049                        -449.909799
#
#    rougher.state.floatbank10_e_air  rougher.state.floatbank10_e_level  \
# 0                      1404.472046                        -455.462982
# 1                      1399.227084                        -450.869848
# 2                      1399.180945                        -449.937588
# 3                      1400.943157                        -450.030142
# 4                      1401.560902                        -448.877187
#
#    rougher.state.floatbank10_f_air  rougher.state.floatbank10_f_level  \
# 0                      1416.354980                        -451.939636
# 1                      1399.719514                        -450.119001
# 2                      1400.316682                        -450.527147
# 3                      1400.234743                        -449.790835
# 4                      1401.160227                        -450.407128
#
#    secondary_cleaner.output.tail_ag  secondary_cleaner.output.tail_pb  \
# 0                         14.500184                          4.694824
# 1                         14.265474                          4.592547
# 2                         14.115662                          4.624775
# 3                         13.732071                          4.482453
# 4                         14.079996                          4.470737
#
#    secondary_cleaner.output.tail_sol  secondary_cleaner.output.tail_au  \
# 0                           8.764648                          2.606185
# 1                           9.001494                          2.488248
# 2                           8.842896                          2.458187
# 3                           9.122857                          2.322062
# 4                           8.871028                          2.330448
#
#    secondary_cleaner.state.floatbank2_a_air  \
# 0                                 25.853109
# 1                                 25.880539
# 2                                 26.005245
# 3                                 25.942508
# 4                                 26.024787
#
#    secondary_cleaner.state.floatbank2_a_level  \
# 0                                 -498.526489
# 1                                 -499.989656
# 2                                 -499.929616
# 3                                 -499.176749
# 4                                 -500.279091
#
#    secondary_cleaner.state.floatbank2_b_air  \
# 0                                 23.893660
# 1                                 23.889530
# 2                                 23.886657
# 3                                 23.955516
# 4                                 23.955345
#
#    secondary_cleaner.state.floatbank2_b_level  \
# 0                                 -501.406281
# 1                                 -500.372428
# 2                                 -499.951928
# 3                                 -499.848796
# 4                                 -500.593614
#
#    secondary_cleaner.state.floatbank3_a_air  \
# 0                                 23.961798
# 1                                 23.970550
# 2                                 23.913535
# 3                                 23.966838
# 4                                 23.985703
#
#    secondary_cleaner.state.floatbank3_a_level  \
# 0                                 -495.262817
# 1                                 -500.085473
# 2                                 -499.442343
# 3                                 -500.008812
# 4                                 -500.083811
#
#    secondary_cleaner.state.floatbank3_b_air  \
# 0                                 21.940409
# 1                                 22.085714
# 2                                 23.957717
# 3                                 23.954443
# 4                                 23.958945
#
#    secondary_cleaner.state.floatbank3_b_level  \
# 0                                 -499.340973
# 1                                 -499.446897
# 2                                 -499.901982
# 3                                 -499.944710
# 4                                 -499.990309
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 14.016835
# 1                                 13.992281
# 2                                 14.015015
# 3                                 14.036510
# 4                                 14.027298
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -502.488007
# 1                                 -505.503262
# 2                                 -502.520901
# 3                                 -500.857308
# 4                                 -499.838632
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                 12.099931
# 1                                 11.950531
# 2                                 11.912783
# 3                                 11.999550
# 4                                 11.953070
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -504.715942
# 1                                 -501.331529
# 2                                 -501.133383
# 3                                 -501.193686
# 4                                 -501.053894
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                  9.925633
# 1                                 10.039245
# 2                                 10.070913
# 3                                  9.970366
# 4                                  9.925709
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -498.310211
# 1                                 -500.169983
# 2                                 -500.129135
# 3                                 -499.201640
# 4                                 -501.686727
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                  8.079666
# 1                                  7.984757
# 2                                  8.013877
# 3                                  7.977324
# 4                                  7.894242
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.470978
# 1                                 -500.582168
# 2                                 -500.517572
# 3                                 -500.255908
# 4                                 -500.356035
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 14.151341
# 1                                 13.998353
# 2                                 14.028663
# 3                                 14.005551
# 4                                 13.996647
#
#    secondary_cleaner.state.floatbank6_a_level
# 0                                 -605.841980
# 1                                 -599.787184
# 2                                 -601.427363
# 3                                 -599.996129
# 4                                 -601.496691

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
#  8   final.output.tail_sol                               14144 non-null  float64
#  9   final.output.tail_au                                14149 non-null  float64
#  10  primary_cleaner.input.sulfate                       14129 non-null  float64
#  11  primary_cleaner.input.depressant                    14117 non-null  float64
#  12  primary_cleaner.input.feed_size                     14149 non-null  float64
#  13  primary_cleaner.input.xanthate                      14049 non-null  float64
#  14  primary_cleaner.output.concentrate_ag               14149 non-null  float64
#  15  primary_cleaner.output.concentrate_pb               14063 non-null  float64
#  16  primary_cleaner.output.concentrate_sol              13863 non-null  float64
#  17  primary_cleaner.output.concentrate_au               14149 non-null  float64
#  18  primary_cleaner.output.tail_ag                      14148 non-null  float64
#  19  primary_cleaner.output.tail_pb                      14134 non-null  float64
#  20  primary_cleaner.output.tail_sol                     14103 non-null  float64
#  21  primary_cleaner.output.tail_au                      14149 non-null  float64
#  22  primary_cleaner.state.floatbank8_a_air              14145 non-null  float64
#  23  primary_cleaner.state.floatbank8_a_level            14148 non-null  float64
#  24  primary_cleaner.state.floatbank8_b_air              14145 non-null  float64
#  25  primary_cleaner.state.floatbank8_b_level            14148 non-null  float64
#  26  primary_cleaner.state.floatbank8_c_air              14147 non-null  float64
#  27  primary_cleaner.state.floatbank8_c_level            14148 non-null  float64
#  28  primary_cleaner.state.floatbank8_d_air              14146 non-null  float64
#  29  primary_cleaner.state.floatbank8_d_level            14148 non-null  float64
#  30  rougher.calculation.sulfate_to_au_concentrate       14148 non-null  float64
#  31  rougher.calculation.floatbank10_sulfate_to_au_feed  14148 non-null  float64
#  32  rougher.calculation.floatbank11_sulfate_to_au_feed  14148 non-null  float64
#  33  rougher.calculation.au_pb_ratio                     14149 non-null  float64
#  34  rougher.input.feed_ag                               14149 non-null  float64
#  35  rougher.input.feed_pb                               14049 non-null  float64
#  36  rougher.input.feed_rate                             14141 non-null  float64
#  37  rougher.input.feed_size                             14005 non-null  float64
#  38  rougher.input.feed_sol                              14071 non-null  float64
#  39  rougher.input.feed_au                               14149 non-null  float64
#  40  rougher.input.floatbank10_sulfate                   14120 non-null  float64
#  41  rougher.input.floatbank10_xanthate                  14141 non-null  float64
#  42  rougher.input.floatbank11_sulfate                   14113 non-null  float64
#  43  rougher.input.floatbank11_xanthate                  13721 non-null  float64
#  44  rougher.output.concentrate_ag                       14149 non-null  float64
#  45  rougher.output.concentrate_pb                       14149 non-null  float64
#  46  rougher.output.concentrate_sol                      14127 non-null  float64
#  47  rougher.output.concentrate_au                       14149 non-null  float64
#  48  rougher.output.recovery                             14149 non-null  float64
#  49  rougher.output.tail_ag                              14148 non-null  float64
#  50  rougher.output.tail_pb                              14149 non-null  float64
#  51  rougher.output.tail_sol                             14149 non-null  float64
#  52  rougher.output.tail_au                              14149 non-null  float64
#  53  rougher.state.floatbank10_a_air                     14148 non-null  float64
#  54  rougher.state.floatbank10_a_level                   14148 non-null  float64
#  55  rougher.state.floatbank10_b_air                     14148 non-null  float64
#  56  rougher.state.floatbank10_b_level                   14148 non-null  float64
#  57  rougher.state.floatbank10_c_air                     14148 non-null  float64
#  58  rougher.state.floatbank10_c_level                   14148 non-null  float64
#  59  rougher.state.floatbank10_d_air                     14149 non-null  float64
#  60  rougher.state.floatbank10_d_level                   14149 non-null  float64
#  61  rougher.state.floatbank10_e_air                     13713 non-null  float64
#  62  rougher.state.floatbank10_e_level                   14149 non-null  float64
#  63  rougher.state.floatbank10_f_air                     14149 non-null  float64
#  64  rougher.state.floatbank10_f_level                   14149 non-null  float64
#  65  secondary_cleaner.output.tail_ag                    14147 non-null  float64
#  66  secondary_cleaner.output.tail_pb                    14139 non-null  float64
#  67  secondary_cleaner.output.tail_sol                   12544 non-null  float64
#  68  secondary_cleaner.output.tail_au                    14149 non-null  float64
#  69  secondary_cleaner.state.floatbank2_a_air            13932 non-null  float64
#  70  secondary_cleaner.state.floatbank2_a_level          14148 non-null  float64
#  71  secondary_cleaner.state.floatbank2_b_air            14128 non-null  float64
#  72  secondary_cleaner.state.floatbank2_b_level          14148 non-null  float64
#  73  secondary_cleaner.state.floatbank3_a_air            14145 non-null  float64
#  74  secondary_cleaner.state.floatbank3_a_level          14148 non-null  float64
#  75  secondary_cleaner.state.floatbank3_b_air            14148 non-null  float64
#  76  secondary_cleaner.state.floatbank3_b_level          14148 non-null  float64
#  77  secondary_cleaner.state.floatbank4_a_air            14143 non-null  float64
#  78  secondary_cleaner.state.floatbank4_a_level          14148 non-null  float64
#  79  secondary_cleaner.state.floatbank4_b_air            14148 non-null  float64
#  80  secondary_cleaner.state.floatbank4_b_level          14148 non-null  float64
#  81  secondary_cleaner.state.floatbank5_a_air            14148 non-null  float64
#  82  secondary_cleaner.state.floatbank5_a_level          14148 non-null  float64
#  83  secondary_cleaner.state.floatbank5_b_air            14148 non-null  float64
#  84  secondary_cleaner.state.floatbank5_b_level          14148 non-null  float64
#  85  secondary_cleaner.state.floatbank6_a_air            14147 non-null  float64
#  86  secondary_cleaner.state.floatbank6_a_level          14148 non-null  float64
# dtypes: float64(86), object(1)
# memory usage: 9.4+ MB

# %% [markdown]
# #### Тестовая выборка

# %%
url_test = 'https://code.s3.yandex.net/datasets/gold_recovery_test_new.csv'
data_test = pd.read_csv(url_test)
data_test.head()
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# 1                        0.990469                             1398.777912
# 2                        0.996043                             1398.493666
# 3                        0.863514                             1399.618111
# 4                        0.805575                             1401.268123
#
#    primary_cleaner.state.floatbank8_a_level  \
# 0                               -500.225577
# 1                               -500.057435
# 2                               -500.868360
# 3                               -498.863574
# 4                               -500.808305
#
#    primary_cleaner.state.floatbank8_b_air  \
# 0                             1399.144926
# 1                             1398.055362
# 2                             1398.860436
# 3                             1397.440120
# 4                             1398.128818
#
#    primary_cleaner.state.floatbank8_b_level  \
# 0                               -499.919735
# 1                               -499.778182
# 2                               -499.764529
# 3                               -499.211024
# 4                               -499.504543
#
#    primary_cleaner.state.floatbank8_c_air  \
# 0                             1400.102998
# 1                             1396.151033
# 2                             1398.075709
# 3                             1400.129303
# 4                             1402.172226
#
#    primary_cleaner.state.floatbank8_c_level  \
# 0                               -500.704369
# 1                               -499.240168
# 2                               -502.151509
# 3                               -498.355873
# 4                               -500.810606
#
#    primary_cleaner.state.floatbank8_d_air  \
# 0                             1399.001695
# 1                             1399.508091
# 2                             1399.497088
# 3                             1401.065165
# 4                             1399.480508
#
#    primary_cleaner.state.floatbank8_d_level  rougher.input.feed_ag  \
# 0                               -499.485144              13.128569
# 1                               -500.416324              13.036280
# 2                               -499.715479              13.138412
# 3                               -501.038738              12.400507
# 4                               -499.374053              11.327427
#
#    rougher.input.feed_pb  rougher.input.feed_rate  rougher.input.feed_size  \
# 0               5.636710               489.793655                62.710452
# 1               5.526065               490.104534                61.961163
# 2               5.426561               489.617969                66.903807
# 3               5.114758               476.618130                59.865919
# 4               4.767383               488.248117                63.315324
#
#    rougher.input.feed_sol  rougher.input.feed_au  \
# 0               42.022440              12.084103
# 1               41.187903              11.918977
# 2               42.546294              12.091332
# 3               41.060195              12.181597
# 4               41.269161              11.290425
#
#    rougher.input.floatbank10_sulfate  rougher.input.floatbank10_xanthate  \
# 0                          16.922877                            6.153479
# 1                          17.002532                            5.999043
# 2                          16.992520                            5.850632
# 3                          16.532144                            5.801935
# 4                          13.607257                            5.738081
#
#    rougher.input.floatbank11_sulfate  rougher.input.floatbank11_xanthate  \
# 0                          16.867518                            6.150709
# 1                          16.996063                            6.002315
# 2                          16.982096                            5.853594
# 3                          16.515277                            5.803657
# 4                          13.650053                            5.739634
#
#    rougher.state.floatbank10_a_air  rougher.state.floatbank10_a_level  \
# 0                      1001.849317                        -350.301265
# 1                       998.690785                        -350.425704
# 2                       998.516720                        -349.783538
# 3                      1000.276604                        -350.172597
# 4                       996.541302                        -350.562517
#
#    rougher.state.floatbank10_b_air  rougher.state.floatbank10_b_level  \
# 0                      1249.738612                        -399.107531
# 1                      1248.395457                        -399.946025
# 2                      1247.440748                        -400.264330
# 3                      1251.322675                        -398.655289
# 4                      1304.658848                        -399.511519
#
#    rougher.state.floatbank10_c_air  rougher.state.floatbank10_c_level  \
# 0                      1249.750520                        -399.396730
# 1                      1249.514451                        -399.630810
# 2                      1248.207204                        -401.074405
# 3                      1250.493702                        -399.746728
# 4                      1306.455515                        -399.050685
#
#    rougher.state.floatbank10_d_air  rougher.state.floatbank10_d_level  \
# 0                      1198.287855                        -399.488594
# 1                      1200.506459                        -399.942434
# 2                      1199.770026                        -400.790582
# 3                      1199.398691                        -397.503052
# 4                      1248.699349                        -400.876894
#
#    rougher.state.floatbank10_e_air  rougher.state.floatbank10_e_level  \
# 0                       999.472250                        -399.530962
# 1                      1000.002114                        -399.491528
# 2                       999.925519                        -399.236999
# 3                      1001.930679                        -400.437573
# 4                      1058.839106                        -398.988239
#
#    rougher.state.floatbank10_f_air  rougher.state.floatbank10_f_level  \
# 0                       949.566189                        -398.180807
# 1                       950.200009                        -405.787514
# 2                       950.320481                        -400.864340
# 3                       950.735324                        -399.802986
# 4                       949.645313                        -399.277632
#
#    secondary_cleaner.state.floatbank2_a_air  \
# 0                                 24.938200
# 1                                 24.923466
# 2                                 24.908732
# 3                                 24.893998
# 4                                 24.886905
#
#    secondary_cleaner.state.floatbank2_a_level  \
# 0                                 -500.490963
# 1                                 -499.813963
# 2                                 -500.304035
# 3                                 -499.382374
# 4                                 -499.357375
#
#    secondary_cleaner.state.floatbank2_b_air  \
# 0                                 14.947607
# 1                                 14.930873
# 2                                 14.996511
# 3                                 14.916674
# 4                                 14.979233
#
#    secondary_cleaner.state.floatbank2_b_level  \
# 0                                 -500.013837
# 1                                 -500.764452
# 2                                 -500.993821
# 3                                 -499.862299
# 4                                 -500.186804
#
#    secondary_cleaner.state.floatbank3_a_air  \
# 0                                 20.018166
# 1                                 19.988503
# 2                                 20.039689
# 3                                 20.031100
# 4                                 19.962364
#
#    secondary_cleaner.state.floatbank3_a_level  \
# 0                                 -450.395995
# 1                                 -450.114024
# 2                                 -450.263164
# 3                                 -449.372570
# 4                                 -450.638828
#
#    secondary_cleaner.state.floatbank3_b_air  \
# 0                                 13.987058
# 1                                 14.092981
# 2                                 14.077881
# 3                                 14.013968
# 4                                 14.009245
#
#    secondary_cleaner.state.floatbank3_b_level  \
# 0                                 -449.831513
# 1                                 -450.059163
# 2                                 -449.660997
# 3                                 -449.526900
# 4                                 -450.022259
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 12.023554
# 1                                 12.058140
# 2                                 11.962366
# 3                                 12.033091
# 4                                 12.025367
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -497.795834
# 1                                 -498.695773
# 2                                 -498.767484
# 3                                 -498.350935
# 4                                 -500.786497
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                  8.016656
# 1                                  8.130979
# 2                                  8.096893
# 3                                  8.074946
# 4                                  8.054678
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -501.289139
# 1                                 -499.634209
# 2                                 -500.827423
# 3                                 -499.474407
# 4                                 -500.397500
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                  7.946562
# 1                                  7.958270
# 2                                  8.071056
# 3                                  7.897085
# 4                                  8.107890
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -432.317850
# 1                                 -525.839648
# 2                                 -500.801673
# 3                                 -500.868509
# 4                                 -509.526725
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                  4.872511
# 1                                  4.878850
# 2                                  4.905125
# 3                                  4.931400
# 4                                  4.957674
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.037437
# 1                                 -500.162375
# 2                                 -499.828510
# 3                                 -499.963623
# 4                                 -500.360026
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 26.705889
# 1                                 25.019940
# 2                                 24.994862
# 3                                 24.948919
# 4                                 25.003331
#
#    secondary_cleaner.state.floatbank6_a_level
# 0                                 -499.709414
# 1                                 -499.819438
# 2                                 -500.622559
# 3                                 -498.709987
# 4                                 -500.856333

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5286 non-null   float64
#  2   primary_cleaner.input.depressant            5285 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5286 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
#  9   primary_cleaner.state.floatbank8_c_air      5290 non-null   float64
#  10  primary_cleaner.state.floatbank8_c_level    5290 non-null   float64
#  11  primary_cleaner.state.floatbank8_d_air      5290 non-null   float64
#  12  primary_cleaner.state.floatbank8_d_level    5290 non-null   float64
#  13  rougher.input.feed_ag                       5290 non-null   float64
#  14  rougher.input.feed_pb                       5290 non-null   float64
#  15  rougher.input.feed_rate                     5287 non-null   float64
#  16  rougher.input.feed_size                     5289 non-null   float64
#  17  rougher.input.feed_sol                      5269 non-null   float64
#  18  rougher.input.feed_au                       5290 non-null   float64
#  19  rougher.input.floatbank10_sulfate           5285 non-null   float64
#  20  rougher.input.floatbank10_xanthate          5290 non-null   float64
#  21  rougher.input.floatbank11_sulfate           5282 non-null   float64
#  22  rougher.input.floatbank11_xanthate          5265 non-null   float64
#  23  rougher.state.floatbank10_a_air             5290 non-null   float64
#  24  rougher.state.floatbank10_a_level           5290 non-null   float64
#  25  rougher.state.floatbank10_b_air             5290 non-null   float64
#  26  rougher.state.floatbank10_b_level           5290 non-null   float64
#  27  rougher.state.floatbank10_c_air             5290 non-null   float64
#  28  rougher.state.floatbank10_c_level           5290 non-null   float64
#  29  rougher.state.floatbank10_d_air             5290 non-null   float64
#  30  rougher.state.floatbank10_d_level           5290 non-null   float64
#  31  rougher.state.floatbank10_e_air             5290 non-null   float64
#  32  rougher.state.floatbank10_e_level           5290 non-null   float64
#  33  rougher.state.floatbank10_f_air             5290 non-null   float64
#  34  rougher.state.floatbank10_f_level           5290 non-null   float64
#  35  secondary_cleaner.state.floatbank2_a_air    5287 non-null   float64
#  36  secondary_cleaner.state.floatbank2_a_level  5290 non-null   float64
#  37  secondary_cleaner.state.floatbank2_b_air    5288 non-null   float64
#  38  secondary_cleaner.state.floatbank2_b_level  5290 non-null   float64
#  39  secondary_cleaner.state.floatbank3_a_air    5281 non-null   float64
#  40  secondary_cleaner.state.floatbank3_a_level  5290 non-null   float64
#  41  secondary_cleaner.state.floatbank3_b_air    5290 non-null   float64
#  42  secondary_cleaner.state.floatbank3_b_level  5290 non-null   float64
#  43  secondary_cleaner.state.floatbank4_a_air    5290 non-null   float64
#  44  secondary_cleaner.state.floatbank4_a_level  5290 non-null   float64
#  45  secondary_cleaner.state.floatbank4_b_air    5290 non-null   float64
#  46  secondary_cleaner.state.floatbank4_b_level  5290 non-null   float64
#  47  secondary_cleaner.state.floatbank5_a_air    5290 non-null   float64
#  48  secondary_cleaner.state.floatbank5_a_level  5290 non-null   float64
#  49  secondary_cleaner.state.floatbank5_b_air    5290 non-null   float64
#  50  secondary_cleaner.state.floatbank5_b_level  5290 non-null   float64
#  51  secondary_cleaner.state.floatbank6_a_air    5290 non-null   float64
#  52  secondary_cleaner.state.floatbank6_a_level  5290 non-null   float64
# dtypes: float64(52), object(1)
# memory usage: 2.1+ MB

# %% [markdown]
# #### Исходная выборка

# %%
url_init = 'https://code.s3.yandex.net/datasets/gold_recovery_full_new.csv'
data_init = pd.read_csv(url_init)
data_init.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# 2                    42.657501              68.116445             10.507046
# 3                    42.689819              68.347543             10.422762
# 4                    42.774141              66.927016             10.360302
#
#    final.output.tail_pb  final.output.tail_sol  final.output.tail_au  \
# 0              0.895447              16.904297              2.143149
# 1              0.927452              16.634514              2.224930
# 2              0.953716              16.208849              2.257889
# 3              0.883763              16.532835              2.146849
# 4              0.792826              16.525686              2.055292
#
#    primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# 0                     127.092003                         10.128295
# 1                     125.629232                         10.296251
# 2                     123.819808                         11.316280
# 3                     122.270188                         11.322140
# 4                     117.988169                         11.913613
#
#    primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  \
# 0                             7.25                        0.988759
# 1                             7.25                        1.002663
# 2                             7.25                        0.991265
# 3                             7.25                        0.996739
# 4                             7.25                        1.009869
#
#    primary_cleaner.output.concentrate_ag  \
# 0                               8.547551
# 1                               8.558743
# 2                               8.603505
# 3                               7.221879
# 4                               9.089428
#
#    primary_cleaner.output.concentrate_pb  \
# 0                              10.389648
# 1                              10.497069
# 2                              10.354494
# 3                               8.496563
# 4                               9.986786
#
#    primary_cleaner.output.concentrate_sol  \
# 0                               19.529297
# 1                               19.369147
# 2                               19.167579
# 3                               15.978538
# 4                               19.199864
#
#    primary_cleaner.output.concentrate_au  primary_cleaner.output.tail_ag  \
# 0                              34.174427                       14.936526
# 1                              34.118526                       16.250511
# 2                              33.969464                       16.491823
# 3                              28.260743                       16.024359
# 4                              33.044932                       16.480185
#
#    primary_cleaner.output.tail_pb  primary_cleaner.output.tail_sol  \
# 0                        2.534912                         7.476074
# 1                        3.049646                         6.733907
# 2                        3.124664                         6.471768
# 3                        2.960362                         6.843791
# 4                        3.112100                         6.550154
#
#    primary_cleaner.output.tail_au  primary_cleaner.state.floatbank8_a_air  \
# 0                        2.106679                             1549.775757
# 1                        2.353017                             1576.166671
# 2                        2.416800                             1601.556163
# 3                        2.262051                             1599.968720
# 4                        2.277073                             1601.339707
#
#    primary_cleaner.state.floatbank8_a_level  \
# 0                               -498.912140
# 1                               -500.904965
# 2                               -499.997791
# 3                               -500.951778
# 4                               -498.975456
#
#    primary_cleaner.state.floatbank8_b_air  \
# 0                             1551.434204
# 1                             1575.950626
# 2                             1600.386685
# 3                             1600.659236
# 4                             1601.437854
#
#    primary_cleaner.state.floatbank8_b_level  \
# 0                               -516.403442
# 1                               -499.865889
# 2                               -500.607762
# 3                               -499.677094
# 4                               -500.323246
#
#    primary_cleaner.state.floatbank8_c_air  \
# 0                             1549.873901
# 1                             1575.994189
# 2                             1602.003542
# 3                             1600.304144
# 4                             1599.581894
#
#    primary_cleaner.state.floatbank8_c_level  \
# 0                               -498.666595
# 1                               -499.315107
# 2                               -500.870069
# 3                               -500.727997
# 4                               -500.888152
#
#    primary_cleaner.state.floatbank8_d_air  \
# 0                             1554.367432
# 1                             1574.479259
# 2                             1599.541515
# 3                             1600.449520
# 4                             1602.649541
#
#    primary_cleaner.state.floatbank8_d_level  \
# 0                               -493.428131
# 1                               -498.931665
# 2                               -499.827444
# 3                               -500.052575
# 4                               -500.593010
#
#    rougher.calculation.sulfate_to_au_concentrate  \
# 0                                   41885.707031
# 1                                   42050.861809
# 2                                   42018.101184
# 3                                   42029.447991
# 4                                   42125.354245
#
#    rougher.calculation.floatbank10_sulfate_to_au_feed  \
# 0                                        3481.779053
# 1                                        3498.370979
# 2                                        3495.348910
# 3                                        3498.578313
# 4                                        3494.800771
#
#    rougher.calculation.floatbank11_sulfate_to_au_feed  \
# 0                                        3520.337158
# 1                                        3489.981857
# 2                                        3502.359819
# 3                                        3499.162912
# 4                                        3506.679315
#
#    rougher.calculation.au_pb_ratio  rougher.input.feed_ag  \
# 0                         2.838687               6.100378
# 1                         2.858998               6.161113
# 2                         2.945989               6.116455
# 3                         3.002340               6.043309
# 4                         3.169615               6.060915
#
#    rougher.input.feed_pb  rougher.input.feed_rate  rougher.input.feed_size  \
# 0               2.284912               523.546326                55.486599
# 1               2.266033               525.290581                57.278666
# 2               2.159622               530.026610                57.510649
# 3               2.037807               542.590390                57.792734
# 4               1.786875               540.531893                56.047189
#
#    rougher.input.feed_sol  rougher.input.feed_au  \
# 0               36.808594               6.486150
# 1               35.753385               6.478583
# 2               35.971630               6.362222
# 3               36.862241               6.118189
# 4               34.347666               5.663707
#
#    rougher.input.floatbank10_sulfate  rougher.input.floatbank10_xanthate  \
# 0                          11.986616                            6.007990
# 1                          11.971193                            6.005766
# 2                          11.920603                            6.197377
# 3                          11.630094                            6.203177
# 4                          10.957755                            6.198826
#
#    rougher.input.floatbank11_sulfate  rougher.input.floatbank11_xanthate  \
# 0                          11.836743                            6.005818
# 1                          11.996163                            6.012594
# 2                          11.920305                            6.204633
# 3                          11.692450                            6.196578
# 4                          10.960521                            6.194897
#
#    rougher.output.concentrate_ag  rougher.output.concentrate_pb  \
# 0                      11.500771                       7.101074
# 1                      11.615865                       7.278807
# 2                      11.695753                       7.216833
# 3                      11.915047                       7.175616
# 4                      12.411054                       7.240205
#
#    rougher.output.concentrate_sol  rougher.output.concentrate_au  \
# 0                       28.029297                      19.793808
# 1                       28.067063                      20.050975
# 2                       27.454037                      19.737170
# 3                       27.341277                      19.320810
# 4                       27.041023                      19.216101
#
#    rougher.output.recovery  rougher.output.tail_ag  rougher.output.tail_pb  \
# 0                87.107763                5.008018                0.508728
# 1                86.843261                4.955378                0.536689
# 2                86.842308                4.843460                0.546416
# 3                87.226430                4.655288                0.542525
# 4                86.688794                4.552800                0.515438
#
#    rougher.output.tail_sol  rougher.output.tail_au  \
# 0                19.154297                1.170244
# 1                18.965234                1.184827
# 2                18.808533                1.162562
# 3                19.330200                1.079755
# 4                19.267422                1.012642
#
#    rougher.state.floatbank10_a_air  rougher.state.floatbank10_a_level  \
# 0                       999.706909                        -404.066986
# 1                      1000.286398                        -400.065196
# 2                       999.719565                        -400.074028
# 3                       999.814770                        -400.200179
# 4                       999.678690                        -399.752729
#
#    rougher.state.floatbank10_b_air  rougher.state.floatbank10_b_level  \
# 0                      1603.011353                        -434.715027
# 1                      1600.754587                        -449.953435
# 2                      1599.337330                        -450.008530
# 3                      1600.059442                        -450.619948
# 4                      1600.208824                        -449.599614
#
#    rougher.state.floatbank10_c_air  rougher.state.floatbank10_c_level  \
# 0                      1602.375000                        -442.204468
# 1                      1600.479580                        -449.830646
# 2                      1599.672797                        -449.954491
# 3                      1600.012842                        -449.910497
# 4                      1600.357732                        -450.034364
#
#    rougher.state.floatbank10_d_air  rougher.state.floatbank10_d_level  \
# 0                      1598.937256                        -451.294128
# 1                      1600.527589                        -449.953649
# 2                      1599.849325                        -449.954185
# 3                      1597.725177                        -450.130127
# 4                      1599.759049                        -449.909799
#
#    rougher.state.floatbank10_e_air  rougher.state.floatbank10_e_level  \
# 0                      1404.472046                        -455.462982
# 1                      1399.227084                        -450.869848
# 2                      1399.180945                        -449.937588
# 3                      1400.943157                        -450.030142
# 4                      1401.560902                        -448.877187
#
#    rougher.state.floatbank10_f_air  rougher.state.floatbank10_f_level  \
# 0                      1416.354980                        -451.939636
# 1                      1399.719514                        -450.119001
# 2                      1400.316682                        -450.527147
# 3                      1400.234743                        -449.790835
# 4                      1401.160227                        -450.407128
#
#    secondary_cleaner.output.tail_ag  secondary_cleaner.output.tail_pb  \
# 0                         14.500184                          4.694824
# 1                         14.265474                          4.592547
# 2                         14.115662                          4.624775
# 3                         13.732071                          4.482453
# 4                         14.079996                          4.470737
#
#    secondary_cleaner.output.tail_sol  secondary_cleaner.output.tail_au  \
# 0                           8.764648                          2.606185
# 1                           9.001494                          2.488248
# 2                           8.842896                          2.458187
# 3                           9.122857                          2.322062
# 4                           8.871028                          2.330448
#
#    secondary_cleaner.state.floatbank2_a_air  \
# 0                                 25.853109
# 1                                 25.880539
# 2                                 26.005245
# 3                                 25.942508
# 4                                 26.024787
#
#    secondary_cleaner.state.floatbank2_a_level  \
# 0                                 -498.526489
# 1                                 -499.989656
# 2                                 -499.929616
# 3                                 -499.176749
# 4                                 -500.279091
#
#    secondary_cleaner.state.floatbank2_b_air  \
# 0                                 23.893660
# 1                                 23.889530
# 2                                 23.886657
# 3                                 23.955516
# 4                                 23.955345
#
#    secondary_cleaner.state.floatbank2_b_level  \
# 0                                 -501.406281
# 1                                 -500.372428
# 2                                 -499.951928
# 3                                 -499.848796
# 4                                 -500.593614
#
#    secondary_cleaner.state.floatbank3_a_air  \
# 0                                 23.961798
# 1                                 23.970550
# 2                                 23.913535
# 3                                 23.966838
# 4                                 23.985703
#
#    secondary_cleaner.state.floatbank3_a_level  \
# 0                                 -495.262817
# 1                                 -500.085473
# 2                                 -499.442343
# 3                                 -500.008812
# 4                                 -500.083811
#
#    secondary_cleaner.state.floatbank3_b_air  \
# 0                                 21.940409
# 1                                 22.085714
# 2                                 23.957717
# 3                                 23.954443
# 4                                 23.958945
#
#    secondary_cleaner.state.floatbank3_b_level  \
# 0                                 -499.340973
# 1                                 -499.446897
# 2                                 -499.901982
# 3                                 -499.944710
# 4                                 -499.990309
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 14.016835
# 1                                 13.992281
# 2                                 14.015015
# 3                                 14.036510
# 4                                 14.027298
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -502.488007
# 1                                 -505.503262
# 2                                 -502.520901
# 3                                 -500.857308
# 4                                 -499.838632
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                 12.099931
# 1                                 11.950531
# 2                                 11.912783
# 3                                 11.999550
# 4                                 11.953070
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -504.715942
# 1                                 -501.331529
# 2                                 -501.133383
# 3                                 -501.193686
# 4                                 -501.053894
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                  9.925633
# 1                                 10.039245
# 2                                 10.070913
# 3                                  9.970366
# 4                                  9.925709
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -498.310211
# 1                                 -500.169983
# 2                                 -500.129135
# 3                                 -499.201640
# 4                                 -501.686727
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                  8.079666
# 1                                  7.984757
# 2                                  8.013877
# 3                                  7.977324
# 4                                  7.894242
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.470978
# 1                                 -500.582168
# 2                                 -500.517572
# 3                                 -500.255908
# 4                                 -500.356035
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 14.151341
# 1                                 13.998353
# 2                                 14.028663
# 3                                 14.005551
# 4                                 13.996647
#
#    secondary_cleaner.state.floatbank6_a_level
# 0                                 -605.841980
# 1                                 -599.787184
# 2                                 -601.427363
# 3                                 -599.996129
# 4                                 -601.496691

# %%
data_init.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
#  8   final.output.tail_sol                               19433 non-null  float64
#  9   final.output.tail_au                                19439 non-null  float64
#  10  primary_cleaner.input.sulfate                       19415 non-null  float64
#  11  primary_cleaner.input.depressant                    19402 non-null  float64
#  12  primary_cleaner.input.feed_size                     19439 non-null  float64
#  13  primary_cleaner.input.xanthate                      19335 non-null  float64
#  14  primary_cleaner.output.concentrate_ag               19439 non-null  float64
#  15  primary_cleaner.output.concentrate_pb               19323 non-null  float64
#  16  primary_cleaner.output.concentrate_sol              19069 non-null  float64
#  17  primary_cleaner.output.concentrate_au               19439 non-null  float64
#  18  primary_cleaner.output.tail_ag                      19435 non-null  float64
#  19  primary_cleaner.output.tail_pb                      19418 non-null  float64
#  20  primary_cleaner.output.tail_sol                     19377 non-null  float64
#  21  primary_cleaner.output.tail_au                      19439 non-null  float64
#  22  primary_cleaner.state.floatbank8_a_air              19435 non-null  float64
#  23  primary_cleaner.state.floatbank8_a_level            19438 non-null  float64
#  24  primary_cleaner.state.floatbank8_b_air              19435 non-null  float64
#  25  primary_cleaner.state.floatbank8_b_level            19438 non-null  float64
#  26  primary_cleaner.state.floatbank8_c_air              19437 non-null  float64
#  27  primary_cleaner.state.floatbank8_c_level            19438 non-null  float64
#  28  primary_cleaner.state.floatbank8_d_air              19436 non-null  float64
#  29  primary_cleaner.state.floatbank8_d_level            19438 non-null  float64
#  30  rougher.calculation.sulfate_to_au_concentrate       19437 non-null  float64
#  31  rougher.calculation.floatbank10_sulfate_to_au_feed  19437 non-null  float64
#  32  rougher.calculation.floatbank11_sulfate_to_au_feed  19437 non-null  float64
#  33  rougher.calculation.au_pb_ratio                     19439 non-null  float64
#  34  rougher.input.feed_ag                               19439 non-null  float64
#  35  rougher.input.feed_pb                               19339 non-null  float64
#  36  rougher.input.feed_rate                             19428 non-null  float64
#  37  rougher.input.feed_size                             19294 non-null  float64
#  38  rougher.input.feed_sol                              19340 non-null  float64
#  39  rougher.input.feed_au                               19439 non-null  float64
#  40  rougher.input.floatbank10_sulfate                   19405 non-null  float64
#  41  rougher.input.floatbank10_xanthate                  19431 non-null  float64
#  42  rougher.input.floatbank11_sulfate                   19395 non-null  float64
#  43  rougher.input.floatbank11_xanthate                  18986 non-null  float64
#  44  rougher.output.concentrate_ag                       19439 non-null  float64
#  45  rougher.output.concentrate_pb                       19439 non-null  float64
#  46  rougher.output.concentrate_sol                      19416 non-null  float64
#  47  rougher.output.concentrate_au                       19439 non-null  float64
#  48  rougher.output.recovery                             19439 non-null  float64
#  49  rougher.output.tail_ag                              19438 non-null  float64
#  50  rougher.output.tail_pb                              19439 non-null  float64
#  51  rougher.output.tail_sol                             19439 non-null  float64
#  52  rougher.output.tail_au                              19439 non-null  float64
#  53  rougher.state.floatbank10_a_air                     19438 non-null  float64
#  54  rougher.state.floatbank10_a_level                   19438 non-null  float64
#  55  rougher.state.floatbank10_b_air                     19438 non-null  float64
#  56  rougher.state.floatbank10_b_level                   19438 non-null  float64
#  57  rougher.state.floatbank10_c_air                     19438 non-null  float64
#  58  rougher.state.floatbank10_c_level                   19438 non-null  float64
#  59  rougher.state.floatbank10_d_air                     19439 non-null  float64
#  60  rougher.state.floatbank10_d_level                   19439 non-null  float64
#  61  rougher.state.floatbank10_e_air                     19003 non-null  float64
#  62  rougher.state.floatbank10_e_level                   19439 non-null  float64
#  63  rougher.state.floatbank10_f_air                     19439 non-null  float64
#  64  rougher.state.floatbank10_f_level                   19439 non-null  float64
#  65  secondary_cleaner.output.tail_ag                    19437 non-null  float64
#  66  secondary_cleaner.output.tail_pb                    19427 non-null  float64
#  67  secondary_cleaner.output.tail_sol                   17691 non-null  float64
#  68  secondary_cleaner.output.tail_au                    19439 non-null  float64
#  69  secondary_cleaner.state.floatbank2_a_air            19219 non-null  float64
#  70  secondary_cleaner.state.floatbank2_a_level          19438 non-null  float64
#  71  secondary_cleaner.state.floatbank2_b_air            19416 non-null  float64
#  72  secondary_cleaner.state.floatbank2_b_level          19438 non-null  float64
#  73  secondary_cleaner.state.floatbank3_a_air            19426 non-null  float64
#  74  secondary_cleaner.state.floatbank3_a_level          19438 non-null  float64
#  75  secondary_cleaner.state.floatbank3_b_air            19438 non-null  float64
#  76  secondary_cleaner.state.floatbank3_b_level          19438 non-null  float64
#  77  secondary_cleaner.state.floatbank4_a_air            19433 non-null  float64
#  78  secondary_cleaner.state.floatbank4_a_level          19438 non-null  float64
#  79  secondary_cleaner.state.floatbank4_b_air            19438 non-null  float64
#  80  secondary_cleaner.state.floatbank4_b_level          19438 non-null  float64
#  81  secondary_cleaner.state.floatbank5_a_air            19438 non-null  float64
#  82  secondary_cleaner.state.floatbank5_a_level          19438 non-null  float64
#  83  secondary_cleaner.state.floatbank5_b_air            19438 non-null  float64
#  84  secondary_cleaner.state.floatbank5_b_level          19438 non-null  float64
#  85  secondary_cleaner.state.floatbank6_a_air            19437 non-null  float64
#  86  secondary_cleaner.state.floatbank6_a_level          19438 non-null  float64
# dtypes: float64(86), object(1)
# memory usage: 12.9+ MB

# %% [markdown]
# ## Вычисление эффективности обогащения
# На обучающей выборке для признака `rougher.output.recovery` выполняем проверку, насколько правильно рассчитана эффективности обогащения чернового концентрата.
#
# В расчёте эффективности обогащения чернового концентрата используются следующие значения:
# - `rougher.output.concentrate_au` - доля золота в концентрате после флотации/очистки
# - `rougher.input.feed_au` - доля золота в сырье/концентрате до флотации/очистки
# - `rougher.output.tail_au` - доля золота в отвальных хвостах после флотации/очистки

# %%
# Вычисление эффективности обогащения
recovery_calculated = ((data_train['rougher.output.concentrate_au'] * (data_train['rougher.input.feed_au'] - data_train['rougher.output.tail_au'])) / 
                       (data_train['rougher.input.feed_au'] * (data_train['rougher.output.concentrate_au'] - data_train['rougher.output.tail_au']))) * 100

# %% [markdown]
# Покажем `MAE` между расчётами и значением признака эффективности обогащения.

# %%
# Вычисление средней абсолютной ошибки (MAE)
mean_absolute_error(data_train['rougher.output.recovery'], recovery_calculated)
# Out:
# 9.73512347450521e-15

# %% [markdown]
# Значение средней абсолютной ошибки `MAE` очень близка к нулю (_9.73512347450521e-15_). Это предполагает точность выполненных расчётов эффективности обогащения. Таким образом, можно с уверенностью сказать, что эффективность обогащения золота была рассчитана правильно на обучающей выборке.

# %% [markdown]
# ## Подготовка тестовой выборки
# ### Анализ признаков, недоступных в тестовой выборке
# Проанализируем признаки, недоступные в тестовой выборке.
#
# <font color='red'><strong>Что это за параметры? К какому типу относятся?</strong></font>

# %%
set(data_init.columns) - set(data_test.columns) # параметры, отсутствующие в тестовой выборке
# Out:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
#  'rougher.output.tail_ag',
#  'rougher.output.tail_au',
#  'rougher.output.tail_pb',
#  'rougher.output.tail_sol',
#  'secondary_cleaner.output.tail_ag',
#  'secondary_cleaner.output.tail_au',
#  'secondary_cleaner.output.tail_pb',
#  'secondary_cleaner.output.tail_sol'}

# %% [markdown]
# В тестовой выборке отсутствуют следующие группы параметров:
# - содержащие описание финальных характеристик (блок _этап_ в тестовой выборке не содержит `final`) продукта (тип параметра `output`)
# - доля сырья после первичной очистки (этап `primary_cleaner` для типа параметра `output`)
# - доля в сырье/концентрате после флотации/очистки (параметр продукта (т.е. ПОСЛЕ того, как сырьё прошло этап очистки) `output` для этапа флотации `rougher`)
# - расчётные характеристики (тип параметра `calculation`) для флотации
# - доля продукта (тип параметра `output`) в отвальных хвостах (техпроцесс `tail`) после вторичной очистки (этап `secondary_cleaner`)
#
# Таким образом в тестовой выборке отсутствуют все параметры, относящиеся к типам `output` и `calculation`, т.е. всё относящееся к данным после обработки (когда из сырья получен продукт) и расчётные характеристики (расчётные характеристики в исходных данных представлены только для этапа флотации).
#
# Также наблюдаем подтверждение догадки об отсутствии в тестовой выборке двух целевых признаков, `rougher.output.recovery` и `final.output.recovery`, прогнозы по которым необходимо будет построить.

# %% [markdown]
# ### Дополнение тестовой выборки целевыми признаками
# Тестовую выборку необходимо дополнить двумя целевыми признаками, которые необходимо брать из исходного датасета

# %%
data_test_tar = data_test.merge(
    data_init[['rougher.output.recovery', 'final.output.recovery']], 
    left_index=True, 
    right_index=True, 
    how='left'
                                      )

data_test_tar.head()
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# 1                        0.990469                             1398.777912
# 2                        0.996043                             1398.493666
# 3                        0.863514                             1399.618111
# 4                        0.805575                             1401.268123
#
#    primary_cleaner.state.floatbank8_a_level  \
# 0                               -500.225577
# 1                               -500.057435
# 2                               -500.868360
# 3                               -498.863574
# 4                               -500.808305
#
#    primary_cleaner.state.floatbank8_b_air  \
# 0                             1399.144926
# 1                             1398.055362
# 2                             1398.860436
# 3                             1397.440120
# 4                             1398.128818
#
#    primary_cleaner.state.floatbank8_b_level  \
# 0                               -499.919735
# 1                               -499.778182
# 2                               -499.764529
# 3                               -499.211024
# 4                               -499.504543
#
#    primary_cleaner.state.floatbank8_c_air  \
# 0                             1400.102998
# 1                             1396.151033
# 2                             1398.075709
# 3                             1400.129303
# 4                             1402.172226
#
#    primary_cleaner.state.floatbank8_c_level  \
# 0                               -500.704369
# 1                               -499.240168
# 2                               -502.151509
# 3                               -498.355873
# 4                               -500.810606
#
#    primary_cleaner.state.floatbank8_d_air  \
# 0                             1399.001695
# 1                             1399.508091
# 2                             1399.497088
# 3                             1401.065165
# 4                             1399.480508
#
#    primary_cleaner.state.floatbank8_d_level  rougher.input.feed_ag  \
# 0                               -499.485144              13.128569
# 1                               -500.416324              13.036280
# 2                               -499.715479              13.138412
# 3                               -501.038738              12.400507
# 4                               -499.374053              11.327427
#
#    rougher.input.feed_pb  rougher.input.feed_rate  rougher.input.feed_size  \
# 0               5.636710               489.793655                62.710452
# 1               5.526065               490.104534                61.961163
# 2               5.426561               489.617969                66.903807
# 3               5.114758               476.618130                59.865919
# 4               4.767383               488.248117                63.315324
#
#    rougher.input.feed_sol  rougher.input.feed_au  \
# 0               42.022440              12.084103
# 1               41.187903              11.918977
# 2               42.546294              12.091332
# 3               41.060195              12.181597
# 4               41.269161              11.290425
#
#    rougher.input.floatbank10_sulfate  rougher.input.floatbank10_xanthate  \
# 0                          16.922877                            6.153479
# 1                          17.002532                            5.999043
# 2                          16.992520                            5.850632
# 3                          16.532144                            5.801935
# 4                          13.607257                            5.738081
#
#    rougher.input.floatbank11_sulfate  rougher.input.floatbank11_xanthate  \
# 0                          16.867518                            6.150709
# 1                          16.996063                            6.002315
# 2                          16.982096                            5.853594
# 3                          16.515277                            5.803657
# 4                          13.650053                            5.739634
#
#    rougher.state.floatbank10_a_air  rougher.state.floatbank10_a_level  \
# 0                      1001.849317                        -350.301265
# 1                       998.690785                        -350.425704
# 2                       998.516720                        -349.783538
# 3                      1000.276604                        -350.172597
# 4                       996.541302                        -350.562517
#
#    rougher.state.floatbank10_b_air  rougher.state.floatbank10_b_level  \
# 0                      1249.738612                        -399.107531
# 1                      1248.395457                        -399.946025
# 2                      1247.440748                        -400.264330
# 3                      1251.322675                        -398.655289
# 4                      1304.658848                        -399.511519
#
#    rougher.state.floatbank10_c_air  rougher.state.floatbank10_c_level  \
# 0                      1249.750520                        -399.396730
# 1                      1249.514451                        -399.630810
# 2                      1248.207204                        -401.074405
# 3                      1250.493702                        -399.746728
# 4                      1306.455515                        -399.050685
#
#    rougher.state.floatbank10_d_air  rougher.state.floatbank10_d_level  \
# 0                      1198.287855                        -399.488594
# 1                      1200.506459                        -399.942434
# 2                      1199.770026                        -400.790582
# 3                      1199.398691                        -397.503052
# 4                      1248.699349                        -400.876894
#
#    rougher.state.floatbank10_e_air  rougher.state.floatbank10_e_level  \
# 0                       999.472250                        -399.530962
# 1                      1000.002114                        -399.491528
# 2                       999.925519                        -399.236999
# 3                      1001.930679                        -400.437573
# 4                      1058.839106                        -398.988239
#
#    rougher.state.floatbank10_f_air  rougher.state.floatbank10_f_level  \
# 0                       949.566189                        -398.180807
# 1                       950.200009                        -405.787514
# 2                       950.320481                        -400.864340
# 3                       950.735324                        -399.802986
# 4                       949.645313                        -399.277632
#
#    secondary_cleaner.state.floatbank2_a_air  \
# 0                                 24.938200
# 1                                 24.923466
# 2                                 24.908732
# 3                                 24.893998
# 4                                 24.886905
#
#    secondary_cleaner.state.floatbank2_a_level  \
# 0                                 -500.490963
# 1                                 -499.813963
# 2                                 -500.304035
# 3                                 -499.382374
# 4                                 -499.357375
#
#    secondary_cleaner.state.floatbank2_b_air  \
# 0                                 14.947607
# 1                                 14.930873
# 2                                 14.996511
# 3                                 14.916674
# 4                                 14.979233
#
#    secondary_cleaner.state.floatbank2_b_level  \
# 0                                 -500.013837
# 1                                 -500.764452
# 2                                 -500.993821
# 3                                 -499.862299
# 4                                 -500.186804
#
#    secondary_cleaner.state.floatbank3_a_air  \
# 0                                 20.018166
# 1                                 19.988503
# 2                                 20.039689
# 3                                 20.031100
# 4                                 19.962364
#
#    secondary_cleaner.state.floatbank3_a_level  \
# 0                                 -450.395995
# 1                                 -450.114024
# 2                                 -450.263164
# 3                                 -449.372570
# 4                                 -450.638828
#
#    secondary_cleaner.state.floatbank3_b_air  \
# 0                                 13.987058
# 1                                 14.092981
# 2                                 14.077881
# 3                                 14.013968
# 4                                 14.009245
#
#    secondary_cleaner.state.floatbank3_b_level  \
# 0                                 -449.831513
# 1                                 -450.059163
# 2                                 -449.660997
# 3                                 -449.526900
# 4                                 -450.022259
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 12.023554
# 1                                 12.058140
# 2                                 11.962366
# 3                                 12.033091
# 4                                 12.025367
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -497.795834
# 1                                 -498.695773
# 2                                 -498.767484
# 3                                 -498.350935
# 4                                 -500.786497
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                  8.016656
# 1                                  8.130979
# 2                                  8.096893
# 3                                  8.074946
# 4                                  8.054678
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -501.289139
# 1                                 -499.634209
# 2                                 -500.827423
# 3                                 -499.474407
# 4                                 -500.397500
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                  7.946562
# 1                                  7.958270
# 2                                  8.071056
# 3                                  7.897085
# 4                                  8.107890
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -432.317850
# 1                                 -525.839648
# 2                                 -500.801673
# 3                                 -500.868509
# 4                                 -509.526725
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                  4.872511
# 1                                  4.878850
# 2                                  4.905125
# 3                                  4.931400
# 4                                  4.957674
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.037437
# 1                                 -500.162375
# 2                                 -499.828510
# 3                                 -499.963623
# 4                                 -500.360026
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 26.705889
# 1                                 25.019940
# 2                                 24.994862
# 3                                 24.948919
# 4                                 25.003331
#
#    secondary_cleaner.state.floatbank6_a_level  rougher.output.recovery  \
# 0                                 -499.709414                87.107763
# 1                                 -499.819438                86.843261
# 2                                 -500.622559                86.842308
# 3                                 -498.709987                87.226430
# 4                                 -500.856333                86.688794
#
#    final.output.recovery
# 0              70.541216
# 1              69.266198
# 2              68.116445
# 3              68.347543
# 4              66.927016

# %%
data_test_tar.shape
# Out:
# (5290, 55)

# %% [markdown]
# В тестовой выборке фигурирует 55 признаков и более 5К строк.

# %% [markdown]
# ## Подготовка обучающей выборки
# <font color='red'><strong>train уменьшить до 53+2 признаков, как в test</strong></font>
#
# Обучающая выборка содержит ровным счётом те же самые признаки, что и исходный датасет. Однако для непосредственно обучения и последующего тестирования нам необходимо идентичное число признаков в тестовом и обучающем датасетах. Следовательно избавимся от "лишних" признаков.

# %%
difference_columns = set(data_init.columns) - set(data_test_tar.columns)
data_train_clr = data_train.drop(columns=difference_columns)
data_train_clr.shape
# Out:
# (14149, 55)

# %% [markdown]
# В итоге в обучающей выборке фигурирует более 14К строк и 55 признаков. Процент строк тестовой выборки в отношении к всем рассматриваемым строкам составляет более 27%.

# %% [markdown]
# ## Предобработка данных
# Предобработку данных будем делать для обучающей выборки <font color='red'><strong>и возможно для тестовой</strong></font>.

# %% [markdown]
# ### Определение и устранение аномальных значений
# <font color='red'><strong>и возможно для тестовой аномалиями для удаления считал только 0% и 100% концентрации. Смотрел по гистограмме. Хотя boxplot также просили построить. По итогу осталось больше 95% данных</strong></font>
#
# Построим диаграмму `ящик с усами` для каждого из признаков, входящих в обучающую выборку. Нам это даст возможность визуально оценить, значения каких параметров можно отнести к выбросам и избавиться от них, сделав, тем самым, очистку данных.

# %%
fig, axes = plt.subplots(nrows=(len(data_train_clr.columns)-1)//5+1, ncols=5, figsize=(20, 45))

for i, column in enumerate(data_train_clr.columns):
    if column != 'date':
        row = i // axes.shape[1]
        col = i % axes.shape[1]
        data_train_clr.boxplot(column=column, ax=axes[row, col])

plt.tight_layout()
plt.show()

# %% [markdown]
# По графикам на обучающей выборке можно сделать заключение о наличии выбросов практически для каждого из параметров.
# Удалим значения 0 и 100 для признаков `rougher.output.recovery` и `final.output.recovery`, а затем посмотрим на иные результаты. Что характерно, для `rougher.output.recovery` 100 не является выбросом, а находится на самой верхней границе диаграммы. Но очевидно, что доля продукта после флотации не может составлять 100%, поэтому от такого значения избавимся. Посмотрим график в более крупном масштабе и примем решение.

# %%
fig, ax = plt.subplots(figsize=(20, 5))

data_train_clr.boxplot(column=['final.output.recovery', 'rougher.output.recovery'], ax=ax, vert=False)
ax.set_title('Обогащение продукта для целевых признаков')
ax.set_xticks(range(0, 101, 4))
plt.show()

# %%
data_train_clr = data_train_clr[(data_train_clr['final.output.recovery'] > 50) & (data_train_clr['final.output.recovery'] < 88)]
data_train_clr = data_train_clr[(data_train_clr['rougher.output.recovery'] > 66) & (data_train_clr['rougher.output.recovery'] != 100)]

# %% [markdown]
# Для признаков, входящих в тестовую выборку, построим аналогичный boxplot, а затем на основании его избавимся от выбросов в целевых признаках.

# %%
fig, ax = plt.subplots(figsize=(20, 5))

data_test_tar.boxplot(column=['final.output.recovery', 'rougher.output.recovery'], ax=ax, vert=False)
ax.set_title('Обогащение продукта для целевых признаков')
ax.set_xticks(range(0, 101, 4))
plt.show()

# %%
data_test_tar = data_test_tar[(data_test_tar['final.output.recovery'] > 46) & (data_test_tar['final.output.recovery'] < 84)]
data_test_tar = data_test_tar[(data_test_tar['rougher.output.recovery'] > 60) & (data_test_tar['rougher.output.recovery'] != 100)]

# %% [markdown]
# ### Определение пропусков
# <font color='red'><strong>Замена NaN на очищенных выборках (train и test). Перебирал разные варианты 0 / bfill / ffill / interpolate - особой разницы не увидел. Но написать какое-то обоснование нужно.</font></strong>
#
# Подсчитаем количество пропусков для признаков в тестовой и обучающей выборках.

# %% [markdown]
# #### Определение пропусков в обучающей выборке

# %%
data_train_clr.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# rougher.state.floatbank10_e_air             356
# rougher.input.floatbank11_xanthate          321
# secondary_cleaner.state.floatbank2_a_air    186
# rougher.input.feed_size                     124
# primary_cleaner.input.xanthate               71
# rougher.input.feed_pb                        60
# rougher.input.feed_sol                       36
# rougher.input.floatbank11_sulfate            10
# primary_cleaner.input.depressant              9
# rougher.input.feed_rate                       5
# dtype: int64

# %%
print(f'Суммарное число пропусков {data_train_clr.isnull().sum().sum()} из {data_train_clr.shape[0]} строк обучающей выборки')
# Out:
# Суммарное число пропусков 1230 из 12865 строк обучающей выборки

# %% [markdown]
# Как видно, процент пропусков для каждого из признаков достаточно мал. Наибольшее значение пропусков для параметра `rougher.state.floatbank10_e_air` в обучающей выборке составляет менее 3% от общего числа строк. Однако суммарное число пропусков в обучающей выборке составляет около 10%. Поэтому заполним пропущенные значения на основе ближайших известных значений. Тем самым результат будет "более плавным", основываясь на соседних известных точках. Использование _bfill/ffill_ может привести к заполнению пропусков в ряде случаев значениями, выходящими за границы верхней и нижней границ. А мы как раз от этого избавлялись.

# %%
data_train_clr = data_train_clr.interpolate(method='linear', inplace=False)

# %% [markdown]
# #### Определение пропусков в тестовой выборке

# %%
data_test_tar.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# rougher.input.floatbank11_xanthate          25
# rougher.input.feed_sol                      21
# secondary_cleaner.state.floatbank3_a_air     9
# rougher.input.floatbank11_sulfate            8
# primary_cleaner.input.depressant             5
# rougher.input.floatbank10_sulfate            5
# primary_cleaner.input.xanthate               4
# primary_cleaner.input.sulfate                4
# secondary_cleaner.state.floatbank2_a_air     3
# rougher.input.feed_rate                      3
# dtype: int64

# %%
print(f'Суммарное число пропусков {data_test_tar.isnull().sum().sum()} из {data_test_tar.shape[0]} строк тестовой выборки')
# Out:
# Суммарное число пропусков 90 из 5290 строк тестовой выборки

# %% [markdown]
# Число пропусков крайне мало по сравнению с общим числом строк и составляет суммарно менее 2%. Поэтому имеет смысл попросту удалить из датасета.

# %%
data_test_tar.dropna(inplace=True)

# %% [markdown]
# ### Устранение неявных дубликатов
# <font color='red'><strong>Нужно ли???</font></strong>

# %% [markdown]
# ## Подсчёт корреляции
# <font color='red'><strong>Дополнить и сделать выводы</font></strong>

# %%
#pd.set_option('display.max_columns', None)
correlation_matrix = data_train_clr.drop('date', axis=1).corr()
correlation_matrix
# Out:
#                                             final.output.recovery  \
# final.output.recovery                                    1.000000
# primary_cleaner.input.sulfate                            0.392178
# primary_cleaner.input.depressant                         0.167652
# primary_cleaner.input.feed_size                          0.033078
# primary_cleaner.input.xanthate                           0.234987
# ...                                                           ...
# secondary_cleaner.state.floatbank5_a_level               0.026035
# secondary_cleaner.state.floatbank5_b_air                 0.054670
# secondary_cleaner.state.floatbank5_b_level               0.030820
# secondary_cleaner.state.floatbank6_a_air                -0.066191
# secondary_cleaner.state.floatbank6_a_level              -0.035935
#
#                                             primary_cleaner.input.sulfate  \
# final.output.recovery                                            0.392178
# primary_cleaner.input.sulfate                                    1.000000
# primary_cleaner.input.depressant                                 0.482953
# primary_cleaner.input.feed_size                                  0.148718
# primary_cleaner.input.xanthate                                   0.244896
# ...                                                                   ...
# secondary_cleaner.state.floatbank5_a_level                      -0.033252
# secondary_cleaner.state.floatbank5_b_air                        -0.011143
# secondary_cleaner.state.floatbank5_b_level                      -0.035024
# secondary_cleaner.state.floatbank6_a_air                        -0.124292
# secondary_cleaner.state.floatbank6_a_level                      -0.150123
#
#                                             primary_cleaner.input.depressant  \
# final.output.recovery                                               0.167652
# primary_cleaner.input.sulfate                                       0.482953
# primary_cleaner.input.depressant                                    1.000000
# primary_cleaner.input.feed_size                                     0.165765
# primary_cleaner.input.xanthate                                      0.263275
# ...                                                                      ...
# secondary_cleaner.state.floatbank5_a_level                         -0.159159
# secondary_cleaner.state.floatbank5_b_air                           -0.233767
# secondary_cleaner.state.floatbank5_b_level                         -0.151554
# secondary_cleaner.state.floatbank6_a_air                           -0.175383
# secondary_cleaner.state.floatbank6_a_level                         -0.135981
#
#                                             primary_cleaner.input.feed_size  \
# final.output.recovery                                              0.033078
# primary_cleaner.input.sulfate                                      0.148718
# primary_cleaner.input.depressant                                   0.165765
# primary_cleaner.input.feed_size                                    1.000000
# primary_cleaner.input.xanthate                                    -0.023005
# ...                                                                     ...
# secondary_cleaner.state.floatbank5_a_level                         0.122984
# secondary_cleaner.state.floatbank5_b_air                          -0.218621
# secondary_cleaner.state.floatbank5_b_level                         0.129286
# secondary_cleaner.state.floatbank6_a_air                           0.152878
# secondary_cleaner.state.floatbank6_a_level                         0.065068
#
#                                             primary_cleaner.input.xanthate  \
# final.output.recovery                                             0.234987
# primary_cleaner.input.sulfate                                     0.244896
# primary_cleaner.input.depressant                                  0.263275
# primary_cleaner.input.feed_size                                  -0.023005
# primary_cleaner.input.xanthate                                    1.000000
# ...                                                                    ...
# secondary_cleaner.state.floatbank5_a_level                       -0.210137
# secondary_cleaner.state.floatbank5_b_air                         -0.105689
# secondary_cleaner.state.floatbank5_b_level                       -0.211460
# secondary_cleaner.state.floatbank6_a_air                         -0.237701
# secondary_cleaner.state.floatbank6_a_level                       -0.078515
#
#                                             primary_cleaner.state.floatbank8_a_air  \
# final.output.recovery                                                     0.173615
# primary_cleaner.input.sulfate                                             0.021743
# primary_cleaner.input.depressant                                         -0.148926
# primary_cleaner.input.feed_size                                          -0.138426
# primary_cleaner.input.xanthate                                            0.061262
# ...                                                                            ...
# secondary_cleaner.state.floatbank5_a_level                                0.245383
# secondary_cleaner.state.floatbank5_b_air                                  0.498036
# secondary_cleaner.state.floatbank5_b_level                                0.251554
# secondary_cleaner.state.floatbank6_a_air                                  0.306304
# secondary_cleaner.state.floatbank6_a_level                                0.053818
#
#                                             primary_cleaner.state.floatbank8_a_level  \
# final.output.recovery                                                       0.069803
# primary_cleaner.input.sulfate                                              -0.037689
# primary_cleaner.input.depressant                                            0.131777
# primary_cleaner.input.feed_size                                             0.069070
# primary_cleaner.input.xanthate                                              0.023333
# ...                                                                              ...
# secondary_cleaner.state.floatbank5_a_level                                  0.100792
# secondary_cleaner.state.floatbank5_b_air                                    0.064366
# secondary_cleaner.state.floatbank5_b_level                                  0.089537
# secondary_cleaner.state.floatbank6_a_air                                    0.175175
# secondary_cleaner.state.floatbank6_a_level                                  0.184128
#
#                                             primary_cleaner.state.floatbank8_b_air  \
# final.output.recovery                                                     0.189535
# primary_cleaner.input.sulfate                                             0.039726
# primary_cleaner.input.depressant                                         -0.113435
# primary_cleaner.input.feed_size                                          -0.140699
# primary_cleaner.input.xanthate                                            0.087363
# ...                                                                            ...
# secondary_cleaner.state.floatbank5_a_level                                0.248782
# secondary_cleaner.state.floatbank5_b_air                                  0.483466
# secondary_cleaner.state.floatbank5_b_level                                0.257735
# secondary_cleaner.state.floatbank6_a_air                                  0.304833
# secondary_cleaner.state.floatbank6_a_level                                0.029969
#
#                                             primary_cleaner.state.floatbank8_b_level  \
# final.output.recovery                                                       0.066568
# primary_cleaner.input.sulfate                                              -0.032282
# primary_cleaner.input.depressant                                            0.147731
# primary_cleaner.input.feed_size                                             0.071328
# primary_cleaner.input.xanthate                                              0.020097
# ...                                                                              ...
# secondary_cleaner.state.floatbank5_a_level                                  0.113837
# secondary_cleaner.state.floatbank5_b_air                                    0.042596
# secondary_cleaner.state.floatbank5_b_level                                  0.102915
# secondary_cleaner.state.floatbank6_a_air                                    0.170949
# secondary_cleaner.state.floatbank6_a_level                                  0.188286
#
#                                             primary_cleaner.state.floatbank8_c_air  \
# final.output.recovery                                                     0.179850
# primary_cleaner.input.sulfate                                             0.040200
# primary_cleaner.input.depressant                                         -0.126732
# primary_cleaner.input.feed_size                                          -0.165450
# primary_cleaner.input.xanthate                                            0.056036
# ...                                                                            ...
# secondary_cleaner.state.floatbank5_a_level                                0.210458
# secondary_cleaner.state.floatbank5_b_air                                  0.554915
# secondary_cleaner.state.floatbank5_b_level                                0.226071
# secondary_cleaner.state.floatbank6_a_air                                  0.273469
# secondary_cleaner.state.floatbank6_a_level                                0.040121
#
#                                             primary_cleaner.state.floatbank8_c_level  \
# final.output.recovery                                                       0.065895
# primary_cleaner.input.sulfate                                              -0.024804
# primary_cleaner.input.depressant                                            0.153190
# primary_cleaner.input.feed_size                                             0.068552
# primary_cleaner.input.xanthate                                              0.019080
# ...                                                                              ...
# secondary_cleaner.state.floatbank5_a_level                                  0.113455
# secondary_cleaner.state.floatbank5_b_air                                    0.042407
# secondary_cleaner.state.floatbank5_b_level                                  0.096883
# secondary_cleaner.state.floatbank6_a_air                                    0.167111
# secondary_cleaner.state.floatbank6_a_level                                  0.188625
#
#                                             primary_cleaner.state.floatbank8_d_air  \
# final.output.recovery                                                     0.052504
# primary_cleaner.input.sulfate                                             0.112480
# primary_cleaner.input.depressant                                         -0.098256
# primary_cleaner.input.feed_size                                          -0.199890
# primary_cleaner.input.xanthate                                            0.110077
# ...                                                                            ...
# secondary_cleaner.state.floatbank5_a_level                                0.055497
# secondary_cleaner.state.floatbank5_b_air                                  0.251304
# secondary_cleaner.state.floatbank5_b_level                                0.066160
# secondary_cleaner.state.floatbank6_a_air                                  0.024703
# secondary_cleaner.state.floatbank6_a_level                               -0.111366
#
#                                             primary_cleaner.state.floatbank8_d_level  \
# final.output.recovery                                                       0.020603
# primary_cleaner.input.sulfate                                              -0.022156
# primary_cleaner.input.depressant                                            0.081888
# primary_cleaner.input.feed_size                                             0.063210
# primary_cleaner.input.xanthate                                             -0.021249
# ...                                                                              ...
# secondary_cleaner.state.floatbank5_a_level                                  0.036118
# secondary_cleaner.state.floatbank5_b_air                                    0.015291
# secondary_cleaner.state.floatbank5_b_level                                  0.020285
# secondary_cleaner.state.floatbank6_a_air                                    0.089371
# secondary_cleaner.state.floatbank6_a_level                                  0.173075
#
#                                             rougher.input.feed_ag  \
# final.output.recovery                                    0.389423
# primary_cleaner.input.sulfate                            0.559824
# primary_cleaner.input.depressant                         0.493351
# primary_cleaner.input.feed_size                          0.112748
# primary_cleaner.input.xanthate                           0.250120
# ...                                                           ...
# secondary_cleaner.state.floatbank5_a_level               0.159617
# secondary_cleaner.state.floatbank5_b_air                -0.017298
# secondary_cleaner.state.floatbank5_b_level               0.164006
# secondary_cleaner.state.floatbank6_a_air                 0.033784
# secondary_cleaner.state.floatbank6_a_level              -0.113173
#
#                                             rougher.input.feed_pb  \
# final.output.recovery                                    0.231677
# primary_cleaner.input.sulfate                            0.571250
# primary_cleaner.input.depressant                         0.283178
# primary_cleaner.input.feed_size                         -0.109510
# primary_cleaner.input.xanthate                          -0.027263
# ...                                                           ...
# secondary_cleaner.state.floatbank5_a_level               0.019357
# secondary_cleaner.state.floatbank5_b_air                 0.148350
# secondary_cleaner.state.floatbank5_b_level               0.020364
# secondary_cleaner.state.floatbank6_a_air                -0.051538
# secondary_cleaner.state.floatbank6_a_level              -0.120863
#
#                                             rougher.input.feed_rate  \
# final.output.recovery                                      0.145190
# primary_cleaner.input.sulfate                              0.272000
# primary_cleaner.input.depressant                           0.128612
# primary_cleaner.input.feed_size                            0.053720
# primary_cleaner.input.xanthate                             0.269913
# ...                                                             ...
# secondary_cleaner.state.floatbank5_a_level                -0.279721
# secondary_cleaner.state.floatbank5_b_air                  -0.185087
# secondary_cleaner.state.floatbank5_b_level                -0.303438
# secondary_cleaner.state.floatbank6_a_air                  -0.330554
# secondary_cleaner.state.floatbank6_a_level                 0.024993
#
#                                             rougher.input.feed_size  \
# final.output.recovery                                      0.107238
# primary_cleaner.input.sulfate                             -0.033517
# primary_cleaner.input.depressant                          -0.032588
# primary_cleaner.input.feed_size                           -0.131801
# primary_cleaner.input.xanthate                             0.102056
# ...                                                             ...
# secondary_cleaner.state.floatbank5_a_level                -0.073183
# secondary_cleaner.state.floatbank5_b_air                   0.037128
# secondary_cleaner.state.floatbank5_b_level                -0.079186
# secondary_cleaner.state.floatbank6_a_air                  -0.157688
# secondary_cleaner.state.floatbank6_a_level                 0.076515
#
#                                             rougher.input.feed_sol  \
# final.output.recovery                                     0.233026
# primary_cleaner.input.sulfate                             0.357198
# primary_cleaner.input.depressant                          0.055123
# primary_cleaner.input.feed_size                           0.047060
# primary_cleaner.input.xanthate                            0.169709
# ...                                                            ...
# secondary_cleaner.state.floatbank5_a_level               -0.130655
# secondary_cleaner.state.floatbank5_b_air                  0.126733
# secondary_cleaner.state.floatbank5_b_level               -0.130148
# secondary_cleaner.state.floatbank6_a_air                 -0.162663
# secondary_cleaner.state.floatbank6_a_level               -0.023804
#
#                                             rougher.input.feed_au  \
# final.output.recovery                                    0.356981
# primary_cleaner.input.sulfate                            0.623291
# primary_cleaner.input.depressant                         0.432296
# primary_cleaner.input.feed_size                          0.125844
# primary_cleaner.input.xanthate                           0.139645
# ...                                                           ...
# secondary_cleaner.state.floatbank5_a_level               0.177800
# secondary_cleaner.state.floatbank5_b_air                -0.045647
# secondary_cleaner.state.floatbank5_b_level               0.182099
# secondary_cleaner.state.floatbank6_a_air                 0.057089
# secondary_cleaner.state.floatbank6_a_level              -0.164819
#
#                                             rougher.input.floatbank10_sulfate  \
# final.output.recovery                                               -0.043971
# primary_cleaner.input.sulfate                                        0.410423
# primary_cleaner.input.depressant                                     0.104845
# primary_cleaner.input.feed_size                                      0.106181
# primary_cleaner.input.xanthate                                      -0.164739
# ...                                                                       ...
# secondary_cleaner.state.floatbank5_a_level                           0.024632
# secondary_cleaner.state.floatbank5_b_air                            -0.034907
# secondary_cleaner.state.floatbank5_b_level                           0.022466
# secondary_cleaner.state.floatbank6_a_air                            -0.032354
# secondary_cleaner.state.floatbank6_a_level                          -0.041587
#
#                                             rougher.input.floatbank10_xanthate  \
# final.output.recovery                                                 0.313012
# primary_cleaner.input.sulfate                                         0.342362
# primary_cleaner.input.depressant                                      0.374960
# primary_cleaner.input.feed_size                                      -0.029724
# primary_cleaner.input.xanthate                                        0.382344
# ...                                                                        ...
# secondary_cleaner.state.floatbank5_a_level                           -0.188063
# secondary_cleaner.state.floatbank5_b_air                             -0.187114
# secondary_cleaner.state.floatbank5_b_level                           -0.199281
# secondary_cleaner.state.floatbank6_a_air                             -0.356893
# secondary_cleaner.state.floatbank6_a_level                            0.011775
#
#                                             rougher.input.floatbank11_sulfate  \
# final.output.recovery                                               -0.003193
# primary_cleaner.input.sulfate                                        0.520752
# primary_cleaner.input.depressant                                     0.222880
# primary_cleaner.input.feed_size                                      0.169197
# primary_cleaner.input.xanthate                                      -0.067703
# ...                                                                       ...
# secondary_cleaner.state.floatbank5_a_level                          -0.032846
# secondary_cleaner.state.floatbank5_b_air                            -0.116206
# secondary_cleaner.state.floatbank5_b_level                          -0.036561
# secondary_cleaner.state.floatbank6_a_air                            -0.078264
# secondary_cleaner.state.floatbank6_a_level                          -0.054778
#
#                                             rougher.input.floatbank11_xanthate  \
# final.output.recovery                                                 0.268918
# primary_cleaner.input.sulfate                                         0.390283
# primary_cleaner.input.depressant                                      0.421343
# primary_cleaner.input.feed_size                                       0.026394
# primary_cleaner.input.xanthate                                        0.380548
# ...                                                                        ...
# secondary_cleaner.state.floatbank5_a_level                           -0.204375
# secondary_cleaner.state.floatbank5_b_air                             -0.230261
# secondary_cleaner.state.floatbank5_b_level                           -0.210029
# secondary_cleaner.state.floatbank6_a_air                             -0.332650
# secondary_cleaner.state.floatbank6_a_level                           -0.006017
#
#                                             rougher.output.recovery  \
# final.output.recovery                                      0.624749
# primary_cleaner.input.sulfate                              0.405469
# primary_cleaner.input.depressant                           0.114965
# primary_cleaner.input.feed_size                           -0.096890
# primary_cleaner.input.xanthate                             0.184100
# ...                                                             ...
# secondary_cleaner.state.floatbank5_a_level                -0.019703
# secondary_cleaner.state.floatbank5_b_air                   0.243824
# secondary_cleaner.state.floatbank5_b_level                -0.003776
# secondary_cleaner.state.floatbank6_a_air                  -0.143073
# secondary_cleaner.state.floatbank6_a_level                -0.063786
#
#                                             rougher.state.floatbank10_a_air  \
# final.output.recovery                                              0.281217
# primary_cleaner.input.sulfate                                      0.191304
# primary_cleaner.input.depressant                                  -0.030947
# primary_cleaner.input.feed_size                                   -0.231997
# primary_cleaner.input.xanthate                                     0.143914
# ...                                                                     ...
# secondary_cleaner.state.floatbank5_a_level                         0.031036
# secondary_cleaner.state.floatbank5_b_air                           0.473083
# secondary_cleaner.state.floatbank5_b_level                         0.029395
# secondary_cleaner.state.floatbank6_a_air                          -0.008592
# secondary_cleaner.state.floatbank6_a_level                        -0.010453
#
#                                             rougher.state.floatbank10_a_level  \
# final.output.recovery                                                0.108925
# primary_cleaner.input.sulfate                                        0.070985
# primary_cleaner.input.depressant                                    -0.277574
# primary_cleaner.input.feed_size                                     -0.367653
# primary_cleaner.input.xanthate                                      -0.060013
# ...                                                                       ...
# secondary_cleaner.state.floatbank5_a_level                          -0.122142
# secondary_cleaner.state.floatbank5_b_air                             0.482724
# secondary_cleaner.state.floatbank5_b_level                          -0.118585
# secondary_cleaner.state.floatbank6_a_air                            -0.209844
# secondary_cleaner.state.floatbank6_a_level                           0.116877
#
#                                             rougher.state.floatbank10_b_air  \
# final.output.recovery                                             -0.222368
# primary_cleaner.input.sulfate                                     -0.231805
# primary_cleaner.input.depressant                                  -0.113512
# primary_cleaner.input.feed_size                                    0.192541
# primary_cleaner.input.xanthate                                    -0.276491
# ...                                                                     ...
# secondary_cleaner.state.floatbank5_a_level                         0.360697
# secondary_cleaner.state.floatbank5_b_air                           0.022915
# secondary_cleaner.state.floatbank5_b_level                         0.345267
# secondary_cleaner.state.floatbank6_a_air                           0.407629
# secondary_cleaner.state.floatbank6_a_level                         0.161044
#
#                                             rougher.state.floatbank10_b_level  \
# final.output.recovery                                               -0.143097
# primary_cleaner.input.sulfate                                       -0.226745
# primary_cleaner.input.depressant                                    -0.316093
# primary_cleaner.input.feed_size                                      0.086216
# primary_cleaner.input.xanthate                                      -0.325667
# ...                                                                       ...
# secondary_cleaner.state.floatbank5_a_level                           0.470091
# secondary_cleaner.state.floatbank5_b_air                             0.114045
# secondary_cleaner.state.floatbank5_b_level                           0.453135
# secondary_cleaner.state.floatbank6_a_air                             0.464783
# secondary_cleaner.state.floatbank6_a_level                           0.188413
#
#                                             rougher.state.floatbank10_c_air  \
# final.output.recovery                                             -0.263094
# primary_cleaner.input.sulfate                                     -0.259168
# primary_cleaner.input.depressant                                  -0.152108
# primary_cleaner.input.feed_size                                    0.207150
# primary_cleaner.input.xanthate                                    -0.308510
# ...                                                                     ...
# secondary_cleaner.state.floatbank5_a_level                         0.354647
# secondary_cleaner.state.floatbank5_b_air                           0.019282
# secondary_cleaner.state.floatbank5_b_level                         0.342059
# secondary_cleaner.state.floatbank6_a_air                           0.444999
# secondary_cleaner.state.floatbank6_a_level                         0.132946
#
#                                             rougher.state.floatbank10_c_level  \
# final.output.recovery                                               -0.157596
# primary_cleaner.input.sulfate                                       -0.228206
# primary_cleaner.input.depressant                                    -0.313147
# primary_cleaner.input.feed_size                                      0.076606
# primary_cleaner.input.xanthate                                      -0.335516
# ...                                                                       ...
# secondary_cleaner.state.floatbank5_a_level                           0.486900
# secondary_cleaner.state.floatbank5_b_air                             0.121493
# secondary_cleaner.state.floatbank5_b_level                           0.469696
# secondary_cleaner.state.floatbank6_a_air                             0.466142
# secondary_cleaner.state.floatbank6_a_level                           0.187234
#
#                                             rougher.state.floatbank10_d_air  \
# final.output.recovery                                             -0.251388
# primary_cleaner.input.sulfate                                     -0.296517
# primary_cleaner.input.depressant                                  -0.129834
# primary_cleaner.input.feed_size                                    0.207317
# primary_cleaner.input.xanthate                                    -0.250356
# ...                                                                     ...
# secondary_cleaner.state.floatbank5_a_level                         0.271047
# secondary_cleaner.state.floatbank5_b_air                          -0.006458
# secondary_cleaner.state.floatbank5_b_level                         0.256799
# secondary_cleaner.state.floatbank6_a_air                           0.410188
# secondary_cleaner.state.floatbank6_a_level                         0.129493
#
#                                             rougher.state.floatbank10_d_level  \
# final.output.recovery                                               -0.157762
# primary_cleaner.input.sulfate                                       -0.226060
# primary_cleaner.input.depressant                                    -0.313472
# primary_cleaner.input.feed_size                                      0.077547
# primary_cleaner.input.xanthate                                      -0.332666
# ...                                                                       ...
# secondary_cleaner.state.floatbank5_a_level                           0.489087
# secondary_cleaner.state.floatbank5_b_air                             0.121340
# secondary_cleaner.state.floatbank5_b_level                           0.472084
# secondary_cleaner.state.floatbank6_a_air                             0.467593
# secondary_cleaner.state.floatbank6_a_level                           0.190051
#
#                                             rougher.state.floatbank10_e_air  \
# final.output.recovery                                             -0.163781
# primary_cleaner.input.sulfate                                     -0.263935
# primary_cleaner.input.depressant                                  -0.029764
# primary_cleaner.input.feed_size                                    0.157207
# primary_cleaner.input.xanthate                                    -0.100755
# ...                                                                     ...
# secondary_cleaner.state.floatbank5_a_level                         0.156797
# secondary_cleaner.state.floatbank5_b_air                          -0.033029
# secondary_cleaner.state.floatbank5_b_level                         0.136489
# secondary_cleaner.state.floatbank6_a_air                           0.198946
# secondary_cleaner.state.floatbank6_a_level                         0.195429
#
#                                             rougher.state.floatbank10_e_level  \
# final.output.recovery                                               -0.158622
# primary_cleaner.input.sulfate                                       -0.233453
# primary_cleaner.input.depressant                                    -0.320363
# primary_cleaner.input.feed_size                                      0.072015
# primary_cleaner.input.xanthate                                      -0.329660
# ...                                                                       ...
# secondary_cleaner.state.floatbank5_a_level                           0.489713
# secondary_cleaner.state.floatbank5_b_air                             0.130892
# secondary_cleaner.state.floatbank5_b_level                           0.471811
# secondary_cleaner.state.floatbank6_a_air                             0.472268
# secondary_cleaner.state.floatbank6_a_level                           0.180180
#
#                                             rougher.state.floatbank10_f_air  \
# final.output.recovery                                             -0.132783
# primary_cleaner.input.sulfate                                     -0.242257
# primary_cleaner.input.depressant                                  -0.060957
# primary_cleaner.input.feed_size                                    0.142886
# primary_cleaner.input.xanthate                                    -0.113873
# ...                                                                     ...
# secondary_cleaner.state.floatbank5_a_level                         0.143882
# secondary_cleaner.state.floatbank5_b_air                           0.098457
# secondary_cleaner.state.floatbank5_b_level                         0.123306
# secondary_cleaner.state.floatbank6_a_air                           0.255312
# secondary_cleaner.state.floatbank6_a_level                         0.198328
#
#                                             rougher.state.floatbank10_f_level  \
# final.output.recovery                                               -0.159688
# primary_cleaner.input.sulfate                                       -0.233040
# primary_cleaner.input.depressant                                    -0.324019
# primary_cleaner.input.feed_size                                      0.072811
# primary_cleaner.input.xanthate                                      -0.323559
# ...                                                                       ...
# secondary_cleaner.state.floatbank5_a_level                           0.490865
# secondary_cleaner.state.floatbank5_b_air                             0.136452
# secondary_cleaner.state.floatbank5_b_level                           0.472423
# secondary_cleaner.state.floatbank6_a_air                             0.477658
# secondary_cleaner.state.floatbank6_a_level                           0.179207
#
#                                             secondary_cleaner.state.floatbank2_a_air  \
# final.output.recovery                                                       0.182961
# primary_cleaner.input.sulfate                                               0.121048
# primary_cleaner.input.depressant                                           -0.062386
# primary_cleaner.input.feed_size                                            -0.184552
# primary_cleaner.input.xanthate                                             -0.090774
# ...                                                                              ...
# secondary_cleaner.state.floatbank5_a_level                                 -0.145392
# secondary_cleaner.state.floatbank5_b_air                                    0.348316
# secondary_cleaner.state.floatbank5_b_level                                 -0.135052
# secondary_cleaner.state.floatbank6_a_air                                   -0.041005
# secondary_cleaner.state.floatbank6_a_level                                  0.010658
#
#                                             secondary_cleaner.state.floatbank2_a_level  \
# final.output.recovery                                                         0.034596
# primary_cleaner.input.sulfate                                                 0.120369
# primary_cleaner.input.depressant                                              0.193041
# primary_cleaner.input.feed_size                                               0.112776
# primary_cleaner.input.xanthate                                               -0.086078
# ...                                                                                ...
# secondary_cleaner.state.floatbank5_a_level                                    0.078402
# secondary_cleaner.state.floatbank5_b_air                                     -0.253426
# secondary_cleaner.state.floatbank5_b_level                                    0.077380
# secondary_cleaner.state.floatbank6_a_air                                     -0.059396
# secondary_cleaner.state.floatbank6_a_level                                    0.091807
#
#                                             secondary_cleaner.state.floatbank2_b_air  \
# final.output.recovery                                                       0.164376
# primary_cleaner.input.sulfate                                               0.127614
# primary_cleaner.input.depressant                                            0.075531
# primary_cleaner.input.feed_size                                            -0.138992
# primary_cleaner.input.xanthate                                             -0.015163
# ...                                                                              ...
# secondary_cleaner.state.floatbank5_a_level                                 -0.241900
# secondary_cleaner.state.floatbank5_b_air                                    0.410280
# secondary_cleaner.state.floatbank5_b_level                                 -0.220025
# secondary_cleaner.state.floatbank6_a_air                                   -0.045318
# secondary_cleaner.state.floatbank6_a_level                                 -0.051037
#
#                                             secondary_cleaner.state.floatbank2_b_level  \
# final.output.recovery                                                         0.021842
# primary_cleaner.input.sulfate                                                 0.132338
# primary_cleaner.input.depressant                                              0.180453
# primary_cleaner.input.feed_size                                               0.093261
# primary_cleaner.input.xanthate                                               -0.081978
# ...                                                                                ...
# secondary_cleaner.state.floatbank5_a_level                                    0.092275
# secondary_cleaner.state.floatbank5_b_air                                     -0.209150
# secondary_cleaner.state.floatbank5_b_level                                    0.091619
# secondary_cleaner.state.floatbank6_a_air                                     -0.039886
# secondary_cleaner.state.floatbank6_a_level                                    0.091166
#
#                                             secondary_cleaner.state.floatbank3_a_air  \
# final.output.recovery                                                       0.200050
# primary_cleaner.input.sulfate                                               0.058325
# primary_cleaner.input.depressant                                           -0.188589
# primary_cleaner.input.feed_size                                            -0.161917
# primary_cleaner.input.xanthate                                              0.026729
# ...                                                                              ...
# secondary_cleaner.state.floatbank5_a_level                                 -0.023392
# secondary_cleaner.state.floatbank5_b_air                                    0.755336
# secondary_cleaner.state.floatbank5_b_level                                  0.009109
# secondary_cleaner.state.floatbank6_a_air                                    0.347827
# secondary_cleaner.state.floatbank6_a_level                                 -0.027112
#
#                                             secondary_cleaner.state.floatbank3_a_level  \
# final.output.recovery                                                         0.004630
# primary_cleaner.input.sulfate                                                -0.019748
# primary_cleaner.input.depressant                                             -0.079073
# primary_cleaner.input.feed_size                                               0.092038
# primary_cleaner.input.xanthate                                               -0.259106
# ...                                                                                ...
# secondary_cleaner.state.floatbank5_a_level                                    0.695012
# secondary_cleaner.state.floatbank5_b_air                                      0.171950
# secondary_cleaner.state.floatbank5_b_level                                    0.668771
# secondary_cleaner.state.floatbank6_a_air                                      0.502716
# secondary_cleaner.state.floatbank6_a_level                                    0.299974
#
#                                             secondary_cleaner.state.floatbank3_b_air  \
# final.output.recovery                                                       0.015313
# primary_cleaner.input.sulfate                                              -0.007623
# primary_cleaner.input.depressant                                            0.010926
# primary_cleaner.input.feed_size                                             0.016222
# primary_cleaner.input.xanthate                                             -0.083007
# ...                                                                              ...
# secondary_cleaner.state.floatbank5_a_level                                 -0.077480
# secondary_cleaner.state.floatbank5_b_air                                    0.629280
# secondary_cleaner.state.floatbank5_b_level                                 -0.029110
# secondary_cleaner.state.floatbank6_a_air                                    0.383804
# secondary_cleaner.state.floatbank6_a_level                                 -0.058035
#
#                                             secondary_cleaner.state.floatbank3_b_level  \
# final.output.recovery                                                         0.007447
# primary_cleaner.input.sulfate                                                -0.038776
# primary_cleaner.input.depressant                                              0.018585
# primary_cleaner.input.feed_size                                               0.131676
# primary_cleaner.input.xanthate                                               -0.109014
# ...                                                                                ...
# secondary_cleaner.state.floatbank5_a_level                                    0.584313
# secondary_cleaner.state.floatbank5_b_air                                     -0.319711
# secondary_cleaner.state.floatbank5_b_level                                    0.549664
# secondary_cleaner.state.floatbank6_a_air                                      0.179337
# secondary_cleaner.state.floatbank6_a_level                                    0.293364
#
#                                             secondary_cleaner.state.floatbank4_a_air  \
# final.output.recovery                                                       0.244897
# primary_cleaner.input.sulfate                                               0.074603
# primary_cleaner.input.depressant                                           -0.239887
# primary_cleaner.input.feed_size                                            -0.342184
# primary_cleaner.input.xanthate                                              0.029418
# ...                                                                              ...
# secondary_cleaner.state.floatbank5_a_level                                  0.097003
# secondary_cleaner.state.floatbank5_b_air                                    0.724005
# secondary_cleaner.state.floatbank5_b_level                                  0.102399
# secondary_cleaner.state.floatbank6_a_air                                    0.197084
# secondary_cleaner.state.floatbank6_a_level                                  0.003164
#
#                                             secondary_cleaner.state.floatbank4_a_level  \
# final.output.recovery                                                         0.034764
# primary_cleaner.input.sulfate                                                 0.019703
# primary_cleaner.input.depressant                                             -0.166051
# primary_cleaner.input.feed_size                                               0.107474
# primary_cleaner.input.xanthate                                               -0.231022
# ...                                                                                ...
# secondary_cleaner.state.floatbank5_a_level                                    0.801572
# secondary_cleaner.state.floatbank5_b_air                                      0.251859
# secondary_cleaner.state.floatbank5_b_level                                    0.786070
# secondary_cleaner.state.floatbank6_a_air                                      0.581933
# secondary_cleaner.state.floatbank6_a_level                                    0.269724
#
#                                             secondary_cleaner.state.floatbank4_b_air  \
# final.output.recovery                                                       0.184852
# primary_cleaner.input.sulfate                                               0.099797
# primary_cleaner.input.depressant                                           -0.140277
# primary_cleaner.input.feed_size                                            -0.263828
# primary_cleaner.input.xanthate                                              0.000764
# ...                                                                              ...
# secondary_cleaner.state.floatbank5_a_level                                  0.002151
# secondary_cleaner.state.floatbank5_b_air                                    0.879683
# secondary_cleaner.state.floatbank5_b_level                                  0.027040
# secondary_cleaner.state.floatbank6_a_air                                    0.309748
# secondary_cleaner.state.floatbank6_a_level                                 -0.108732
#
#                                             secondary_cleaner.state.floatbank4_b_level  \
# final.output.recovery                                                        -0.138432
# primary_cleaner.input.sulfate                                                -0.055428
# primary_cleaner.input.depressant                                             -0.289608
# primary_cleaner.input.feed_size                                               0.029519
# primary_cleaner.input.xanthate                                               -0.336021
# ...                                                                                ...
# secondary_cleaner.state.floatbank5_a_level                                    0.574310
# secondary_cleaner.state.floatbank5_b_air                                      0.163332
# secondary_cleaner.state.floatbank5_b_level                                    0.558208
# secondary_cleaner.state.floatbank6_a_air                                      0.300935
# secondary_cleaner.state.floatbank6_a_level                                    0.294252
#
#                                             secondary_cleaner.state.floatbank5_a_air  \
# final.output.recovery                                                       0.083374
# primary_cleaner.input.sulfate                                              -0.025492
# primary_cleaner.input.depressant                                           -0.276479
# primary_cleaner.input.feed_size                                            -0.232562
# primary_cleaner.input.xanthate                                             -0.098533
# ...                                                                              ...
# secondary_cleaner.state.floatbank5_a_level                                  0.083523
# secondary_cleaner.state.floatbank5_b_air                                    0.890392
# secondary_cleaner.state.floatbank5_b_level                                  0.100943
# secondary_cleaner.state.floatbank6_a_air                                    0.437156
# secondary_cleaner.state.floatbank6_a_level                                 -0.002181
#
#                                             secondary_cleaner.state.floatbank5_a_level  \
# final.output.recovery                                                         0.026035
# primary_cleaner.input.sulfate                                                -0.033252
# primary_cleaner.input.depressant                                             -0.159159
# primary_cleaner.input.feed_size                                               0.122984
# primary_cleaner.input.xanthate                                               -0.210137
# ...                                                                                ...
# secondary_cleaner.state.floatbank5_a_level                                    1.000000
# secondary_cleaner.state.floatbank5_b_air                                      0.035247
# secondary_cleaner.state.floatbank5_b_level                                    0.914822
# secondary_cleaner.state.floatbank6_a_air                                      0.516106
# secondary_cleaner.state.floatbank6_a_level                                    0.386162
#
#                                             secondary_cleaner.state.floatbank5_b_air  \
# final.output.recovery                                                       0.054670
# primary_cleaner.input.sulfate                                              -0.011143
# primary_cleaner.input.depressant                                           -0.233767
# primary_cleaner.input.feed_size                                            -0.218621
# primary_cleaner.input.xanthate                                             -0.105689
# ...                                                                              ...
# secondary_cleaner.state.floatbank5_a_level                                  0.035247
# secondary_cleaner.state.floatbank5_b_air                                    1.000000
# secondary_cleaner.state.floatbank5_b_level                                  0.047836
# secondary_cleaner.state.floatbank6_a_air                                    0.477623
# secondary_cleaner.state.floatbank6_a_level                                 -0.027078
#
#                                             secondary_cleaner.state.floatbank5_b_level  \
# final.output.recovery                                                         0.030820
# primary_cleaner.input.sulfate                                                -0.035024
# primary_cleaner.input.depressant                                             -0.151554
# primary_cleaner.input.feed_size                                               0.129286
# primary_cleaner.input.xanthate                                               -0.211460
# ...                                                                                ...
# secondary_cleaner.state.floatbank5_a_level                                    0.914822
# secondary_cleaner.state.floatbank5_b_air                                      0.047836
# secondary_cleaner.state.floatbank5_b_level                                    1.000000
# secondary_cleaner.state.floatbank6_a_air                                      0.514151
# secondary_cleaner.state.floatbank6_a_level                                    0.354225
#
#                                             secondary_cleaner.state.floatbank6_a_air  \
# final.output.recovery                                                      -0.066191
# primary_cleaner.input.sulfate                                              -0.124292
# primary_cleaner.input.depressant                                           -0.175383
# primary_cleaner.input.feed_size                                             0.152878
# primary_cleaner.input.xanthate                                             -0.237701
# ...                                                                              ...
# secondary_cleaner.state.floatbank5_a_level                                  0.516106
# secondary_cleaner.state.floatbank5_b_air                                    0.477623
# secondary_cleaner.state.floatbank5_b_level                                  0.514151
# secondary_cleaner.state.floatbank6_a_air                                    1.000000
# secondary_cleaner.state.floatbank6_a_level                                  0.101552
#
#                                             secondary_cleaner.state.floatbank6_a_level
# final.output.recovery                                                        -0.035935
# primary_cleaner.input.sulfate                                                -0.150123
# primary_cleaner.input.depressant                                             -0.135981
# primary_cleaner.input.feed_size                                               0.065068
# primary_cleaner.input.xanthate                                               -0.078515
# ...                                                                                ...
# secondary_cleaner.state.floatbank5_a_level                                    0.386162
# secondary_cleaner.state.floatbank5_b_air                                     -0.027078
# secondary_cleaner.state.floatbank5_b_level                                    0.354225
# secondary_cleaner.state.floatbank6_a_air                                      0.101552
# secondary_cleaner.state.floatbank6_a_level                                    1.000000

# %% [markdown]
# # Исследовательский анализ данных
#
# https://github.com/DmitriyPyankov/Prediction-of-recovery-coefficients-of-gold-from-gold-bearing-ore/tree/main/%D0%9F%D1%80%D0%BE%D0%B3%D0%BD%D0%BE%D0%B7%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20%D0%BA%D0%BE%D1%8D%D1%84%D1%84%D0%B8%D1%86%D0%B8%D0%B5%D0%BD%D1%82%D0%BE%D0%B2%20%D0%B2%D0%BE%D1%81%D1%81%D1%82%D0%B0%D0%BD%D0%BE%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D1%8F%20%D0%B7%D0%BE%D0%BB%D0%BE%D1%82%D0%B0%20%D0%B8%D0%B7%20%D0%B7%D0%BE%D0%BB%D0%BE%D1%82%D0%BE%D1%81%D0%BE%D0%B4%D0%B5%D1%80%D0%B6%D0%B0%D1%89%D0%B5%D0%B9%20%D1%80%D1%83%D0%B4%D1%8B

# %% [markdown]
# ## Изменение концентрации металлов
# _Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Опишите выводы._

# %% [markdown]
# ## Сравнение распределения гранул сырья на выборках
# _Сравните распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной._

# %% [markdown]
# ## Исследование суммарной концентрации веществ
# _Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах_

# %% [markdown]
# # Построение модели

# %% [markdown]
# ## Создание функции для вычисления итоговой sMAPE

# %% [markdown]
# ## Обучение разных моделей
#  <font color='red'><strong>Перед обучением потребовали масштабирование. Использовал StandardScaler().
#  fit+transform scaler-a только на обучающей, а  на остальных только transform</font></strong>

# %% [markdown]
# ## Оценка качества моделей кросс-валидацией

# %% [markdown]
# ## Проверка выбранной модели на тестовой выборке

# %% [markdown]
# # Чек-лист готовности проекта

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [ ]  Весь код выполняется без ошибок
# - [ ]  Ячейки с кодом расположены в порядке выполнения
# - [ ]  Выполнен шаг 1: данные подготовлены
#     - [ ]  Проверена формула вычисления эффективности обогащения
#     - [ ]  Проанализированы признаки, недоступные в тестовой выборке
#     - [ ]  Проведена предобработка данных
# - [ ]  Выполнен шаг 2: данные проанализированы
#     - [ ]  Исследовано изменение концентрации элементов на каждом этапе
#     - [ ]  Проанализированы распределения размеров гранул на обучающей и тестовой выборках
#     - [ ]  Исследованы суммарные концентрации
# - [ ]  Выполнен шаг 3: построена модель прогнозирования
#     - [ ]  Написана функция для вычисления итогового *sMAPE*
#     - [ ]  Обучено и проверено несколько моделей
#     - [ ]  Выбрана лучшая модель, её качество проверено на тестовой выборке
