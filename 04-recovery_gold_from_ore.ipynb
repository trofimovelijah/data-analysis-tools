# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>✔️ Комментарий ревьюера V3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Приветствую снова!
#
# Что ж, теперь, на мой взгляд, проект вполне пригоден для того, чтобы быть принятым, с чем тебя и поздравляю! :)
#
# Успехов с реальными рабочими DS/DA проектами!
# <br />
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4">🍕<b> Комментарий ревьюера V2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Привет ещё раз!
#
# Теперь уже прям почти хорошо, но пара моментов есть:
#
# + Делать грид серч по смапе, а не MAE
# + Сделать проверку на адекватность не только на final таргете, но и на rougher
#
# Пока на этом всё. Жду новую отправку!

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Илья! Спасибо, что прислал задание :) <br>Меня зовут Никита Сон и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты, как это принято в Практикуме, если ты не против. Но если хочешь на Вы - не буду возражать 🙂
#
# Поехали 🚀
#     <br />
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. При внесении правок в проект, пожалуйста, не меняй и не удаляй их т.к. дальнейшая проверка будет происходить в том числе на основе того, исправлены замечания в комментариях или нет. Зато ты всегда можешь оставить свои комментарии для меня :)
#     </font>
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# В зелёных блоках будут позитивные комментарии
# <br />
#     </font>
# </div>
#
# <div class="alert alert-warning">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# В жёлтых - некритичные замечания
#     </font>
# </div>
#
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# В красных - важные замечания, которые надо обязательно устранить
#     </font>
# </div>
#
# <div class="alert alert-info">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# В синих с пиццей - различные нейтральные сообщения, советы на будещее и прочее.
#     </font>
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-общей-информации" data-toc-modified-id="Изучение-общей-информации-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение общей информации</a></span><ul class="toc-item"><li><span><a href="#Импорт-библиотек" data-toc-modified-id="Импорт-библиотек-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Импорт библиотек</a></span></li><li><span><a href="#Открытие-датасета" data-toc-modified-id="Открытие-датасета-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Открытие датасета</a></span><ul class="toc-item"><li><span><a href="#Обучающая-выборка" data-toc-modified-id="Обучающая-выборка-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Обучающая выборка</a></span></li><li><span><a href="#Тестовая-выборка" data-toc-modified-id="Тестовая-выборка-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Тестовая выборка</a></span></li><li><span><a href="#Исходная-выборка" data-toc-modified-id="Исходная-выборка-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Исходная выборка</a></span></li></ul></li></ul></li><li><span><a href="#Вычисление-эффективности-обогащения" data-toc-modified-id="Вычисление-эффективности-обогащения-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Вычисление эффективности обогащения</a></span></li><li><span><a href="#Подготовка-тестовой-выборки" data-toc-modified-id="Подготовка-тестовой-выборки-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Подготовка тестовой выборки</a></span><ul class="toc-item"><li><span><a href="#Анализ-признаков,-недоступных-в-тестовой-выборке" data-toc-modified-id="Анализ-признаков,-недоступных-в-тестовой-выборке-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Анализ признаков, недоступных в тестовой выборке</a></span></li><li><span><a href="#Дополнение-тестовой-выборки-целевыми-признаками" data-toc-modified-id="Дополнение-тестовой-выборки-целевыми-признаками-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Дополнение тестовой выборки целевыми признаками</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Определение-и-устранение-аномальных-значений" data-toc-modified-id="Определение-и-устранение-аномальных-значений-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Определение и устранение аномальных значений</a></span><ul class="toc-item"><li><span><a href="#Устранение-аномальных-значений-для-обучающей-выборки" data-toc-modified-id="Устранение-аномальных-значений-для-обучающей-выборки-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Устранение аномальных значений для обучающей выборки</a></span></li><li><span><a href="#Устранение-аномальных-значений-для-тестовой-выборки" data-toc-modified-id="Устранение-аномальных-значений-для-тестовой-выборки-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Устранение аномальных значений для тестовой выборки</a></span></li></ul></li><li><span><a href="#Определение-пропусков" data-toc-modified-id="Определение-пропусков-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Определение пропусков</a></span><ul class="toc-item"><li><span><a href="#Определение-пропусков-в-обучающей-выборке" data-toc-modified-id="Определение-пропусков-в-обучающей-выборке-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Определение пропусков в обучающей выборке</a></span></li><li><span><a href="#Определение-пропусков-в-тестовой-выборке" data-toc-modified-id="Определение-пропусков-в-тестовой-выборке-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Определение пропусков в тестовой выборке</a></span></li></ul></li><li><span><a href="#Подсчёт-корреляции" data-toc-modified-id="Подсчёт-корреляции-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Подсчёт корреляции</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изменение-концентрации-металлов" data-toc-modified-id="Изменение-концентрации-металлов-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Изменение концентрации металлов</a></span></li><li><span><a href="#Сравнение-распределения-гранул-сырья-на-выборках" data-toc-modified-id="Сравнение-распределения-гранул-сырья-на-выборках-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Сравнение распределения гранул сырья на выборках</a></span></li><li><span><a href="#Исследование-суммарной-концентрации-веществ" data-toc-modified-id="Исследование-суммарной-концентрации-веществ-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Исследование суммарной концентрации веществ</a></span></li><li><span><a href="#Подготовка-обучающей-и-тестовой-выборок" data-toc-modified-id="Подготовка-обучающей-и-тестовой-выборок-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Подготовка обучающей и тестовой выборок</a></span></li><li><span><a href="#Создание-функции-для-вычисления-итоговой-sMAPE" data-toc-modified-id="Создание-функции-для-вычисления-итоговой-sMAPE-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Создание функции для вычисления итоговой sMAPE</a></span></li></ul></li><li><span><a href="#Обучение-разных-моделей" data-toc-modified-id="Обучение-разных-моделей-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Обучение разных моделей</a></span><ul class="toc-item"><li><span><a href="#Подход-к-моделированию" data-toc-modified-id="Подход-к-моделированию-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Подход к моделированию</a></span></li><li><span><a href="#Выделение-валидационной-выборки" data-toc-modified-id="Выделение-валидационной-выборки-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Выделение валидационной выборки</a></span></li><li><span><a href="#Составление-прогноза-с-помощью-модели-дерева-решений" data-toc-modified-id="Составление-прогноза-с-помощью-модели-дерева-решений-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Составление прогноза с помощью модели дерева решений</a></span><ul class="toc-item"><li><span><a href="#Предсказание-эффективности-обогащения-чернового-концентрата" data-toc-modified-id="Предсказание-эффективности-обогащения-чернового-концентрата-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Предсказание эффективности обогащения чернового концентрата</a></span></li><li><span><a href="#Предсказание-эффективности-обогащения-финального-концентрата" data-toc-modified-id="Предсказание-эффективности-обогащения-финального-концентрата-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>Предсказание эффективности обогащения финального концентрата</a></span></li></ul></li><li><span><a href="#Составление-прогноза-с-помощью-модели-случайного-леса" data-toc-modified-id="Составление-прогноза-с-помощью-модели-случайного-леса-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Составление прогноза с помощью модели случайного леса</a></span><ul class="toc-item"><li><span><a href="#Предсказание-эффективности-обогащения-чернового-концентрата" data-toc-modified-id="Предсказание-эффективности-обогащения-чернового-концентрата-6.4.1"><span class="toc-item-num">6.4.1&nbsp;&nbsp;</span>Предсказание эффективности обогащения чернового концентрата</a></span></li><li><span><a href="#Предсказание-эффективности-обогащения-финального-концентрата" data-toc-modified-id="Предсказание-эффективности-обогащения-финального-концентрата-6.4.2"><span class="toc-item-num">6.4.2&nbsp;&nbsp;</span>Предсказание эффективности обогащения финального концентрата</a></span></li></ul></li><li><span><a href="#Составление-прогноза-с-помощью-модели-линейной-регрессии" data-toc-modified-id="Составление-прогноза-с-помощью-модели-линейной-регрессии-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Составление прогноза с помощью модели линейной регрессии</a></span><ul class="toc-item"><li><span><a href="#Предсказание-эффективности-обогащения-чернового-концентрата" data-toc-modified-id="Предсказание-эффективности-обогащения-чернового-концентрата-6.5.1"><span class="toc-item-num">6.5.1&nbsp;&nbsp;</span>Предсказание эффективности обогащения чернового концентрата</a></span></li><li><span><a href="#Предсказание-эффективности-обогащения-финального-концентрата" data-toc-modified-id="Предсказание-эффективности-обогащения-финального-концентрата-6.5.2"><span class="toc-item-num">6.5.2&nbsp;&nbsp;</span>Предсказание эффективности обогащения финального концентрата</a></span></li></ul></li></ul></li><li><span><a href="#Проверка-выбранной-модели-на-тестовой-выборке" data-toc-modified-id="Проверка-выбранной-модели-на-тестовой-выборке-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Проверка выбранной модели на тестовой выборке</a></span></li><li><span><a href="#Проверка-модели-на-адекватность" data-toc-modified-id="Проверка-модели-на-адекватность-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Проверка модели на адекватность</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для компании `Цифра`. Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# Данные находятся в трёх файлах:
#
# - [gold_recovery_train_new.csv](https://code.s3.yandex.net/datasets/gold_recovery_train_new.csv) — обучающая выборка;
# - [gold_recovery_test_new.csv](https://code.s3.yandex.net/datasets/gold_recovery_test_new.csv) — тестовая выборка;
# - [gold_recovery_full_new.csv](https://code.s3.yandex.net/datasets/gold_recovery_full_new.csv) — исходные данные.
#
# Данные индексируются датой и временем получения информации (признак `date`). Соседние по времени параметры часто похожи.
#
# Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков.
#
# Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.
#
# В вашем распоряжении сырые данные: их просто выгрузили из хранилища. Прежде чем приступить к построению модели, проверьте по нашей инструкции их на корректность.
#
# Исходя из описания технологического процесса восстановления золота из руды, необходимо спрогнозировать две величины:
# - `rougher.output.recovery` - эффективность обогащения чернового концентрата,
# - `final.output.recovery` - эффективность обогащения финального концентрата.

# %%
# КОД РЕВЬЮЕРА
# !pip install scikit-learn --upgrade

# %% [markdown]
# # Подготовка данных

# %% [markdown]
# ## Изучение общей информации
# ### Импорт библиотек

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
import random
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor
from tqdm import tqdm
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

# %% [markdown]
# ### Открытие датасета
# Ввиду того, что у нас представлены три отдельных датасета (обучающий, тестовый и полный с исходными данными), выполним открытие каждого из датасетов по отдельности и посмотрим инфо по типам данных, сделав первоначальный анализ имеющегося материала. Затем
#
#
# _Данные индексируются датой и временем получения информации (признак date). Соседние по времени параметры часто похожи._
#
# _Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков._
#
# _Исходный датасет содержит обучающую и тестовую выборки со всеми признаками._
#
# _В вашем распоряжении сырые данные: их просто выгрузили из хранилища. Прежде чем приступить к построению модели, проверьте по нашей инструкции их на корректность._

# %% [markdown]
# #### Обучающая выборка

# %%
url_train = 'https://code.s3.yandex.net/datasets/gold_recovery_train_new.csv'
data_train = pd.read_csv(url_train)
pd.set_option('display.max_columns', None)
data_train.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %% [markdown]
# #### Тестовая выборка

# %%
url_test = 'https://code.s3.yandex.net/datasets/gold_recovery_test_new.csv'
data_test = pd.read_csv(url_test)
data_test.head()
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5286 non-null   float64
#  2   primary_cleaner.input.depressant            5285 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5286 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
# ...

# %% [markdown]
# #### Исходная выборка

# %%
url_init = 'https://code.s3.yandex.net/datasets/gold_recovery_full_new.csv'
data_init = pd.read_csv(url_init)
data_init.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
data_init.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
# ...

# %% [markdown]
# ## Вычисление эффективности обогащения
# На обучающей выборке для признака `rougher.output.recovery` выполняем проверку, насколько правильно рассчитана эффективности обогащения чернового концентрата.
#
# В расчёте эффективности обогащения чернового концентрата используются следующие значения:
# - `rougher.output.concentrate_au` - доля золота в концентрате после флотации/очистки
# - `rougher.input.feed_au` - доля золота в сырье/концентрате до флотации/очистки
# - `rougher.output.tail_au` - доля золота в отвальных хвостах после флотации/очистки

# %%
# Вычисление эффективности обогащения
recovery_calculated = ((data_train['rougher.output.concentrate_au'] * (data_train['rougher.input.feed_au'] - data_train['rougher.output.tail_au'])) / 
                       (data_train['rougher.input.feed_au'] * (data_train['rougher.output.concentrate_au'] - data_train['rougher.output.tail_au']))) * 100

# %% [markdown]
# Покажем `MAE` между расчётами и значением признака эффективности обогащения.

# %%
# Вычисление средней абсолютной ошибки (MAE)
mean_absolute_error(data_train['rougher.output.recovery'], recovery_calculated)
# Out:
# 9.73512347450521e-15

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Расчёт верный

# %% [markdown]
# <div class="alert alert-info">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Вообще, почему несмотря на неравную в точности нулю ошибку мы можем говорить, что данные корректны? Дело в том, что в питоне, как и любом другом языке программирования, операции с нецелыми числами имеют ограниченную точность. Например:

# %%
# КОД РЕВЬЮЕРА
1/2 + 1/3 - 5/6
# Out:
# -1.1102230246251565e-16

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"></font>
#     <font size="3", color = "black">
# Приведя к общему знаменателю нетрудно посчитать, что значение выражения в точности равно нулю. Почему же питон считает, что это число порядка 1е-16? 1/3 в десятичном виде == 0.33333 ну и бесконечное число троек после запятой. Разумеется, физически невозможно, да и просто бессмысленно хранить бесконечное число знаков, хранится ограниченное количество, из-за этого и возникают микроскопические расхождения.

# %% [markdown]
# Значение средней абсолютной ошибки `MAE` очень близка к нулю (_9.73512347450521e-15_). Это предполагает точность выполненных расчётов эффективности обогащения. Таким образом, можно с уверенностью сказать, что эффективность обогащения золота была рассчитана правильно на обучающей выборке.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Спасибо. Не знал.

# %% [markdown]
# ## Подготовка тестовой выборки
# ### Анализ признаков, недоступных в тестовой выборке
# Проанализируем признаки, недоступные в тестовой выборке.

# %%
set(data_init.columns) - set(data_test.columns) # параметры, отсутствующие в тестовой выборке
# Out:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# В тестовой выборке отсутствуют следующие группы параметров:
# - содержащие описание финальных характеристик (блок _этап_ в тестовой выборке не содержит `final`) продукта (тип параметра `output`)
# - доля сырья после первичной очистки (этап `primary_cleaner` для типа параметра `output`)
# - доля в сырье/концентрате после флотации/очистки (параметр продукта (т.е. ПОСЛЕ того, как сырьё прошло этап очистки) `output` для этапа флотации `rougher`)
# - расчётные характеристики (тип параметра `calculation`) для флотации
# - доля продукта (тип параметра `output`) в отвальных хвостах (техпроцесс `tail`) после вторичной очистки (этап `secondary_cleaner`)
#
# Таким образом в тестовой выборке отсутствуют все параметры, относящиеся к типам `output` и `calculation`, т.е. всё относящееся к данным после обработки (когда из сырья получен продукт) и расчётные характеристики (расчётные характеристики в исходных данных представлены только для этапа флотации).
#
# Также наблюдаем подтверждение догадки об отсутствии в тестовой выборке двух целевых признаков, `rougher.output.recovery` и `final.output.recovery`, прогнозы по которым необходимо будет построить.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Всё верно. Отсутствуют признаки, которые нельзя использовать для прогноза. Иначе будет утечка данных.

# %% [markdown]
# ### Дополнение тестовой выборки целевыми признаками
# Тестовую выборку необходимо дополнить двумя целевыми признаками, которые необходимо брать из исходного датасета

# %%
data_test_tar = data_test.merge(
    data_init[['date', 'rougher.output.recovery', 'final.output.recovery']], 
    on='date',
    how='left'
                                      )

data_test_tar.head()
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %%
# КОД РЕВЬЮЕРА
data_test_tar[['date', 'rougher.output.recovery', 'final.output.recovery']].head()
# Out:
#                   date  rougher.output.recovery  final.output.recovery
# 0  2016-09-01 00:59:59                89.993421              70.273583
# 1  2016-09-01 01:59:59                88.089657              68.910432
# 2  2016-09-01 02:59:59                88.412756              68.143213
# 3  2016-09-01 03:59:59                87.360133              67.776393
# 4  2016-09-01 04:59:59                83.236367              61.467078

# %%
# КОД РЕВЬЮЕРА
data_init[['date', 'rougher.output.recovery', 'final.output.recovery']].iloc[4682:4687]
# Out:
#                      date  rougher.output.recovery  final.output.recovery
# 4682  2016-09-01 00:59:59                89.993421              70.273583
# 4683  2016-09-01 01:59:59                88.089657              68.910432
# 4684  2016-09-01 02:59:59                88.412756              68.143213
# 4685  2016-09-01 03:59:59                87.360133              67.776393
# 4686  2016-09-01 04:59:59                83.236367              61.467078

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Обрати внимание, что для одной и той же даты и времени в полных данных и в тестовых у тебя разные значения целевых переменных. Видимо, надо объединять таблички не по индексу ;)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Таблицы объединены через <i>date</i>. Проверка осуществляется успешно.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>✔️ Комментарий ревьюера V2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Да, делать merge по дате - именно то, что нужно 👍

# %%
data_test_tar.shape
# Out:
# (5290, 55)

# %% [markdown]
# В тестовой выборке фигурирует 55 признаков и более 5К строк.

# %% [markdown]
# ## Предобработка данных
# Предобработку данных будем делать для обучающей и для тестовой выборок.

# %% [markdown]
# ### Определение и устранение аномальных значений
# Построим диаграмму `ящик с усами` для каждого из признаков, входящих в обучающую выборку. Нам это даст возможность визуально оценить, значения каких параметров можно отнести к выбросам и избавиться от них, сделав, тем самым, очистку данных.

# %% [markdown]
# #### Устранение аномальных значений для обучающей выборки

# %%
fig, axes = plt.subplots(nrows=(len(data_train.columns)-1)//7+1, ncols=7, figsize=(20, 45))

for i, column in enumerate(data_train.columns):
    if column != 'date':
        row = i // axes.shape[1]
        col = i % axes.shape[1]
        data_train.boxplot(column=column, ax=axes[row, col])

plt.tight_layout()
plt.show()

# %% [markdown]
# По графикам на обучающей выборке можно сделать заключение о наличии выбросов практически для каждого из параметров.
# Удалим значения 0 и 100 для признаков `rougher.output.recovery` и `final.output.recovery`, а затем посмотрим на иные результаты. Что характерно, для `rougher.output.recovery` 100 не является выбросом, а находится на самой верхней границе диаграммы. Но очевидно, что доля продукта после флотации не может составлять 100%, поэтому от такого значения избавимся. Посмотрим график в более крупном масштабе и примем решение.

# %%
fig, ax = plt.subplots(figsize=(20, 5))

data_train.boxplot(column=['final.output.recovery', 'rougher.output.recovery'], ax=ax, vert=False)
ax.set_title('Обогащение продукта для целевых признаков')
ax.set_xticks(range(0, 101, 4))
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Не всё, что лежит за пределами усов - это аномалия, которую надо удалять. Когда малое число точек далеко от усов - ок. Но если куча точек вплотную к усам, то это просто хвост распределения, удалять нет смысла, скорее сделаем хуже, уменьшив репрезентативность данных.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Принято. После некоторого числа опытов удалил только нулевые значения, оставив все значения, находящиеся поблизости от усов.

# %%
data_train_clr = data_train[(data_train['final.output.recovery'] != 0) & (data_train['final.output.recovery'] != 100)]
data_train_clr = data_train_clr[(data_train_clr['rougher.output.recovery'] != 0) & (data_train_clr['rougher.output.recovery'] != 100)]

# %% [markdown]
# Теперь устраним для остальных признаков выбивающиеся значения `0`

# %%
for column in data_train_clr.columns:
    data_train_clr = data_train_clr[data_train_clr[column] != 0]

# %%
# КОД РЕВЬЮЕРА
data_train_clr.shape[0] / data_train.shape[0]
# Out:
# 0.9142695596861969

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Опять же, к вопросу разницы что аномалия и хвост распределения - не одно и то же. Аномалия она на то и аномалия, что является чем-то редким. 14.3% данных аномалии - как-то слишком. Надо удалять только то, что серьёзно выбивается из общей картины данных.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Пересчитал. 91,43% строк осталось. Если не удалять нули во всех иных признаках, тогда число строк вырастет до 96,98%. Однако считаю такой подход неверным, ведь неспростра боксплоты строил, чтобы выявить именно те признаки, в которых присутствуют 0 и 100. Так вот, например, нули присутствуют во всех признаках, касающихся финальных характеристики, что очевидно, неверно. Поэтому лучше от подобного избавляться.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4">🍕<b> Комментарий ревьюера V2</b></font>
#     <br />
#     <font size="3", color = "black">
#         <b></b>
#
# <img src="https://kartinkof.club/uploads/posts/2022-03/1648241141_25-kartinkof-club-p-mem-priemlemo-s-kotom-25.jpg" width=300>

# %% [markdown]
# #### Устранение аномальных значений для тестовой выборки

# %% [markdown]
# Для признаков, входящих в тестовую выборку, построим аналогичный boxplot, а затем на основании его избавимся от выбросов в целевых признаках.

# %%
fig, ax = plt.subplots(figsize=(20, 5))

data_test_tar.boxplot(column=['final.output.recovery', 'rougher.output.recovery'], ax=ax, vert=False)
ax.set_title('Обогащение продукта для целевых признаков')
ax.set_xticks(range(0, 101, 4))
plt.show()

# %%
data_test_tar = data_test_tar[(data_test_tar['final.output.recovery'] != 0) & (data_test_tar['final.output.recovery'] != 100)]
data_test_tar = data_test_tar[(data_test_tar['rougher.output.recovery'] != 0) & (data_test_tar['rougher.output.recovery'] != 100)]

# %% [markdown]
# Для остальных признаков устраним выбивающиеся значения `0`

# %%
for column in data_test_tar.columns:
    data_test_tar = data_test_tar[data_test_tar[column] != 0]

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Пересчитал и в тестовой выборке. Тут результат очистки более 97%.

# %%
data_test_tar.shape[0] / data_test.shape[0]
# Out:
# 0.9712665406427221

# %% [markdown]
# ### Определение пропусков
# Подсчитаем количество пропусков для признаков в тестовой и обучающей выборках.

# %% [markdown]
# #### Определение пропусков в обучающей выборке

# %%
data_train_clr.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# secondary_cleaner.output.tail_sol           1560
# rougher.state.floatbank10_e_air              356
# primary_cleaner.output.concentrate_sol       243
# final.output.concentrate_sol                 201
# secondary_cleaner.state.floatbank2_a_air     197
# rougher.input.floatbank11_xanthate           122
# rougher.input.feed_size                      119
# final.output.tail_pb                         100
# rougher.input.feed_pb                         99
# primary_cleaner.input.xanthate                77
# dtype: int64

# %%
print(f'Суммарное число пропусков {data_train_clr.isnull().sum().sum()} из {data_train_clr.shape[0]} строк обучающей выборки')
# Out:
# Суммарное число пропусков 3391 из 12936 строк обучающей выборки

# %% [markdown]
# Как видно, процент пропусков велик - более четверти всех строк. Наибольшее значение пропусков в `secondary_cleaner.output.tail_sol` составляет более 12% от общего числа строк. Этот признак отвечает за `содержание твёрдых частиц в отвальных хвостах после вторичной очистки`. В тестовой выборке этот признак отсутствует, поэтому проверять обученность модели по нему не получится. И в дальнейшем от данного признака мы избавимся на шаге [подготовки обучающей выборки](#Подготовка-обучающей-выборки).
#
# Ввиду многочисленности пропусков удалять их не станем, ибо сие может искривить итоговый результат не в сторону точности. Так что `secondary_cleaner.output.tail_sol` заполним методом _bfill/ffill_, а для остальных признаков заполним пропущенные значения на основе ближайших известных значений. Тем самым результат будет "более плавным", основываясь на соседних известных точках. А мы как раз от этого избавлялись.

# %%
data_train_clr['secondary_cleaner.output.tail_sol'].fillna(method='bfill', inplace=True)
data_train_clr.interpolate(method='linear', inplace=True)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>✔️ Комментарий ревьюера V2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# 👌

# %%
print(f'После очистки от пропусков и выбросов в обучающей выборке остались те же {data_train_clr.shape[0]} строк и {data_train_clr.shape[1]} признаков')
# Out:
# После очистки от пропусков и выбросов в обучающей выборке остались те же 12936 строк и 87 признаков

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# 12% данных удалённых из-за пропусков - перебор. Стоит всё-таки заполнять ffill/bfill. Тем более, как я описал выше, не такие уж ужасные верхние и нижние границы, что за них нельзя выходить.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Внесены изменения в код и в описание

# %% [markdown]
# #### Определение пропусков в тестовой выборке

# %%
data_test_tar.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# rougher.input.feed_sol                      20
# rougher.input.floatbank11_xanthate          17
# secondary_cleaner.state.floatbank3_a_air     8
# rougher.input.floatbank10_sulfate            4
# rougher.input.feed_rate                      3
# secondary_cleaner.state.floatbank2_a_air     3
# primary_cleaner.input.depressant             2
# rougher.input.floatbank11_sulfate            1
# rougher.input.feed_size                      1
# secondary_cleaner.state.floatbank2_b_air     1
# dtype: int64

# %%
print(f'Суммарное число пропусков {data_test_tar.isnull().sum().sum()} из {data_test_tar.shape[0]} строк тестовой выборки')
# Out:
# Суммарное число пропусков 62 из 5138 строк тестовой выборки

# %% [markdown]
# Число пропусков крайне мало по сравнению с общим числом строк и составляет суммарно менее 1%. Поэтому имеет смысл попросту удалить из датасета.

# %%
data_test_tar.dropna(inplace=True)

# %%
print(f'После очистки от пропусков и выбросов в тестовой выборке осталось {data_test_tar.shape[0]} строк и {data_test_tar.shape[1]} признаков')
# Out:
# После очистки от пропусков и выбросов в тестовой выборке осталось 5091 строк и 55 признаков

# %% [markdown]
# ### Подсчёт корреляции
# Выполним проверку на мультиколлинеарность для обучающей и тестовой выборок. В результате получим матрицу корреляций между всеми столбцами (признаками) датасетов. Если есть сильная корреляция между какими-то столбцами, то это может указывать на мультиколлинеарность. В таком случае можно рассмотреть возможность удаления одного из коррелирующих столбцов.

# %%
pd.set_option('display.max_rows', None)
correlation_matrix_train_ken = data_train_clr.drop('date', axis=1).corr(method='kendall')
correlation_matrix_train_ken
# Out:
#                                                     final.output.concentrate_ag  \
# final.output.concentrate_ag                                            1.000000
# final.output.concentrate_pb                                           -0.115227
# final.output.concentrate_sol                                           0.204250
# final.output.concentrate_au                                           -0.437809
# final.output.recovery                                                  0.107617
# final.output.tail_ag                                                   0.267896
# final.output.tail_pb                                                  -0.101096
# final.output.tail_sol                                                  0.024965
# final.output.tail_au                                                   0.148019
# primary_cleaner.input.sulfate                                          0.049050
# primary_cleaner.input.depressant                                       0.142743
# ...

# %%
correlation_matrix_train_sp = data_train_clr.drop('date', axis=1).corr(method='spearman')
correlation_matrix_train_sp
# Out:
#                                                     final.output.concentrate_ag  \
# final.output.concentrate_ag                                            1.000000
# final.output.concentrate_pb                                           -0.167623
# final.output.concentrate_sol                                           0.298020
# final.output.concentrate_au                                           -0.595097
# final.output.recovery                                                  0.156698
# final.output.tail_ag                                                   0.386896
# final.output.tail_pb                                                  -0.145813
# final.output.tail_sol                                                  0.038410
# final.output.tail_au                                                   0.220532
# primary_cleaner.input.sulfate                                          0.070443
# primary_cleaner.input.depressant                                       0.211683
# ...

# %% [markdown]
# Мультиколлинеарность означает, что два или более признака сильно коррелируют друг с другом. В данном случае мы видим, что явно отсутствуют хотя бы два признака с сильной линейной зависимостью друг с другом. В свою очередь, это не должно привести к проблемам при построении модели, т.к. исключает ситуацию, когда один из признаков вносит больший вклад в предсказание целевого признака.

# %% [markdown]
# <div class="alert alert-warning">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
#         <b></b>
#
# Совсем не факт, что признаки распределены нормально, а это условие применимости корреляции Пирсона. Так что стоит вычислять корреляции Спирмена или Кендалла. Для этого в метод `.corr()` надо всего-то добавить параметр `method`, указав нужный аргумент.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Подсчитал корреляции указанными методами. Мультиколлинеарности для целевых признаков замечено всё равно не было.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изменение концентрации металлов
# Посмотрим на изменение концентрации металлов (Au, Ag, Pb) на различных этапах очистки

# %%
filter_concentrate = data_train_clr.filter(like='output.concentrate').merge(
    data_train_clr.filter(like='rougher.input.feed'), 
    left_index=True, 
    right_index=True
                                                                           )

# Строим графики для каждого металла на различных этапах очистки
for metal in ['au', 'ag', 'pb']:
    metal_concentrate = filter_concentrate.filter(like=metal)
    metal_concentrate.plot(
        kind='hist',
        histtype='barstacked',
        bins=200, 
        linewidth=10,
        alpha=0.6, 
        figsize=(20, 5)
    )
    plt.title(f'Изменение концентрации {metal.upper()} в зависимости от стадий очистки')
    plt.xlabel('Концентрация металлов')
    plt.ylabel('Частота')
    #plt.xlim(0,0.4)
    #plt.ylim(0,200)
    plt.grid(which="major", linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>✔️ Комментарий ревьюера V2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Красота да и только :)

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# По твоим гистограммам невозможно сделать вывод как на концентрации металлов влияет флотация. Для того, чтобы можно было это понять стоит также добавить на каждый из плотов гистограмму, соотвествующую концентрации металла в исходном сырье.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Добавлено

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# И снова к вопросу что ты чистил не те аномалии. Вот тут у нас везде видны явно выбивающиеся из общей картины данных околонулевые столбики. Вот их стоит удалить. Как раз потому что очень выбиваются из распределения.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Аномалии выявлены. Ниже более подробно описано. Ещё ниже (в конце раздела) представлено их экстерминирование.

# %% [markdown]
# На основании полученных гистограмм можно сделать следующие выводы:
# 1. более всего нас интересует концентрация золота, а по графику видно, что она возрастает, начиная с этапа флотации сырья, и на каждом последующем этапе очистки, что свидетельствует об эффективности процесса обогащения золота;
# 2. концентрация серебра максимальна в черновом концентрате, но затем уменьшается на каждом последующем этапе;
# 3. концентрация свинца довольно сильно возрастает после флотации, а затем немного увеличивается после первичной очистки; далее остаётся примерно на одном уровне на этапе первичной очистки и в финальном концентрате;
# 4. на графиках видны значительные частые выбросы для концентраций металлов после первичной очистки (например, для золота значение `primary_cleaner.output.concentrate_au` от 0 до 0.275 встречаются с частотой ~110), поэтому от таких значений необходимо избавиться.

# %% [markdown]
# По итогам анализа концентрации металлов избавимся от выбросов в обучающей выборке

# %%
data_train_clr = data_train_clr[(data_train_clr['primary_cleaner.output.concentrate_au'] >= 0.3) & 
                               (data_train_clr['primary_cleaner.output.concentrate_ag'] >= 0.2) & 
                               (data_train_clr['primary_cleaner.output.concentrate_pb'] >= 0.1)]
data_train_clr.shape
# Out:
# (12823, 87)

# %% [markdown]
# ### Сравнение распределения гранул сырья на выборках
# Для сравнения распределения размеров гранул сырья на обучающей и тестовой выборках построим два отдельных графика, поскольку в каждой из выборок за размер гранул отвечает две переменные: `rougher.input.feed_size` и `primary_cleaner.input.feed_size`.

# %%
plt.figure(figsize=(20, 8))
plt.hist(
    data_train_clr['rougher.input.feed_size'], 
    bins=400, 
    alpha=0.7, 
    label='Обучающая выборка', 
    color='green',
    density=True
        )
plt.hist(
    data_test_tar['rougher.input.feed_size'], 
    bins=400, 
    alpha=0.3, 
    label='Тестовая выборка',  
    color='black',
    density=True
        )
plt.title('Сравнение распределения размера гранул сырья на этапе флотации')
plt.xlabel('Частота')
plt.ylabel('Размер гранул')
plt.legend()
plt.xlim(10, 120)
plt.show()

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Сравнивать гистограммы, построенные по отличающимся в разы объёмам данных - затея очень плохая. Чтобы сравнение было корректным надо строить такие гистограммы, что высота столбика соответствует не количеству элементов в соответствующей корзине, а доле элементов в корзине по отношению к общему объёму данных.
#
# Для этого можно просто передать параметр `density=True`

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         График подредактирован в соответствии с замечанием

# %% [markdown]
# <div class="alert alert-info">
# <font size="4">🍕<b> Комментарий ревьюера V2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Было б неплохо ещё взять побольше bins, сейчас очень грубовато выглядят гистограммы. В отличие от тех же гистограмм концентраций, например.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Подправил. Но вообще ещё лучше б было использовать <i>distplot</i> из библиотеки seaborn. Но этого делать не стал из-за условий задания. Там вовсе были над прямоугольниками аггрегирующие линии.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4">🍕<b> Комментарий ревьюера V3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Дистплот или кдеплот - очень даже хорошие решения - факт. Здорово, что сам до них доходишь :)

# %%
plt.figure(figsize=(20, 6))
plt.hist(
    data_train_clr['primary_cleaner.input.feed_size'], 
    bins=200, 
    alpha=0.7, 
    label='Обучающая выборка',
    color='gold',
    density=True
        )
plt.hist(
    data_test_tar['primary_cleaner.input.feed_size'], 
    bins=200, 
    alpha=0.3, 
    label='Тестовая выборка',
    color='blue',
    density=True
        )
plt.title('Сравнение распределения размера гранул сырья на этапе первичной очистки')
plt.xlabel('Частота')
plt.ylabel('Размер гранул')
plt.legend()
#plt.xlim(5, 10)
plt.show()

# %% [markdown]
# На основании данных распределений можно сделать вывод, что особо сильно по размеру гранулы в ходе флотации и первичной очистки не отличаются. Но для более убедительного сравнения лучше построим "ящик с усами". А поскольку на графиках явно видны выбросы, то построения боксплота можно избавиться от для признаков `rougher.input.feed_size` и `primary_cleaner.input.feed_size` на каждой из выборок.

# %%
data_train_clr = data_train_clr[(data_train_clr['rougher.input.feed_size'] < 200)]
data_train_clr = data_train_clr[(data_train_clr['primary_cleaner.input.feed_size'] > 4) & 
                                (data_train_clr['primary_cleaner.input.feed_size'] < 11)]

data_train_clr.shape
# Out:
# (12752, 87)

# %%
data_test_tar = data_test_tar[(data_test_tar['rougher.input.feed_size'] < 200)]
data_test_tar = data_test_tar[(data_test_tar['primary_cleaner.input.feed_size'] > 4) & 
                                (data_test_tar['primary_cleaner.input.feed_size'] < 11)]

data_test_tar.shape
# Out:
# (5080, 55)

# %%
fig, ax = plt.subplots(figsize=(20, 3))
ax.boxplot([data_train_clr['primary_cleaner.input.feed_size'], data_test_tar['primary_cleaner.input.feed_size']], labels=['Обучающая выборка', 'Тестовая выборка'], vert=False)
ax.set_title('Сравнение распределения размера гранул сырья на этапе первичной очистки')
plt.grid(axis='x')
plt.xlim(4, 10)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 3))
ax.boxplot([data_train_clr['rougher.input.feed_size'], data_test_tar['rougher.input.feed_size']], labels=['Обучающая выборка', 'Тестовая выборка'], vert=False)
ax.set_title('Сравнение распределения размера гранул сырья на этапе флотации')
plt.grid(axis='x')
plt.xlim(20, 100)
plt.show()

# %%
print(f"Медианное/Среднее значение размера гранул до флотации: \nна обучающей выборке - {data_train_clr['rougher.input.feed_size'].describe()[5].round(3)} / {data_train_clr['rougher.input.feed_size'].describe()[1].round(3)} \nна тестовой выборке - {data_test_tar['rougher.input.feed_size'].describe()[5].round(3)} / {data_test_tar['rougher.input.feed_size'].describe()[1].round(3)}")
print()
print(f"Медианное/Среднее значение размера гранул до первичной очистки: \nна обучающей выборке - {data_train_clr['primary_cleaner.input.feed_size'].describe()[5].round(3)} / {data_train_clr['primary_cleaner.input.feed_size'].describe()[1].round(3)} \nна тестовой выборке - {data_test_tar['primary_cleaner.input.feed_size'].describe()[5].round(3)} / {data_test_tar['primary_cleaner.input.feed_size'].describe()[1].round(3)}")
# Out:
# Медианное/Среднее значение размера гранул до флотации:
# на обучающей выборке - 55.127 / 58.147
# на тестовой выборке - 50.991 / 55.47
#
# Медианное/Среднее значение размера гранул до первичной очистки:
# на обучающей выборке - 7.3 / 7.34
# на тестовой выборке - 7.25 / 7.266

# %% [markdown]
# На основании всех диаграмм можно констатировать отсутствие сильных различий между распределениями размера гранул сырья на каждом из этапов. Конечно в каждом из распределений встречаются выбросы, но на общую картину они не влияют. Т.е. нет такого, чтобы межквартильный размах, к примеру, в случае каждой из выборок различался на порядок. Медианные же и средние значения в каждом из случаев близки. Так что если оценка модели и будет неправильной, то уж точно не по причине размеров гранул сырья.

# %% [markdown]
# ### Исследование суммарной концентрации веществ
#
# Согласно описанию [технологического процесса](https://practicum.yandex.ru/trainer/2035-data-analysis-tools/lesson/213b95ed-2a0b-49a4-80ad-5f2ea9f81def/) к сырью можно отнести признаки, содержащие тип параметра `input` для этапа флотации `Rougher feed`. Финальный концентрат имеет признак этапа `final`, а в названии параметра содержится упоминанение концентрата. Черновой концентрат получается после прохождения флотации (до очистки), соответственно сюда можно отнести признаки, содержащие `rougher.output.concentrate` для разных металлов. Для этих стадий и построим гистограмму.

# %%
# суммарная концентрация веществ на стадии сырья
rougher_input_feed = data_train_clr['rougher.input.feed_au'] + data_train_clr['rougher.input.feed_ag'] + data_train_clr['rougher.input.feed_pb'] + data_train_clr['rougher.input.feed_sol']

# суммарная концентрация веществ в стадии чернового концентрата
rougher_output_concentrate = data_train_clr['rougher.output.concentrate_au'] + data_train_clr['rougher.output.concentrate_ag'] + data_train_clr['rougher.output.concentrate_pb'] + data_train_clr['rougher.output.concentrate_sol']

# суммарная концентрация веществ в стадии финального концентрата 
final_output_concentrate = data_train_clr['final.output.concentrate_au'] + data_train_clr['final.output.concentrate_ag'] + data_train_clr['final.output.concentrate_pb'] + data_train_clr['final.output.concentrate_sol']

# %%
plt.figure(figsize=(20, 10))
plt.hist(
    rougher_input_feed, 
    histtype='barstacked', 
    bins=100, 
    rwidth=0.8, 
    label='Сырьё', 
    color='orange'
        )
plt.hist(
    rougher_output_concentrate, 
    histtype='barstacked', 
    bins=100, 
    rwidth=0.8, 
    alpha=0.8, 
    label='Черновой концентрат', 
    color='green'
        )
plt.hist(
    final_output_concentrate, 
    histtype='barstacked', 
    bins=100, 
    rwidth=0.8, 
    alpha=0.4, 
    label='Финальный концентрат', 
    color='blue'
        )
plt.title('Суммарная концентрация веществ (Au, Ar, Pb, Sol) на разных стадиях технологического процесса')
plt.xlabel('Суммарная концентрация веществ')
plt.ylabel('Частота')
plt.legend()
plt.grid(True)
plt.xlim(20,90)
plt.show()

# %% [markdown]
# Как видно на гистограмме суммарная концентрация всех веществ (не только металлов) возрастает после флотации по сравнению с концентрацией в исходном сырье. Суммарная концентрация после первичной и вторичной очисток в целом схожа с черновым концентратом, но гораздо более распространена. Это можно объяснить самой суть технологического процесса. После обогащения во флотационной установки смеси руды получается черновой концентрат и «отвальные хвосты». Значит в ходе флотации и осуществляется основной "отбор" содержания вещества. Дальнейшие очистки лишь стабилизируют выработку концентрата.

# %% [markdown]
# # Построение модели

# %% [markdown]
# ### Подготовка обучающей и тестовой выборок
# Обучающая выборка содержит ровным счётом те же самые признаки, что и исходный датасет. Однако для непосредственно обучения и последующего тестирования нам необходимо идентичное число признаков в тестовом и обучающем датасетах. Следовательно избавимся от "лишних" признаков, создав новую обучающую выборку `data_train_ml` (чтобы не трогать, на всякий случай, очищенную ранее выборку `data_train_clr`).
#
# Также избавимся в обучающей, а также тестовой выборках от признака `date`.

# %%
difference_columns = set(data_init.columns) - set(data_test_tar.columns)
data_train_ml = data_train_clr.drop(columns=difference_columns)
data_train_ml = data_train_ml.drop(['date'], axis=1)
data_test_tar = data_test_tar.drop(['date'], axis=1)
print(f'Число строк в подготовленной обучающей выборке {data_train_ml.shape[0]}, число признаков {data_train_ml.shape[1]}')
print(f'Число строк в подготовленной тестовой выборке {data_test_tar.shape[0]}, число признаков {data_test_tar.shape[1]}')
# Out:
# Число строк в подготовленной обучающей выборке 12752, число признаков 54
# Число строк в подготовленной тестовой выборке 5080, число признаков 54

# %% [markdown]
# В итоге в обучающей выборке фигурирует более чем в два раза больше строк, чем в тестовой выборке. Это нормальная практика.

# %% [markdown]
# ### Создание функции для вычисления итоговой sMAPE
# Определяем функцию `smape_function` для нахождения симметричного среднего абсолютного процентного отклонения `sMAPE` (Symmetric Mean Absolute Percentage Error). В данном случае пришлось писать полноценную функцию, в отличие от подсчёта [эффективности обогащения](#Вычисление-эффективности-обогащения), где достаточно было указать рассчётную формулу. Функция принимает на вход два аргумента: `actual` и `forecast` - фактические и прогнозные значения. Затем используем функцию для вычисления метрики sMAPE для данных из предварительно очищенной обучающей выборки.
#
# Также необходимо обратить внимание на правило, которым будем руководствоваться далее. `sMAPE` выражается в процентах и интерпретируется следующим образом:
#
# - меньшее значение sMAPE указывает на лучшую точность прогноза, а значение sMAPE, равное 0, указывает на идеальную точность прогноза;
# - более высокое значение SMAPE указывает на худшую точность прогноза, а значение sMAPE, равное 100, указывает на совершенно неточный прогноз.
#
# Таким образом, нужно спрогнозировать наболее низкое значение.

# %%
def smape_function(actual, forecast):
    smape = 100 * (2 * abs(forecast - actual) / (abs(actual) + abs(forecast))).mean()
    return smape

# %% [markdown]
# <div class="alert alert-info">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Вместо суммирования и деления на длину, кажется, намного проще использовать метод .mean()

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Поменял. Не уверен, что это верно.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4">🍕<b> Комментарий ревьюера V2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# В чём причина твоей неуверенности? Выглядит ок

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Да, ок.

# %% [markdown]
# Теперь определим `итоговую функцию sMAPE`

# %%
#def final_smape_function(rougher, final):
#    final_smape = 0.25 * rougher + 0.75 * final
#    return final_smape.mean()
def final_smape_function(rougher, final):
    final_smape = 0.25*rougher + 0.75*final
    return final_smape

# %% [markdown]
# ## Обучение разных моделей

# %% [markdown]
# ### Подход к моделированию
#
# Перед нами поставлена цель: _прогнозирование эффективности обогащения чернового концентрата `rougher.output.recovery` и эффективности обогащения финального концентрата `final.output.recovery`_. Целевые признаки количественные, а не категориальные. Стало быть, моделированием решается задача регрессии (не _классификации_). Для достижения цели созданы две функции (`smape_function` и `final_smape_function`), по значениям которых можно определить, насколько точно выполнено прогнозирование.
#
# 1. Обученные модели необходимо проверить на правильность с помощью валидационной выборки. Ввиду отсутствия оного датасета мы предварительно выделим его из обучающей выборки `data_train_ml` в отношении 3:1.
#
# 2. Таким образом, построим 6 (шесть) модели прогнозирования:
#     1. эффективность обогащения чернового концентрата с помощью дерева решений,
#     2. эффективность обогащения чернового концентрата с помощью случайного леса,
#     3. эффективность обогащения чернового концентрата с помощью линейной регрессии,
#     4. эффективность обогащения финального концентрата с помощью дерева решений,
#     5. эффективность обогащения финального концентрата с помощью случайного леса,
#     6. эффективность обогащения финального концентрата с помощью линейной регрессии.
#
# 3. После предсказания выбираем лучшую модель на валидационной выборке. Аналогично после предсказания `final` также выбираем лучшую модель на валидационной выборке.
#
# 4. После подсчёта `smape_function` [для лучших моделей на тестовой выборке](#Проверка-выбранной-модели-на-тестовой-выборке) из двух значений формируем `final_smape_function`.
#
# 5. Выполним проверку модели на адекватность с помощью DummyRegression. Таков путь.

# %% [markdown]
# ### Выделение валидационной выборки
# Возможно нам сразу, ещё до этапа предобработки, нужно было выделить валидационную выборку, но сделаем это сейчас.

# %%
np.random.seed(42) # установка начального значения генератора случайных чисел в ходе обучения

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
#         <b></b>
#
# Проблема в том, что при обучении моделей из sklearn используется другой ГСЧ, нампаевский, чтобы его зафиксировать надо использовать `numpy.random.seed()`

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Тут очень интересный момент получается.
#
# Во1, нам в ТЗ сказано использовать конкретные библиотеки. Понятно, что это не подразумевает запрет на использование иных библиотек, но, как подозреваю, это сделано намерено, чтобы студент сконцентрировался на использовании конкретных подходов, а не раздирался на разные варианты.
#
# Во2, мне на одном из прошлых заданий ревьюер (не скажу, кто именно) посоветовал использовать <i>random.seed(42)</i>. И вновь речь по numpy не заходила. Конечно понимаю, что один подход для исследовательского анализа, совсем другой для обучения, поэтому и разные библиотеки. Но применение numpy меня конечно удивляет.
#
# Изменения внёс.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4">🍕<b> Комментарий ревьюера V2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# С ревьюером, возможно, возникло недопонимание. Ты то можешь использовать любые модули, какие хочешь, но без sklearn строить модели машинного обучения - проблематично, а он под капотом использует именно нампаевский ГСЧ, поэтому фиксирование сида модуля random вообще никак не влияет на построение моделей, чтобы построение модели было одинаковым при каждом запуске кода нужно фиксировать именно нампаевский сид.

# %%
features = data_train_ml.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)         # объявление переменной признаков
target_rougher = data_train_ml['rougher.output.recovery']                                           # объявление целевого признака чернового концентрата
target_final = data_train_ml['final.output.recovery']                                               # объявление целевого признака финального концентрата

# %%
# непосредственно разбиение на обучающую и валидационную выборки по признакам
features_train, features_valid, target_rougher_train, target_rougher_valid, target_final_train, target_final_valid = train_test_split(features, target_rougher, target_final, test_size=0.25)

# %% [markdown]
# ### Составление прогноза с помощью модели дерева решений
# #### Предсказание эффективности обогащения чернового концентрата

# %%
# определение лучшей модели по smape
score_smape = make_scorer(smape_function, greater_is_better=False)

# %%
# %%time
# задаем сетку гиперпараметров для перебора GridSearchCV
param_grid = {
    'max_depth': range(1, 19),
    'min_samples_leaf': [1, 5, 10],
    'max_features': ['sqrt', 'log2', None]
}

# создаем объект модели регрессии дерева решений
model_tree_reg_rougher = DecisionTreeRegressor()

# создаем объект GridSearchCV
# оцениваем по neg_mean_absolute_error (чем ближе значение к нулю, тем лучше качество модели)
grid_search_tree_reg_rougher = GridSearchCV(
    model_tree_reg_rougher, 
    param_grid, 
    scoring=score_smape, 
    cv=5
)

# запускаем поиск оптимальных параметров
grid_search_tree_reg_rougher.fit(features_train, target_rougher_train)

# предсказания значения целевой переменной для валидационной выборки
valid_predictions_reg_rougher = grid_search_tree_reg_rougher.best_estimator_.predict(features_train)

# значение smape на валидационной выборке
result_reg_rougher = smape_function(target_rougher_train, valid_predictions_reg_rougher)
               
# выводим лучшие параметры и значение метрики
print(f'sMAPE эффективности обогащения чернового концентрата наилучшей модели на валидационной выборке {round(result_reg_rougher,3)}')
print(f'при следующих параметрах: max_depth={grid_search_tree_reg_rougher.best_params_["max_depth"]}, max_features=\'{grid_search_tree_reg_rougher.best_params_["max_features"]}\', min_samples_leaf={grid_search_tree_reg_rougher.best_params_["min_samples_leaf"]}')
print()
# Out:
# sMAPE эффективности обогащения чернового концентрата наилучшей модели на валидационной выборке 2.257
# при следующих параметрах: max_depth=16, max_features='None', min_samples_leaf=10
#
# CPU times: user 1min 55s, sys: 56.7 ms, total: 1min 55s
# Wall time: 1min 55s
# Parser   : 192 ms

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>✔️ Комментарий ревьюера V3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Появился скорер основанный на смапе 👍
# <br />
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4">🍕<b> Комментарий ревьюера V2</b></font>
#     <br />
#     <font size="3", color = "black">
#         <b></b>
#
# Странно, в документации аргумент `'auto'` параметра `max_features` есть, а тут ругается 🤔

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Действительно странно. Делал контрольные прогоны с перезапуском ядра - ошибка не вылезала. Сегодня запустил - вылезла. Заменил <i>auto</i> на <b>None</b>. Здесь и далее.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>✔️ Комментарий ревьюера V2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# То, что ты перешёл на грид серч - это здорово. С ним код становится проще и понятнее.
# <br />
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера V2</b></font>
#     <br />
#     <font size="3", color = "black">
#         <b></b>
#
# Но есть нюанс. Указав аргумент `scoring='neg_mean_absolute_error'` ты явно сказал грид серчу "найди мне лучшую по MAE модель". Однако, нет никаких причин считать, что лучшая по MAE модель будет лучшей и по smape. Чтобы найти именно модель лучшую по smape нужно с помощью функции <a href="https://scikit-learn.org/stable/modules/generated/sklearn.metrics.make_scorer.html">make_scorer</a> создать свой кастомный скорер, не забыв указать параметр `greater_is_better=False`, ведь smape мы минимизируем, а не максимизируем.
#
# **Важный нюанс**: у sklearn очень специфичный оптимизатор, он не умеет минимизировать. Поэтому когда мы ему говорим, что `greater_is_better=False` он делает следующее: умножает метрики на -1 и ищет максимум. Пример: есть модели с метриками 2, 4, 5, sklearn домножил на -1, получилось -2, -4, -5, максимум == -2. То есть найденная метрика будет с верным по модулю значением, но другим знаком. Если ты выведешь атрибут грид серча `.best_score_`

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Определил <i>score_smape</i>. Переучил модели здесь и далее по коду.

# %%
#%%time
#best_model_reg_rougher = None
#best_result_reg_rougher = 10000
#best_depth_reg_rougher = 0
#for depth in tqdm(range(1, 29)):    
    # создание объекта модели регрессии дерева решений без явного указания гиперпараметров
#    model_tree_reg_rougher = DecisionTreeRegressor(max_depth=depth)

    # обучение модели для оценки эффективности обогащения чернового концентрата
#    model_tree_reg_rougher.fit(features_train, target_rougher_train)

    # предсказания значения целевой переменной для валидационной выборки
 #   valid_predictions_reg_rougher = model_tree_reg_rougher.predict(features_valid)

    # значение smape на валидационной выборке
  #  result_reg_rougher = smape_function(target_rougher_valid, valid_predictions_reg_rougher)
    
   # if result_reg_rougher < best_result_reg_rougher:
    #    best_model_reg_rougher = model_tree_reg_rougher
     #   best_result_reg_rougher = result_reg_rougher
      #  best_depth_reg_rougher = depth

#print(f'sMAPE эффективности обогащения чернового концентрата наилучшей модели на валидационной выборке:", {round(best_result_reg_rougher,3)} (при глубине дерева = {best_depth_reg_rougher})')
#print()

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
#         <b></b>
#
# Ты же переменную `depth` не передаёшь в дерево, странный подбор гиперпараметра 🤔

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Бес попутал. Забыл указать <i>max_depth</i> в качестве передаваемого гиперпараметра. Сейчас исправил.
#
# Тем не менее, пришёл к выводу, что данный расчёт необходимо переделать. Во1, можно оставить и без всяких гиперпараметров и их подбора. Тем самым указать DecisionTreeRegressor().
#
# Во2, можно задать DecisionTreeRegressor(max_depth=depth), но всё равно возникнет вопрос, а по какому критерию определяется оптимальная модель? Значение sMAPE должно быть наиболее приближенным к нулю. Поэтому см. В3.
#
# В3, рассчитал выше с подбором параметров по опыту прошлого задания. Вообще у нас кросс-валидация не нужна при расчётах, но ввёл её поскольку так прогноз получается наиболее близким к 0, что для <i>sMAPE</i> как раз хорошо. Надеюсь, что это близко к правде. Если раскомментировать код выше (с подбором гиперпараметра max_depth), либо вовсе убрать цикл и не подбирать max_depth, то результат будет более 3, а то и 4. При этом при GridSearchCV результат получается чуть больше 2.

# %% [markdown]
# #### Предсказание эффективности обогащения финального концентрата
# Рассчитываем прогноз по `sMAPE` для финального концентрата по модели дерева решений с использованием тех же подобранных значений гиперпараметров, что стали оптимальны в случае чернового концентрата. Возможно использовать нужно иные значения гиперпараметры, но так понимаю, первоначальные условия (значения гиперпараметров) должны быть идентичны.

# %%
# сетка гиперпараметров для перебора GridSearchCV указана выше
# создаем объект модели регрессии дерева решений
model_tree_reg_final = DecisionTreeRegressor()

# создаем объект GridSearchCV
# оцениваем по neg_mean_absolute_error (чем ближе значение к нулю, тем лучше качество модели)
grid_search_tree_reg_final = GridSearchCV(
    model_tree_reg_final, 
    param_grid, 
    scoring=score_smape, 
    cv=5
)

# запускаем поиск оптимальных параметров
grid_search_tree_reg_final.fit(features_train, target_final_train)

# предсказания значения целевой переменной для валидационной выборки
valid_predictions_reg_final = grid_search_tree_reg_final.best_estimator_.predict(features_train)

# значение smape на валидационной выборке
result_reg_final = smape_function(target_final_train, valid_predictions_reg_final)
               
# выводим лучшие параметры и значение метрики
print(f'sMAPE эффективности обогащения финального концентрата наилучшей модели на валидационной выборке {round(result_reg_final,3)}')
print(f'при следующих параметрах: max_depth={grid_search_tree_reg_final.best_params_["max_depth"]}, max_features=\'{grid_search_tree_reg_final.best_params_["max_features"]}\', min_samples_leaf={grid_search_tree_reg_final.best_params_["min_samples_leaf"]}')
print()
# Out:
# sMAPE эффективности обогащения финального концентрата наилучшей модели на валидационной выборке 5.153
# при следующих параметрах: max_depth=13, max_features='None', min_samples_leaf=10

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
#         <b></b>
#
# Тут тоже глубина не передаётся в конструктов `DecisionTreeRegressor`

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Исправлено. Обоснование указал выше.

# %% [markdown]
# ### Составление прогноза с помощью модели случайного леса
# #### Предсказание эффективности обогащения чернового концентрата

# %%
#from sklearn.model_selection import cross_val_score
#from sklearn.metrics import make_scorer
#a,b,c,d = train_test_split(features_train, target_rougher_train, random_state=10)
#pred = cross_val_score(DecisionTreeRegressor(),features_train, target_rougher_train, scoring=make_scorer(smape_function, greater_is_better=False))

#pred

# %%
# %%time
# задаем сетку гиперпараметров для перебора GridSearchCV
param_grid_rfr = {
    'n_estimators': range(1,9,2),
    'max_depth': range(1,9,1),
    'min_samples_leaf': [1, 5, 10],
    'max_features': ['sqrt', 'log2', None]
}
    
# создаем объект модели случайного леса
model_rfr_reg_rougher = RandomForestRegressor()

# создаем объект GridSearchCV
# оцениваем по neg_mean_absolute_error (чем ближе значение к нулю, тем лучше качество модели)
grid_search_rfr_reg_rougher = GridSearchCV(
    model_rfr_reg_rougher, 
    param_grid_rfr, 
    scoring=score_smape, 
    cv=5
)

# запускаем поиск оптимальных параметров
grid_search_rfr_reg_rougher.fit(features_train, target_rougher_train)

# предсказания значения целевой переменной для валидационной выборки
valid_predictions_rfr_reg_rougher = grid_search_rfr_reg_rougher.best_estimator_.predict(features_train)

# значение smape на валидационной выборке
result_rfr_reg_rougher = smape_function(target_rougher_train, valid_predictions_rfr_reg_rougher)
               
# выводим лучшие параметры и значение метрики
print(f'sMAPE эффективности обогащения финального концентрата наилучшей модели на валидационной выборке {round(result_rfr_reg_rougher,3)}')
print(f'при следующих параметрах: n_estimators={grid_search_rfr_reg_rougher.best_params_["n_estimators"]}, max_depth={grid_search_rfr_reg_rougher.best_params_["max_depth"]}, max_features=\'{grid_search_rfr_reg_rougher.best_params_["max_features"]}\', min_samples_leaf={grid_search_rfr_reg_rougher.best_params_["min_samples_leaf"]}')
print()
# Out:
# sMAPE эффективности обогащения финального концентрата наилучшей модели на валидационной выборке 3.046
# при следующих параметрах: n_estimators=7, max_depth=8, max_features='None', min_samples_leaf=5
#
# CPU times: user 5min 17s, sys: 368 ms, total: 5min 17s
# Wall time: 5min 18s

# %%
# %%time
best_result_rfr_rougher = 10000
for est in tqdm(range(1,31,2)):
    for depth in range(1,9,1):
        
        # создание объекта модели регрессии случайный лес с двумя параметрами
        model_rfr_rougher = RandomForestRegressor(n_estimators=est, max_depth=depth)
        
        # обучение модели на тренировочной выборке
        model_rfr_rougher.fit(features_train, target_rougher_train) 
        
        # предсказания модели на валидационной выборке
        predictions_valid_rfr_rougher = model_rfr_rougher.predict(features_valid) 
        
        # значение smape на валидационной выборке
        result_rfr_rougher = smape_function(target_rougher_valid, predictions_valid_rfr_rougher)
        
        if result_rfr_rougher < best_result_rfr_rougher:
            best_model_rfr_rougher = model_rfr_rougher 
            best_result_rfr_rougher = result_rfr_rougher 
            best_est_rfr_rougher = est
            best_depth_rfr_rougher = depth

print(f'sMAPE эффективности обогащения чернового концентрата наилучшей модели на валидационной выборке: {round(best_result_rfr_rougher,3)} (при количестве деревьев = {best_est_rfr_rougher} и максимальной глубине = {best_depth_rfr_rougher})')
print()
# Out:
# 100%|██████████| 15/15 [04:51<00:00, 19.44s/it]
# sMAPE эффективности обогащения чернового концентрата наилучшей модели на валидационной выборке: 3.393 (при количестве деревьев = 27 и максимальной глубине = 8)
#
# CPU times: user 4min 50s, sys: 172 ms, total: 4min 50s
# Wall time: 4min 51s

# %% [markdown]
# #### Предсказание эффективности обогащения финального концентрата

# %%
# %%time
best_result_rfr_final = 10000
for est in tqdm(range(1,31,2)):
    for depth in range(1,9,1):
        
        # создание объекта модели регрессии случайный лес с двумя параметрами
        model_rfr_final = RandomForestRegressor(n_estimators=est, max_depth=depth)
        
        # обучение модели на тренировочной выборке
        model_rfr_final.fit(features_train, target_final_train) 
        
        # предсказания модели на валидационной выборке
        predictions_valid_rfr_final = model_rfr_final.predict(features_valid) 
        
        # значение smape на валидационной выборке
        result_rfr_final = smape_function(target_final_valid, predictions_valid_rfr_final)
        
        if result_rfr_final < best_result_rfr_final:
            best_model_rfr_final = model_rfr_final 
            best_result_rfr_final = result_rfr_final 
            best_est_rfr_final = est
            best_depth_rfr_final = depth

print(f'sMAPE эффективности обогащения финального концентрата наилучшей модели на валидационной выборке: {round(best_result_rfr_final,3)} (при количестве деревьев = {best_est_rfr_final} и максимальной глубине = {best_depth_rfr_final})')
print()
# Out:
# 100%|██████████| 15/15 [04:55<00:00, 19.67s/it]
# sMAPE эффективности обогащения финального концентрата наилучшей модели на валидационной выборке: 6.327 (при количестве деревьев = 17 и максимальной глубине = 8)
#
# CPU times: user 4min 54s, sys: 272 ms, total: 4min 54s
# Wall time: 4min 55s

# %%
# сетка гиперпараметров для перебора GridSearchCV задана ранее

# создаем объект модели случайного леса
#model_rfr_reg_final = RandomForestRegressor()

# создаем объект GridSearchCV
# оцениваем по neg_mean_absolute_error (чем ближе значение к нулю, тем лучше качество модели)
#grid_search_rfr_reg_final = GridSearchCV(
 #   model_rfr_reg_final, 
  #  param_grid, 
   # scoring='neg_mean_absolute_error', 
    #cv=5
#)

# запускаем поиск оптимальных параметров
#grid_search_rfr_reg_final.fit(features_train, target_final_train)

# предсказания значения целевой переменной для валидационной выборки
#valid_predictions_rfr_reg_final = grid_search_rfr_reg_final.best_estimator_.predict(features_train)

# значение smape на валидационной выборке
#result_rfr_reg_final = smape_function(target_final_train, valid_predictions_rfr_reg_final)
               
# выводим лучшие параметры и значение метрики
#print(f'sMAPE эффективности обогащения финального концентрата наилучшей модели на валидационной выборке {round(result_rfr_reg_final,3)}')
#print(f'при следующих параметрах: n_estimators={grid_search_rfr_reg_final.best_params_["n_estimators"]}, max_depth={grid_search_rfr_reg_final.best_params_["max_depth"]}')
#print()

# %% [markdown]
# Обучение проведено для с помощью цикла перебора гиперпараметров `n_estimators` и `max_depth`, а также при подборе гиперпараметров через `GridSearchCV`. Результат, более близкий к желаемому, наблюдается во втором случае, однако перебрать большИй диапазон не представляется возможным, ввиду крайней длительности обучения модели в случае финального концентрата. Мне так ни разу не довелось дождаться выполнения расчёта. Поэтому блок выше закомментирован.
#
# В любом случае величина `sMAPE` у чернового концентрата почти в два раза ниже, чем в случае с финальным концентратом. Тоже самое, как и для модели дерева решений.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
#         <b></b>
#
# Кажется, стоит отреагировать на ошибку :)
#
# Попробуй не в цикле, а в каком-то одном блоке с определённым значением глубины и числа деревьев обучить модель и получить предсказание, посмотреть какие будут эти предсказания и вычислить метрику. Возможно, где-то у тебя появляются пропуски. Возможно, из-за того, что по формуле смапе у тебя получается деление на 0.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Исправлено. Также просчитан вариант с <i>GridSearchCV</i>, но он показал чрезмерную ресурсозатратность.

# %% [markdown]
# <div class="alert alert-warning">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Ресурсозатратность связана с тем, что кросс-валидация - это обучение сразу нескольких моделей для одного и того же набора гиперпараметров, что очевидно дольше, чем строить одну. В качестве альтернативы можно вместо грид серча использовать <a href="https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html">RandomizedSearchCV</a>: по сути всё тоже самое, только исследуется не вся сетка гиперпараметров, а несколько их наборов. По умолчанию 10, если надо другое число - указываешь его в параметре `n_iter`.
#
# Вообще, если использовать кросс-валидацию, то отложенная валидационная выборка уже становится бессмысленной, так что перевести все модели на кросс-валидацию и смотреть метрику на ней - было бы хорошим планом.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Правильно я понимаю, что при кросс-валидации можно вовсе не выделять валидационную выборку? Правда, у меня модель линейной регрессии есть, где всё равно нужно валидировать. Но, допустим, другая модель, либо в линреге можно также сделать кросс-валидацию. Тогда можно не выделять?
#
# Сейчас уже не буду использовать RandomizedSearchCV, но на будущее запомню. Спасибо.

# %% [markdown]
# ### Составление прогноза с помощью модели линейной регрессии
# #### Предсказание эффективности обогащения чернового концентрата

# %%
# создание объекта модели линейной регрессии без явного указания заданных гиперпараметров
model_linreg_rougher = LinearRegression()

# обучение модели для оценки эффективности обогащения чернового концентрата
model_linreg_rougher.fit(features_train, target_rougher_train)

# предсказания на валидационной выборке
predictions_linreg_valid_rougher = model_linreg_rougher.predict(features_valid)

# определение эффективности обогащения чернового концентрата на валидационной выборке в случае линейной регрессии
result_valid_linreg_rougher = smape_function(target_rougher_valid, predictions_linreg_valid_rougher)

print(f'sMAPE эффективности обогащения чернового концентрата наилучшей модели на валидационной выборке: {round(result_valid_linreg_rougher,2)}')
# Out:
# sMAPE эффективности обогащения чернового концентрата наилучшей модели на валидационной выборке: 4.63

# %% [markdown]
# #### Предсказание эффективности обогащения финального концентрата

# %%
# создание объекта модели линейной регрессии без явного указания заданных гиперпараметров
model_linreg_final = LinearRegression()

# обучение модели для оценки эффективности обогащения чернового концентрата
model_linreg_final.fit(features_train, target_final_train)

# предсказания на валидационной выборке
predictions_linreg_valid_final = model_linreg_final.predict(features_valid)

# определение эффективности обогащения финального концентрата на валидационной выборке в случае линейной регрессии
result_valid_linreg_final = smape_function(target_final_valid, predictions_linreg_valid_final)

print(f'sMAPE эффективности обогащения финального концентрата наилучшей модели на валидационной выборке: {round(result_valid_linreg_final,2)}')
# Out:
# sMAPE эффективности обогащения финального концентрата наилучшей модели на валидационной выборке: 7.57

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
#         <b></b>
#
# `result_valid_linreg_final = smape_function(target_rougher_valid, predictions_linreg_valid_final)`
#
# Вроде предсказания финал, а таргет рафер... Что-то не сходится

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Да, верно. Дефект.

# %% [markdown]
# ## Проверка выбранной модели на тестовой выборке
# Прежде, чем проводить тестирование, необходимо подготовить тестовую выборку в плане выделения целевых признаков.

# %%
features_test = data_test_tar.drop(['rougher.output.recovery','final.output.recovery'], axis=1)
targer_test_rougher = data_test_tar['rougher.output.recovery']
targer_test_final = data_test_tar['final.output.recovery']

# %% [markdown]
# Теперь определимся, какая модель лучше. Для этого построим график.

# %%
# массив значений для результатов расчёта эффективности чернового концентрата на разных моделях
rougher_smap = []
rougher_smap.append(result_reg_rougher)
rougher_smap.append(result_rfr_reg_rougher)
rougher_smap.append(result_valid_linreg_rougher)

# массив значений для результатов расчёта эффективности финального концентрата на разных моделях
final_smap = []
final_smap.append(result_reg_final)
final_smap.append(best_result_rfr_final)
final_smap.append(result_valid_linreg_final)

# %%
plt.figure(figsize=(20, 6))
plt.barh(
    ['result_reg_rougher', 'result_rfr_reg_rougher', 'result_valid_linreg_rougher'], 
    rougher_smap, 
    color='black', 
    alpha=0.3,
    label='sMAPE чернового концентрата'
       )
plt.barh(
    ['result_reg_final', 'best_result_rfr_final', 'result_valid_linreg_final'], 
    final_smap, 
    color='gold', 
    alpha=0.8,
    label='sMAPE финального концентрата'
       )
plt.title('sMAPE по обученным моделям для чернового и финального концентратов')
plt.legend()
plt.xlabel('Названия моделей')
plt.ylabel('Рассчитанное значение sMAPE')
# Out:
# Text(0, 0.5, 'Рассчитанное значение sMAPE')

# %% [markdown]
# Как видно по графику, самые минимальные значения эффективности обогащения для чернового и финальных концентратов возвращает модель дерева решений. Её и будем тестировать.
#
# Проверку выполним для каждого из признаков по отдельности. Ввиду того, что обучение модели дерева решений `model_tree_reg_` происходило с применением `GridSearchCV`, наименование тестируемой модели также иное.

# %%
# проверка модели дерева решений для показателя эффективности обогащения чернового концентрата
features_test_rougher = data_test_tar['rougher.output.recovery']
test_predictions_rougher = grid_search_rfr_reg_rougher.predict(features_test)
print(f'sMAPE чернового концентрата = {smape_function(test_predictions_rougher, targer_test_rougher)}')

# проверка модели дерева решений для показателя эффективности обогащения чернового концентрата
features_test_final = data_test_tar['final.output.recovery']
test_predictions_final = grid_search_tree_reg_final.predict(features_test)
print(f'sMAPE финального концентрата = {smape_function(test_predictions_final, targer_test_final)}')
# Out:
# sMAPE чернового концентрата = 4.34182437524914
# sMAPE финального концентрата = 9.956744011108306

# %%
print(f'Итоговое sMAPE равно {final_smape_function(smape_function(test_predictions_rougher, targer_test_rougher), smape_function(test_predictions_final, targer_test_final))}')
# Out:
# Итоговое sMAPE равно 8.553014102143514

# %% [markdown]
# <div class="alert alert-warning">
# <font size="4"><b>⚠️ Комментарий ревьюера V2</b></font>
#     <br />
#     <font size="3", color = "black">
#         <b></b>
#
# Отдельные компоненты итоговой метрики, `smape_function(test_predictions_rougher, targer_test_rougher)` и `smape_function(test_predictions_final, targer_test_final)` тоже стоит вывести на экран. Чтобы можно было понимать не только насколько наши модели хороши в целом, но и в каждой конкретной подзадаче.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Вывел на экран

# %% [markdown]
# <div class="alert alert-warning">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Всё так. На валидации мы отбираем лучшую модель, и просто на тестовой выборке исследуем её метрику. Время раскомментировать.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Выполнено

# %% [markdown]
# ## Проверка модели на адекватность

# %%
model_dummy_r = DummyRegressor(strategy='mean')
model_dummy_r.fit(features_train, target_rougher_train)
target_pred_r = model_dummy_r.predict(features_train)
rougher_smape_ = smape_function(target_rougher_train, target_pred_r)
print('sMAPE эффективности обогащения чернового концентрата на предсказательной модели DummyRegressor', rougher_smape_)
# Out:
# sMAPE эффективности обогащения чернового концентрата на предсказательной модели DummyRegressor 7.292782323427629

# %%
model_dummy = DummyRegressor(strategy='mean')
model_dummy.fit(features_train, target_final_train)
target_pred = model_dummy.predict(features_train)
final_smape_ = smape_function(target_final_train, target_pred)
print('sMAPE эффективности обогащения финального концентрата на предсказательной модели DummyRegressor', final_smape_)
# Out:
# sMAPE эффективности обогащения финального концентрата на предсказательной модели DummyRegressor 9.976787818329196

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера V2</b></font>
#     <br />
#     <font size="3", color = "black">
#         <b></b>
#
# Ты посчитал smape на одном из двух таргетов. Нужно, конечно, на обоих. Просто всё то же самое, только для rougher добавь в работу.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Вывел для чернового концентрата

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>✔️ Комментарий ревьюера V3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# 👍
# <br />
#     </font>
# </div>

# %% [markdown]
# Результат показал, что модель на адекватность возвращает значение `sMAPE` больше, чем расчёты всех обученных моделей и для финального концентрата, и, гораздо лучше, для чернового концентрата. Очень хорошо.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
#         <b></b>
#
# Она нужна потому что мы не можем понимать какое значение смапе хорошее, а какое - нет. Давать заказчику работу, не понимая хорошая ли модель - сомнительная затея. Именно поэтому нам и надо сравнить полученные модели с дамми. Если наша метрика лучше - значит наша работа имеет смысл.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Не знаю, насколько правильно подсчитал, но результат подсчитал.

# %% [markdown]
# # Чек-лист готовности проекта

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке выполнения
# - [x]  Выполнен шаг 1: данные подготовлены
#     - [x]  Проверена формула вычисления эффективности обогащения
#     - [x]  Проанализированы признаки, недоступные в тестовой выборке
#     - [x]  Проведена предобработка данных
# - [x]  Выполнен шаг 2: данные проанализированы
#     - [x]  Исследовано изменение концентрации элементов на каждом этапе
#     - [x]  Проанализированы распределения размеров гранул на обучающей и тестовой выборках
#     - [x]  Исследованы суммарные концентрации
# - [x]  Выполнен шаг 3: построена модель прогнозирования
#     - [x]  Написана функция для вычисления итогового *sMAPE*
#     - [x]  Обучено и проверено несколько моделей
#     - [x]  Выбрана лучшая модель, её качество проверено на тестовой выборке

# %% [markdown]
# <div class="alert alert-info">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Подведём итоги. Ну, ты сам знаешь, что ошибки есть, так что доработка не должна стать сюрпризом :)
#
# Что нужно сделать:
#
# + Корректно брать таргеты из полной выборки в тестовую
# + Пересмотреть свой взгляд на обработку аномалий и пропусков
# + Добавить гистограммы металлов в исходном сырье
# + Нормализовать гистограммы размеров гранул
# + Фиксировать сид не модуля random, а модуля numpy.random
# + Пофиксить ошибку. Видимо, у тебя получается деление на 0
# + Сделать корректный подбор глубин дерева
# + Пофиксить ошибку в расчёте метрики финал Линейной регрессии
# + Раскомментировать тестирование и проверку на адекватность
#
# Немало, но терпимо. Справишься со всем :)
#
# Жду новую отправку!

# %% [markdown]
# <div class="alert alert-info">
# <font size="4"><b>Комментарий студента v1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Исправлено
